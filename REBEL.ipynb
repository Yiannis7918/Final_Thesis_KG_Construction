# %%
import pandas as pd
import ast
import spacy
import re
import os
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MaxAbsScaler
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer
import matplotx

# %% [markdown]
# # Load Rebel Triplets & Obtain Suitable Triplet Format for Neo4j

# %%
rebel_triplets = pd.read_csv("REBEL_triples_per_sentence.csv")

def convert_to_list(column):
    return column.apply(ast.literal_eval)

rebel_triplets['triplets_clean_sent'] = convert_to_list(rebel_triplets['triplets_clean_sent'])

rebel_triplets.head()
# Out:
#                                                Title  \
# 0  TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 1  TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 2  TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 3  TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 4  TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
#
#                      Articles  \
# 0  Article 1  Subject matter
# 1     Article 2  Definitions
# 2     Article 2  Definitions
# 3     Article 2  Definitions
# 4     Article 2  Definitions
#
#                               coreference_list_ready  \
# 0  this regulation lays down the rules for the es...
# 1  ‘applicant’ means a natural person or an entit...
# 2  ‘application document’ means a tender, a reque...
# 3  ‘award procedure’ means a procurement procedur...
# 4  ‘basic act’ means a legal act, other than a re...
#
#                          coreference_paragraph_clean  \
# 0  this regulation lays down the rules for the es...
# 1  applicant means a natural person or an entity ...
# 2  application document means a tender a request ...
# 3  award procedure means a procurement procedure ...
# 4  basic act means a legal act other than a recom...
#
#                           coreference_sentence_clean  \
# 0  this regulation lays down the rules for the es...
# 1  applicant means a natural person or an entity ...
# 2  application document means a tender a request ...
# 3  award procedure means a procurement procedure ...
# 4  basic act means a legal act other than a recom...
#
#                                 coreference_sentence  \
# 0  this regulation lays down the rules for the es...
# 1  ‘applicant’ means a natural person or an entit...
# 2  ‘application document’ means a tender, a reque...
# 3  ‘award procedure’ means a procurement procedur...
# 4  ‘basic act’ means a legal act, other than a re...
#
#                                  triplets_clean_sent
# 0  [[{'head': 'european atomic energy community',...
# 1  [[{'head': 'natural person', 'type': 'subclass...
# 2  [[{'head': 'grant application', 'type': 'subcl...
# 3  [[{'head': 'procurement', 'type': 'part of', '...
# 4  [[{'head': 'euratom treaty', 'type': 'followed...

# %%
rebel_triplets.isna().sum()
# Out:
# Title                          0
# Articles                       0
# coreference_list_ready         0
# coreference_paragraph_clean    0
# coreference_sentence_clean     0
# coreference_sentence           0
# triplets_clean_sent            0
# dtype: int64

# %%
rebel_triplets_exploded = rebel_triplets.explode("triplets_clean_sent")

# %%
def triplet_tuple(triplet_dictionary):

    return (triplet_dictionary[0]["head"], triplet_dictionary[0]["type"], triplet_dictionary[0]["tail"])

# %%
empty_triplets = rebel_triplets_exploded[rebel_triplets_exploded['triplets_clean_sent'].apply(lambda x: len(x) == 0)]
print(empty_triplets)
# Out:
#                                                   Title  \
# 12    TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 12    TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 46    TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 51    TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 88          TITLE II \nBUDGET AND BUDGETARY PRINCIPLES
# 106         TITLE II \nBUDGET AND BUDGETARY PRINCIPLES
# 106         TITLE II \nBUDGET AND BUDGETARY PRINCIPLES
# 184         TITLE II \nBUDGET AND BUDGETARY PRINCIPLES
# 689                   TITLE IV \nBUDGET IMPLEMENTATION
# 719                   TITLE IV \nBUDGET IMPLEMENTATION
# 719                   TITLE IV \nBUDGET IMPLEMENTATION
# 719                   TITLE IV \nBUDGET IMPLEMENTATION
# 969                   TITLE IV \nBUDGET IMPLEMENTATION
# 987                             TITLE V \nCOMMON RULES
# 1025                            TITLE V \nCOMMON RULES
# 1684  TITLE XI \nCONTRIBUTIONS TO EUROPEAN POLITICAL...
# 1684  TITLE XI \nCONTRIBUTIONS TO EUROPEAN POLITICAL...
# 1893          TITLE XV \nADMINISTRATIVE APPROPRIATIONS
# 1897          TITLE XV \nADMINISTRATIVE APPROPRIATIONS
# 1989  TITLE XVI \nINFORMATION REQUESTS AND DELEGATED...
# 2007  TITLE XVI \nINFORMATION REQUESTS AND DELEGATED...
# 2096  TITLE XVI \nINFORMATION REQUESTS AND DELEGATED...
# 2109  TITLE XVI \nINFORMATION REQUESTS AND DELEGATED...
# 2112  TITLE XVI \nINFORMATION REQUESTS AND DELEGATED...
# 2189  TITLE XVI \nINFORMATION REQUESTS AND DELEGATED...
# 2193  TITLE XVI \nINFORMATION REQUESTS AND DELEGATED...
# 2193  TITLE XVI \nINFORMATION REQUESTS AND DELEGATED...
# 2196  TITLE XVI \nINFORMATION REQUESTS AND DELEGATED...
# 2315  TITLE XVI \nINFORMATION REQUESTS AND DELEGATED...
# 2315  TITLE XVI \nINFORMATION REQUESTS AND DELEGATED...
# 2315  TITLE XVI \nINFORMATION REQUESTS AND DELEGATED...
#
#                                                Articles  \
# 12                              Article 2  Definitions
# 12                              Article 2  Definitions
# 46                              Article 2  Definitions
# 51                              Article 2  Definitions
# 88                      Article 7  Scope of the budget
# 106   Article 12  Cancellation and carry-over of app...
# 106   Article 12  Cancellation and carry-over of app...
# 184   Article 22  Structure to accommodate assigned ...
# 689   Article 91  Liability of financial actors for ...
# 719   Article 93  Treatment of financial irregularit...
# 719   Article 93  Treatment of financial irregularit...
# 719   Article 93  Treatment of financial irregularit...
# 969   Article 122  Action before the Court of Justic...
# 987      Article 130  Financial framework partnerships
# 1025  Article 135  Protection of the financial inter...
# 1684                    Article 223  Budgetary aspects
# 1684                    Article 223  Budgetary aspects
# 1893                   Article 264  General provisions
# 1897                   Article 264  General provisions
# 1989  Article 272  Amendments to Regulation (EU) No ...
# 2007  Article 272  Amendments to Regulation (EU) No ...
# 2096  Article 272  Amendments to Regulation (EU) No ...
# 2109  Article 272  Amendments to Regulation (EU) No ...
# 2112  Article 272  Amendments to Regulation (EU) No ...
# 2189  Article 272  Amendments to Regulation (EU) No ...
# 2193  Article 272  Amendments to Regulation (EU) No ...
# 2193  Article 272  Amendments to Regulation (EU) No ...
# 2196  Article 272  Amendments to Regulation (EU) No ...
# 2315  Article 275  Amendments to Regulation (EU) No ...
# 2315  Article 275  Amendments to Regulation (EU) No ...
# 2315  Article 275  Amendments to Regulation (EU) No ...
#
#                                  coreference_list_ready  \
# 12    ‘building contract’ means a contract covering ...
# 12    ‘building contract’ means a contract covering ...
# 46    ‘low value grant’ means a grant lower than or ...
# 51    ‘output’ means the deliverables generated by t...
# 88    commitment appropriations shall cover the tota...
# 106   appropriations which have not been used by the...
# 106   appropriations which have not been used by the...
# 184   the appropriations corresponding to assigned r...
# 689   without prejudice to articles 92, 94 and 95 of...
# 719   the member states shall fully support the unio...
# 719   the member states shall fully support the unio...
# 719   the member states shall fully support the unio...
# 969   without prejudice to the remedies allowed by t...
# 987   the commission may establish financial framewo...
# 1025  the decision to register information concernin...
# 1684  contributions, as well as appropriations set a...
# 1684  contributions, as well as appropriations set a...
# 1893  administrative appropriations shall be non-dif...
# 1897  administrative expenditure arising from contra...
# 1989  article 37 is amended as follows: (a) in parag...
# 2007  article 38 is amended as follows: (a) in parag...
# 2096  article 59 is amended as follows: (a) the foll...
# 2109  article 61 is amended as follows: (a) in parag...
# 2112  article 65 is amended as follows: (a) the thir...
# 2189  article 114 is amended as follows: (a) paragra...
# 2193  article 114 is amended as follows: (a) paragra...
# 2193  article 114 is amended as follows: (a) paragra...
# 2196  article 115 is amended as follows: (a) the hea...
# 2315  the following chapter is inserted: ‘chapter va...
# 2315  the following chapter is inserted: ‘chapter va...
# 2315  the following chapter is inserted: ‘chapter va...
#
#                             coreference_paragraph_clean  \
# 12    building contract means a contract covering th...
# 12    building contract means a contract covering th...
# 46    low value grant means a grant lower than or eq...
# 51    output means the deliverables generated by the...
# 88    commitment appropriations shall cover the tota...
# 106   appropriations which have not been used by the...
# 106   appropriations which have not been used by the...
# 184   the appropriations corresponding to assigned r...
# 689   without prejudice to articles 92 94 and 95 of ...
# 719   the member states shall fully support the unio...
# 719   the member states shall fully support the unio...
# 719   the member states shall fully support the unio...
# 969   without prejudice to the remedies allowed by t...
# 987   the commission may establish financial framewo...
# 1025  the decision to register information concernin...
# 1684  contributions as well as appropriations set as...
# 1684  contributions as well as appropriations set as...
# 1893  administrative appropriations shall be nondiff...
# 1897  administrative expenditure arising from contra...
# 1989  article 37 is amended as follows: in paragraph...
# 2007  article 38 is amended as follows: in paragraph...
# 2096  article 59 is amended as follows: the followin...
# 2109  article 61 is amended as follows: in paragraph...
# 2112  article 65 is amended as follows: the third su...
# 2189  article 114 is amended as follows: paragraph 1...
# 2193  article 114 is amended as follows: paragraph 1...
# 2193  article 114 is amended as follows: paragraph 1...
# 2196  article 115 is amended as follows: the heading...
# 2315  the following chapter is inserted: chapter va ...
# 2315  the following chapter is inserted: chapter va ...
# 2315  the following chapter is inserted: chapter va ...
#
#                              coreference_sentence_clean  \
# 12    land buildings or other immovable property doe...
# 12    land buildings or other immovable property doe...
# 46    low value grant means a grant lower than or eq...
# 51    output means the deliverables generated by the...
# 88    commitment appropriations shall cover the tota...
# 106   appropriations which have not been used by the...
# 106   appropriations which have not been used by the...
# 184   appropriations referred to in point of the fir...
# 689   s e c t i o n 2 r u l e s a p p l i c a b l e ...
# 719   s e c t i o n 3 r u l e s a p p l i c a b l e ...
# 719   s e c t i o n 3 r u l e s a p p l i c a b l e ...
# 719   s e c t i o n 3 r u l e s a p p l i c a b l e ...
# 969   his or her shall lodge such an action within t...
# 987   the commission may establish financial framewo...
# 1025  the decision to register information concernin...
# 1684  contributions as well as appropriations set as...
# 1684  contributions as well as appropriations set as...
# 1893  administrative appropriations shall be nondiff...
# 1897  administrative expenditure arising from contra...
# 1989        paragraph 8 is replaced by the following: 8
# 2007      paragraph 10 is replaced by the following: 10
# 2096  article 59 is amended as follows: the followin...
# 2109        paragraph 8 is replaced by the following: 8
# 2112      paragraph 11 is replaced by the following: 11
# 2189  article 114 is amended as follows: paragraph 1...
# 2193                             paragraph 4 is deleted
# 2193                             paragraph 4 is deleted
# 2196        paragraph 3 is replaced by the following: 3
# 2315  cef blending facilities shall be implemented i...
# 2315  cef blending facilities shall be implemented i...
# 2315  cef blending facilities shall be implemented i...
#
#                                    coreference_sentence triplets_clean_sent
# 12    land, buildings or other immovable property do...                  []
# 12    land, buildings or other immovable property do...                  []
# 46    ‘low value grant’ means a grant lower than or ...                  []
# 51    ‘output’ means the deliverables generated by t...                  []
# 88    commitment appropriations shall cover the tota...                  []
# 106   appropriations which have not been used by the...                  []
# 106   appropriations which have not been used by the...                  []
# 184   appropriations referred to in point (c) of the...                  []
# 689   s e c t i o n 2 r u l e s a p p l i c a b l e ...                  []
# 719   s e c t i o n 3 r u l e s a p p l i c a b l e ...                  []
# 719   s e c t i o n 3 r u l e s a p p l i c a b l e ...                  []
# 719   s e c t i o n 3 r u l e s a p p l i c a b l e ...                  []
# 969   his or her shall lodge such an action within t...                  []
# 987   the commission may establish financial framewo...                  []
# 1025  the decision to register information concernin...                  []
# 1684  contributions, as well as appropriations set a...                  []
# 1684  contributions, as well as appropriations set a...                  []
# 1893  administrative appropriations shall be non-dif...                  []
# 1897  administrative expenditure arising from contra...                  []
# 1989  ’; (c) paragraph 8 is replaced by the followin...                  []
# 2007  ’; (f) paragraph 10 is replaced by the followi...                  []
# 2096  article 59 is amended as follows: (a) the foll...                  []
# 2109  ’; (e) paragraph 8 is replaced by the followin...                  []
# 2112  ’; (b) paragraph 11 is replaced by the followi...                  []
# 2189  article 114 is amended as follows: (a) paragra...                  []
# 2193                     ’; (b) paragraph 4 is deleted;                  []
# 2193                     ’; (b) paragraph 4 is deleted;                  []
# 2196  ’; (c) paragraph 3 is replaced by the followin...                  []
# 2315  cef blending facilities shall be implemented i...                  []
# 2315  cef blending facilities shall be implemented i...                  []
# 2315  cef blending facilities shall be implemented i...                  []

# %%
def triplet_tuple(triplet_dictionary):
    if not triplet_dictionary:  # Check if the list is empty
        return None  # Return a tuple of Nones or handle as desired
    return (triplet_dictionary[0]["head"], triplet_dictionary[0]["type"], triplet_dictionary[0]["tail"])

# %%
rebel_triplets_exploded['Triplet'] = rebel_triplets_exploded['triplets_clean_sent'].apply(triplet_tuple)

# %%
rebel_triplets_exploded["Head"] = rebel_triplets_exploded["Triplet"].apply(lambda x: x[0].strip() if x is not None else None)
rebel_triplets_exploded["Relation"] = rebel_triplets_exploded["Triplet"].apply(lambda x: x[1].strip() if x is not None else None)
rebel_triplets_exploded["Tail"] = rebel_triplets_exploded["Triplet"].apply(lambda x: x[2].strip() if x is not None else None)

# %%
rebel_triplets_exploded.head()
# Out:
#                                                Title  \
# 0  TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 0  TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 0  TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 1  TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 1  TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
#
#                      Articles  \
# 0  Article 1  Subject matter
# 0  Article 1  Subject matter
# 0  Article 1  Subject matter
# 1     Article 2  Definitions
# 1     Article 2  Definitions
#
#                               coreference_list_ready  \
# 0  this regulation lays down the rules for the es...
# 0  this regulation lays down the rules for the es...
# 0  this regulation lays down the rules for the es...
# 1  ‘applicant’ means a natural person or an entit...
# 1  ‘applicant’ means a natural person or an entit...
#
#                          coreference_paragraph_clean  \
# 0  this regulation lays down the rules for the es...
# 0  this regulation lays down the rules for the es...
# 0  this regulation lays down the rules for the es...
# 1  applicant means a natural person or an entity ...
# 1  applicant means a natural person or an entity ...
#
#                           coreference_sentence_clean  \
# 0  this regulation lays down the rules for the es...
# 0  this regulation lays down the rules for the es...
# 0  this regulation lays down the rules for the es...
# 1  applicant means a natural person or an entity ...
# 1  applicant means a natural person or an entity ...
#
#                                 coreference_sentence  \
# 0  this regulation lays down the rules for the es...
# 0  this regulation lays down the rules for the es...
# 0  this regulation lays down the rules for the es...
# 1  ‘applicant’ means a natural person or an entit...
# 1  ‘applicant’ means a natural person or an entit...
#
#                                  triplets_clean_sent  \
# 0  [{'head': 'european atomic energy community', ...
# 0  [{'head': 'european atomic energy community', ...
# 0  [{'head': 'european atomic energy community', ...
# 1  [{'head': 'natural person', 'type': 'subclass ...
# 1  [{'head': 'natural person', 'type': 'subclass ...
#
#                                              Triplet  \
# 0  (european atomic energy community, part of, eu...
# 0  (european atomic energy community, parent orga...
# 0  (european atomic energy community, country, eu...
# 1              (natural person, subclass of, entity)
# 1              (natural person, subclass of, entity)
#
#                                Head             Relation            Tail
# 0  european atomic energy community              part of  european union
# 0  european atomic energy community  parent organization  european union
# 0  european atomic energy community              country  european union
# 1                    natural person          subclass of          entity
# 1                    natural person          subclass of          entity

# %% [markdown]
# # Preprocess the Dataframe
# * Check for NA values
# * Lowercase, Remove Punctuation, Stopwords and Lemmatize
# * Remove Noise from Text such as \n sumbols and unncessary spaces

# %%
rebel_triplets_exploded.isna().sum()
# Out:
# Title                           0
# Articles                        0
# coreference_list_ready          0
# coreference_paragraph_clean     0
# coreference_sentence_clean      0
# coreference_sentence            0
# triplets_clean_sent             0
# Triplet                        31
# Head                           31
# Relation                       31
# Tail                           31
# dtype: int64

# %%
rebel_triplets_exploded = rebel_triplets_exploded.dropna()

# %%
# Remove stopwords, punctuation from heads 
nlp = spacy.load("en_core_web_sm")
lemmatizer = nlp.get_pipe("lemmatizer")


stop_words = spacy.lang.en.stop_words.STOP_WORDS 
stopwords = list(stop_words)
punctuation = '!@#$%^&*_-+={}[];"\'|<>,?/~`’‘()'



def lemmatize(text):
    doc = nlp(text)
    return " ".join([token.lemma_ for token in doc])

def tokens(text):
    doc = nlp(text)
    tokens = []
    for token in doc:
        tokens.append(token)
    return tokens

def remove_punct(text):
    tokens_list = tokens(text)
    new_list = []
    for token in tokens_list:
        new_token = ""
        for letter in token.text:
            if letter not in punctuation:
                new_token = new_token + letter
        new_list.append(new_token)
    return new_list

def remove_punct_text(text):
    tokens_list = tokens(text)
    new_list = []
    for token in tokens_list:
        new_token = ""
        for letter in token.text:
            if letter not in punctuation:
                new_token = new_token + letter
        new_list.append(new_token)
    return " ".join(new_list)

def remove_stopwords(text):
    text_tokens = remove_punct(text.lower())
    new_text = " "
    for token in text_tokens:
        if token not in stopwords:
               new_text = new_text + ' ' + str(token)
    return lemmatize(new_text).strip()

def remove_stopwords_no_lemma(text):
    text_tokens = remove_punct(text)
    new_text = " "
    for token in text_tokens:
        if token not in stopwords:
               new_text = new_text + ' ' + str(token)
    return new_text.strip()

# %%
# Identify entities that are numbers and keep rows that do not have head or tail that are numbers

rebel_triplets_exploded['Head_is_Number'] = rebel_triplets_exploded["Head"].apply(lambda x: x.isdigit())
rebel_triplets_exploded['Tail_is_Number'] = rebel_triplets_exploded["Tail"].apply(lambda x: x.isdigit())

rebel_triplets_exploded = rebel_triplets_exploded[(rebel_triplets_exploded["Tail_is_Number"]==False) & (rebel_triplets_exploded["Head_is_Number"]==False)]

# %%
# Lowercase and remove stopwords

rebel_triplets_exploded['Head'] = rebel_triplets_exploded["Head"].apply(remove_stopwords)
rebel_triplets_exploded['Tail'] = rebel_triplets_exploded["Tail"].apply(remove_stopwords)

# %%
pattern = '\n'
rebel_triplets_exploded['Title'] = rebel_triplets_exploded['Title'].apply(lambda x: re.sub(pattern, '', x).strip())

rebel_triplets_exploded["Articles"] = rebel_triplets_exploded["Articles"].apply(lambda x: x.strip())

# %%
rebel_triplets_exploded['Title'].unique()
# Out:
# array(['TITLE I SUBJECT MATTER, DEFINITIONS AND GENERAL PRINCIPLES',
#        'TITLE II BUDGET AND BUDGETARY PRINCIPLES',
#        'TITLE III ESTABLISHMENT AND STRUCTURE OF THE BUDGET',
#        'TITLE IV BUDGET IMPLEMENTATION', 'TITLE V COMMON RULES',
#        'TITLE VI INDIRECT MANAGEMENT',
#        'TITLE VII PROCUREMENT AND CONCESSIONS', 'TITLE VIII GRANTS',
#        'TITLE IX PRIZES',
#        'TITLE X FINANCIAL INSTRUMENTS, BUDGETARY GUARANTEES AND FINANCIAL ASSISTANCE',
#        'TITLE XI CONTRIBUTIONS TO EUROPEAN POLITICAL PARTIES',
#        'TITLE XII OTHER BUDGET IMPLEMENTATION INSTRUMENTS',
#        'TITLE XIII ANNUAL ACCOUNTS AND OTHER FINANCIAL REPORTING',
#        'TITLE XIV EXTERNAL AUDIT AND DISCHARGE',
#        'TITLE XV ADMINISTRATIVE APPROPRIATIONS',
#        'TITLE XVI INFORMATION REQUESTS AND DELEGATED ACTS'], dtype=object)

# %%
rebel_triplets_exploded.reset_index(inplace=True, drop=True)

# %%
rebel_triplets_exploded.shape
# Out:
# (6516, 13)

# %%
rebel_triplets_exploded.isna().sum()
# Out:
# Title                          0
# Articles                       0
# coreference_list_ready         0
# coreference_paragraph_clean    0
# coreference_sentence_clean     0
# coreference_sentence           0
# triplets_clean_sent            0
# Triplet                        0
# Head                           0
# Relation                       0
# Tail                           0
# Head_is_Number                 0
# Tail_is_Number                 0
# dtype: int64

# %% [markdown]
# # Get Original The original Content of each Article and Merge with the Rebel Dataframe

# %%
original_text = pd.read_csv(r'C:\Users\Student\Desktop\Thesis-Coding\Thesis\final_dataframe.csv')

original_text['Content'] = convert_to_list(original_text['Content'])

original_text["Articles"] = original_text["Articles"].apply(lambda x: x.strip())

original_text = original_text[["Articles","Content"]]

# %%
def get_content(con_list):
    con_text = "".join(con_list).strip()
    con_text = re.sub('\n', '', "".join(con_text))
    con_text = re.sub('  ', ' ', con_text)

    return con_text

def denoise_paragraph(paragraph):
    para_text = re.sub('\n', '', paragraph.strip())
    
    return para_text
    
original_text["Content_Text"] = original_text["Content"].apply(get_content)

original_text = original_text.explode("Content")

original_text["Paragraph_Text"] = original_text["Content"].apply(denoise_paragraph)

original_text = original_text[["Articles","Content_Text","Paragraph_Text"]]

# %%
original_text
# Out:
#                                           Articles  \
# 0                        Article 1  Subject matter
# 1                           Article 2  Definitions
# 1                           Article 2  Definitions
# 1                           Article 2  Definitions
# 1                           Article 2  Definitions
# ..                                             ...
# 280                            Article 281  Repeal
# 280                            Article 281  Repeal
# 281  Article 282  Entry into force and application
# 281  Article 282  Entry into force and application
# 281  Article 282  Entry into force and application
#
#                                           Content_Text  \
# 0    This Regulation lays down the rules for the es...
# 1    ‘applicant’ means a natural person or an entit...
# 1    ‘applicant’ means a natural person or an entit...
# 1    ‘applicant’ means a natural person or an entit...
# 1    ‘applicant’ means a natural person or an entit...
# ..                                                 ...
# 280  Regulation (EU, Euratom) No 966/2012 is repeal...
# 280  Regulation (EU, Euratom) No 966/2012 is repeal...
# 281  This Regulation shall enter into force on the ...
# 281  This Regulation shall enter into force on the ...
# 281  This Regulation shall enter into force on the ...
#
#                                         Paragraph_Text
# 0    This Regulation lays down the rules for the es...
# 1    ‘applicant’ means a natural person or an entit...
# 1    ‘application document’ means a tender, a reque...
# 1    ‘award procedure’ means a procurement procedur...
# 1    ‘basic act’ means a legal act, other than a re...
# ..                                                 ...
# 280  Without prejudice to Article 279(3), the Commi...
# 280  References to the repealed Regulation shall be...
# 281  This Regulation shall enter into force on the ...
# 281                 It shall apply from 2 August 2018.
# 281  By way of derogation from paragraph 2 of this ...
#
# [1104 rows x 3 columns]

# %%
# Dictionary {Article:Content}

article_content = original_text[["Articles","Content_Text"]]

article_content.drop_duplicates(["Articles","Content_Text"], inplace=True, ignore_index=True)
# Out:
# C:\Users\Student\AppData\Local\Temp\ipykernel_6600\4016803028.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   article_content.drop_duplicates(["Articles","Content_Text"], inplace=True, ignore_index=True)

# %%
article_content
# Out:
#                                               Articles  \
# 0                            Article 1  Subject matter
# 1                               Article 2  Definitions
# 2    Article 3  Compliance of secondary legislation...
# 3            Article 4  Periods, dates and time limits
# 4               Article 5  Protection of personal data
# ..                                                 ...
# 277  Article 278  Amendment to Decision No 541/2014/EU
# 278               Article 279  Transitional provisions
# 279                                Article 280  Review
# 280                                Article 281  Repeal
# 281      Article 282  Entry into force and application
#
#                                           Content_Text
# 0    This Regulation lays down the rules for the es...
# 1    ‘applicant’ means a natural person or an entit...
# 2    Provisions concerning the implementation of th...
# 3    Unless otherwise provided in this Regulation, ...
# 4    This Regulation is without prejudice to Regula...
# ..                                                 ...
# 277  In Article 4 of Decision No 541/2014/EU of the...
# 278  Legal commitments for grants implementing the ...
# 279  This Regulation shall be reviewed whenever it ...
# 280  Regulation (EU, Euratom) No 966/2012 is repeal...
# 281  This Regulation shall enter into force on the ...
#
# [282 rows x 2 columns]

# %%
rebel_triplets_exploded = pd.merge(rebel_triplets_exploded, article_content, on='Articles', how='left')

# %%
rebel_triplets_exploded.shape
# Out:
# (6516, 14)

# %%
rebel_triplets_exploded.head()
# Out:
#                                                Title  \
# 0  TITLE I SUBJECT MATTER, DEFINITIONS AND GENERA...
# 1  TITLE I SUBJECT MATTER, DEFINITIONS AND GENERA...
# 2  TITLE I SUBJECT MATTER, DEFINITIONS AND GENERA...
# 3  TITLE I SUBJECT MATTER, DEFINITIONS AND GENERA...
# 4  TITLE I SUBJECT MATTER, DEFINITIONS AND GENERA...
#
#                      Article  \
# 0  Article 1  Subject matter
# 1  Article 1  Subject matter
# 2  Article 1  Subject matter
# 3     Article 2  Definitions
# 4     Article 2  Definitions
#
#                               Paragraph_Coreferenced  \
# 0  this regulation lays down the rules for the es...
# 1  this regulation lays down the rules for the es...
# 2  this regulation lays down the rules for the es...
# 3  ‘applicant’ means a natural person or an entit...
# 4  ‘applicant’ means a natural person or an entit...
#
#                          coreference_paragraph_clean  \
# 0  this regulation lays down the rules for the es...
# 1  this regulation lays down the rules for the es...
# 2  this regulation lays down the rules for the es...
# 3  applicant means a natural person or an entity ...
# 4  applicant means a natural person or an entity ...
#
#                           coreference_sentence_clean  \
# 0  this regulation lays down the rules for the es...
# 1  this regulation lays down the rules for the es...
# 2  this regulation lays down the rules for the es...
# 3  applicant means a natural person or an entity ...
# 4  applicant means a natural person or an entity ...
#
#                                Sentence_Coreferenced  \
# 0  this regulation lays down the rules for the es...
# 1  this regulation lays down the rules for the es...
# 2  this regulation lays down the rules for the es...
# 3  ‘applicant’ means a natural person or an entit...
# 4  ‘applicant’ means a natural person or an entit...
#
#                                  triplets_clean_sent  \
# 0  [{'head': 'european atomic energy community', ...
# 1  [{'head': 'european atomic energy community', ...
# 2  [{'head': 'european atomic energy community', ...
# 3  [{'head': 'natural person', 'type': 'subclass ...
# 4  [{'head': 'natural person', 'type': 'subclass ...
#
#                                              Triplet  \
# 0  (european atomic energy community, part of, eu...
# 1  (european atomic energy community, parent orga...
# 2  (european atomic energy community, country, eu...
# 3              (natural person, subclass of, entity)
# 4              (natural person, subclass of, entity)
#
#                                Head             Relation            Tail  \
# 0  european atomic energy community              part of  european union
# 1  european atomic energy community  parent organization  european union
# 2  european atomic energy community              country  european union
# 3                    natural person          subclass of          entity
# 4                    natural person          subclass of          entity
#
#    Head_is_Number  Tail_is_Number  \
# 0           False           False
# 1           False           False
# 2           False           False
# 3           False           False
# 4           False           False
#
#                                      Article_Content
# 0  This Regulation lays down the rules for the es...
# 1  This Regulation lays down the rules for the es...
# 2  This Regulation lays down the rules for the es...
# 3  ‘applicant’ means a natural person or an entit...
# 4  ‘applicant’ means a natural person or an entit...

# %%
# Change Names

rebel_triplets_exploded.rename(columns={'coreference_list_ready': 'Paragraph_Coreferenced', 
                                        'coreference_sentence': 'Sentence_Coreferenced',
                                        "Content_Text": "Article_Content",
                                        "Articles":"Article"}, inplace=True)

# %% [markdown]
# # Save Rebel Triplets for Each Title

# %%
output_folder = r'C:\Users\Student\Desktop\Thesis-Coding\Thesis\REBEL_triplets_per_title'
numbers_list = ["I","II","III","IV","V","VI","VII","VIII","IX","X","XI",
                "XII","XIII","XIV","XV","XVI"]
title_list = rebel_triplets_exploded['Title'].unique().tolist()

for title, number in zip(title_list, numbers_list):

    rebel_subset = rebel_triplets_exploded[rebel_triplets_exploded["Title"]==title]

    rebel_subset = rebel_subset[rebel_subset['Head'] != rebel_subset['Tail']]

    rebel_subset.drop_duplicates(["Head","Relation","Tail"], inplace=True, ignore_index=True)

    rebel_subset = rebel_subset[["Head","Relation","Tail","Title","Article","Paragraph_Coreferenced",
                                 "Sentence_Coreferenced","Article_Content"]]

    filename = "rebel_triplets_" + str(number) + ".csv"

    output_file_path = os.path.join(output_folder, filename)
    rebel_subset.to_csv(output_file_path, index=False)

# %% [markdown]
# # Save Rebel Triplets for All Titles Together

# %%
rebel_triplets_all = rebel_triplets_exploded[rebel_triplets_exploded['Head'] != rebel_triplets_exploded['Tail']]

rebel_triplets_all.drop_duplicates(["Head","Relation","Tail"], inplace=True, ignore_index=True)

rebel_triplets_all = rebel_triplets_all[["Head","Relation","Tail","Title","Article","Paragraph_Coreferenced",
                                 "Sentence_Coreferenced","Article_Content"]]
# Out:
# C:\Users\Student\AppData\Local\Temp\ipykernel_6600\3964410756.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rebel_triplets_all.drop_duplicates(["Head","Relation","Tail"], inplace=True, ignore_index=True)

# %%
rebel_triplets_all.to_csv(r'C:\Users\Student\Desktop\Thesis-Coding\Thesis\REBEL_triplets_per_title\REBEL_triplets_ALL_titles.csv', index=False)

# %%
# !pip install matplotx[all]

# %% [markdown]
# # Define Visual Exploration Class

# %%
class triplets_vis:
    def __init__(self, dataframe, title):
        self.title = title
        self.dataframe = dataframe

        self.unique_relation_per_title = self.dataframe.groupby("Title")[["Relation"]].nunique()
        self.unique_heads_per_title = self.dataframe.groupby("Title")[["Head"]].nunique()
        self.unique_tails_per_title = self.dataframe.groupby("Title")[["Tail"]].nunique()

        self.relations_freq = self.dataframe[self.dataframe["Title"]==self.title].groupby(["Relation"])["Relation"].count().reset_index(name='count').sort_values(by=('count'), ascending=False)
        self.relations_freq['Relative Freq'] = self.relations_freq['count'] / self.relations_freq['count'].sum()
        self.relations_freq = self.relations_freq.rename(columns={"relation": "Relation", "count": "Frequency"})
        self.relations_freq = self.relations_freq.reset_index(drop=True)

        transformer = StandardScaler()
        transformer_scaler = MaxAbsScaler()
        self.relations_freq['Standardized_Frequency'] = transformer.fit_transform(self.relations_freq[['Frequency']]).flatten()
        self.relations_freq['Scaled_Max_Frequency'] = transformer_scaler.fit_transform(self.relations_freq[['Frequency']]).flatten()

        self.relations_freq['Cumulative Frequency'] = self.relations_freq['Frequency'].cumsum()
        self.relations_freq['Relative Cumulative Frequency'] = self.relations_freq['Relative Freq'].cumsum()

    def na_bar_plot(self):
        
        na_values = self.dataframe[self.dataframe["Title"]==self.title][["Head","Relation","Tail"]].isna().sum().to_frame().reset_index()
        na_values = na_values.rename(columns={"index": "Triplet", 0: "Frequency"})
        plt.style.use(matplotx.styles.dracula)
        fig, ax = plt.subplots()

        ax.bar(na_values['Triplet'],na_values['Frequency'])

        ax.set_ylabel('NA Values')
        ax.set_xlabel('Triplet Part')
        ax.set_title('Frequency of NA Values')

        plt.show()

    def na_table(self):

        na_values = self.dataframe[self.dataframe["Title"]==self.title][["Head","Relation","Tail"]].isna().sum().to_frame().reset_index()
        na_values = na_values.rename(columns={"index": "Triplet", 0: "Frequency"})

        return na_values
    
    def freq_bar_plot(self, border):

        plt.style.use(matplotx.styles.dracula)
        fig, ax = plt.subplots()


        ax.barh(self.relations_freq[self.relations_freq['Frequency'] > border]['Relation'], self.relations_freq[self.relations_freq['Frequency'] > border]['Frequency'])
        ax.invert_yaxis()
        ax.set_ylabel('Relation')
        ax.set_xlabel('Frequency')
        ax.set_title("Relation' Frequencies")

        plt.tight_layout()
        # ax.tick_params(axis='y', labelsize=8)

        plt.show()


        plt.style.use(matplotx.styles.dracula)


    def cumulative_freq_plot(self, border):

        fig, ax = plt.subplots()


        ax.plot(self.relations_freq[self.relations_freq['Frequency'] > border]['Relation'], self.relations_freq[self.relations_freq['Frequency'] > border]['Relative Cumulative Frequency'])

        ax.fill_between(
            self.relations_freq[self.relations_freq['Frequency'] > border]['Relation'], 
            self.relations_freq[self.relations_freq['Frequency'] > border]['Relative Cumulative Frequency'], 
            color='skyblue', alpha=0.4
        )


        # ax.invert_yaxis()
        ax.set_ylabel('Cumulative Frequency')
        ax.set_xlabel('Relation')
        ax.set_title('Relations Frequencies')

        plt.xticks(rotation=90)
        plt.tight_layout()
        # ax.tick_params(axis='y', labelsize=8)

        plt.show()

    def relations_type_freq_plot(self):

        plt.style.use(matplotx.styles.dracula)
        fig, ax = plt.subplots()

        bins = np.sort(self.relations_freq['Frequency'].unique())

        ax.hist(self.relations_freq['Frequency'], density=True, bins=bins)

        ax.set_xticks(bins)
        ax.set_xticklabels(bins ,ha='center')

        ax.set_ylabel('Percentage of Relations with Given Frequency')
        ax.set_xlabel('Frequency of Given Relation')
        ax.set_title('Frequency of Relations Based on Type')
        
        plt.show()

# %% [markdown]
# # Assign Classes for Budget Related Titles (II,III,IV)

# %% [markdown]
# ## Explore Entities and Relations

# %%
rebel_III = pd.read_csv(r'C:\Users\Student\Desktop\Thesis-Coding\Thesis\REBEL_triplets_per_title\rebel_triplets_III.csv')

# %%
rebel_III["Title"].unique()
# Out:
# array(['TITLE III ESTABLISHMENT AND STRUCTURE OF THE BUDGET'],
#       dtype=object)

# %%
visualization = triplets_vis(rebel_III,'TITLE III ESTABLISHMENT AND STRUCTURE OF THE BUDGET')

# %%
visualization.freq_bar_plot(0)

# %%
visualization.relations_freq
# Out:
#                                    Relation  Frequency  Relative Freq  \
# 0                               subclass of         50       0.344828
# 1                                   part of         31       0.213793
# 2                                  has part         22       0.151724
# 3                               instance of         10       0.068966
# 4                                  facet of          7       0.048276
# 5                   applies to jurisdiction          5       0.034483
# 6                               followed by          4       0.027586
# 7                            different from          4       0.027586
# 8                             legislated by          2       0.013793
# 9                               opposite of          2       0.013793
# 10                               subsidiary          2       0.013793
# 11                                  follows          1       0.006897
# 12                   has parts of the class          1       0.006897
# 13                                  country          1       0.006897
# 14                         legislative body          1       0.006897
# 15  office held by head of the organization          1       0.006897
# 16                              participant          1       0.006897
#
#     Standardized_Frequency  Scaled_Max_Frequency  Cumulative Frequency  \
# 0                 3.157659                  1.00                    50
# 1                 1.710959                  0.62                    81
# 2                 1.025679                  0.44                   103
# 3                 0.111974                  0.20                   113
# 4                -0.116453                  0.14                   120
# 5                -0.268737                  0.10                   125
# 6                -0.344879                  0.08                   129
# 7                -0.344879                  0.08                   133
# 8                -0.497163                  0.04                   135
# 9                -0.497163                  0.04                   137
# 10               -0.497163                  0.04                   139
# 11               -0.573305                  0.02                   140
# 12               -0.573305                  0.02                   141
# 13               -0.573305                  0.02                   142
# 14               -0.573305                  0.02                   143
# 15               -0.573305                  0.02                   144
# 16               -0.573305                  0.02                   145
#
#     Relative Cumulative Frequency
# 0                        0.344828
# 1                        0.558621
# 2                        0.710345
# 3                        0.779310
# 4                        0.827586
# 5                        0.862069
# 6                        0.889655
# 7                        0.917241
# 8                        0.931034
# 9                        0.944828
# 10                       0.958621
# 11                       0.965517
# 12                       0.972414
# 13                       0.979310
# 14                       0.986207
# 15                       0.993103
# 16                       1.000000

# %%
rebel_III["Head"].unique()
# Out:
# array(['european parliament', 'humanitarian aid crisis response',
#        'humanitarian aid', 'crisis response', 'council estimate',
#        'parliament', 'draft budget', 'revenue', 'budget', 'union',
#        'union institution', 'appropriation', 'budget line', 'point 30',
#        'fund', 'commission administration', 'financial instrument',
#        'publicprivate partnership', 'equity', 'management fee',
#        'operating charge', 'financial operating charge',
#        'discharge procedure', 'annual discharge procedure',
#        'union basic act', 'trade union', 'union trust fund',
#        'court justice', 'competition law', 'woman', 'country', 'post',
#        'agriculture', 'expenditure estimate',
#        'expenditure estimate agriculture', 'euratom treaty',
#        'member state', 'economic forecast',
#        'european union solidarity fund', 'solidarity fund', 'draft',
#        'previous', 'precede', 'european', 'article 314 tfeu', 'tfeu',
#        'chapter 2', 'european council', 'programme',
#        'administrative appropriation', 'operational appropriation',
#        'chapter', 'pro memoria', 'article 31', 'establishment plan',
#        'administrative expenditure', 'commission', 'commission type',
#        'net amount', 'provision title', 'transfer', 'basic act',
#        'financial year', 'negative reserve', 'euro', 'payment',
#        'emergency aid', 'international monetary fund', 'reserve',
#        'precede year', 'previous year', 'euratom', 'financial assistance',
#        'leverage', 'leverage effect', 'debt management', 'parttime',
#        'union act'], dtype=object)

# %%
rebel_III["Tail"].unique()
# Out:
# array(['council', 'humanitarian aid', 'humanitarian aid crisis response',
#        'councilthe council', 'national parliament', 'budget',
#        'expenditure', 'revenue', 'institution', 'union',
#        'union institution', 'appropriation', 'policy area',
#        'expenditure policy area', 'interinstitutional agreement',
#        'budgetary procedure', 'instrument', 'work document', 'debt',
#        'administrative expenditure', 'discharge', 'annual discharge',
#        'table information', 'table', 'union basic act', 'trust fund',
#        'draft budget', 'gender', 'geographic area', 'personnel',
#        'letter amendment', 'european parliament', 'president',
#        'member state', 'forecast', 'forecast resource',
#        'expenditure drive', 'european union', 'amend', 'estimate',
#        'amend budget', 'current financial year', 'parliament', 'tfeu',
#        'euratom treaty', 'chapter 2', 'council council', 'activity',
#        'operational appropriation', 'administrative appropriation',
#        'token entry', 'token', 'procedure',
#        'multiannual financial framework', 'commission', 'remuneration',
#        'provision', 'budget line', 'basic act', 'eur', 'payment',
#        'world bank', 'transfer', 'emergency aid', 'financial year',
#        'precede year', 'supply agency', 'budgetary guarantee',
#        'capital operation', 'financial instrument', 'body',
#        'council union institution', 'work', 'salary', 'act'], dtype=object)

# %% [markdown]
# ## Define the Categories-Classes based on the Budget Use Case - Create Dictionary

# %%
categories = ["European_Union","Budget","Appropriations","Fund","Appropriations",
              "Action","Work_Documents_Section","Tool","Legal_Entity","Financial Tool","Concept",
              "Person"]

# %%
class_entity = {"European_Union":[""]}
