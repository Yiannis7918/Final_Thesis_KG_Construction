# %%
import pandas as pd
import ast
import spacy
import re
import numpy as np

# %%
#Load title I 

# Load triplets dataframe 
triplets_I= pd.read_csv(r'rule_based_per_chapter_use_cases\rule_triplets_I.csv')

# %%
triplets_I
# Out:
#                     Head Relation                   Tail  \
# 0              applicant     mean  grant award procedure
# 1   application document     mean      grant application
# 2        award procedure     mean            article 621
# 3              basic act     mean         european union
# 4            beneficiary     mean        grant agreement
# ..                   ...      ...                    ...
# 61                 union     mean         european union
# 62     union institution     mean         european union
# 63                vendor     mean      economic operator
# 64             volunteer     mean    noncompulsory basis
# 65         work contract     mean  contracting authority
#
#                                         Original Tail  \
# 0   a natural person or an entity with or without ...
# 1   a tender a request to participate a grant appl...
# 2   a procurement procedure a grant award procedur...
# 3   a legal act other than a recommendation or an ...
# 4   a natural person or an entity with or without ...
# ..                                                ...
# 61  the european union the european atomic energy ...
# 62  the european parliament the european council t...
# 63  an economic operator registered in a list of v...
# 64  a person working on a noncompulsory basis for ...
# 65  a contract covering either: the execution or b...
#
#                                      Tail Noun Chunks  \
# 0   ['natural person', 'entity', 'legal personalit...
# 1   ['tender', 'request', 'grant application', 'ap...
# 2   ['procurement procedure', 'grant award procedu...
# 3   ['legal act', 'recommendation', 'opinion', '',...
# 4   ['natural person', 'entity', 'legal personalit...
# ..                                                ...
# 61  ['european union', 'european atomic energy com...
# 62  ['european parliament', 'european council', 'c...
# 63  ['economic operator', 'list', 'vendors', 'requ...
# 64  ['person', 'noncompulsory basis', 'organisation']
# 65  ['contract', 'execution', 'execution', 'design...
#
#                                                 Title  \
# 0   TITLE I SUBJECT MATTER, DEFINITIONS AND GENERA...
# 1   TITLE I SUBJECT MATTER, DEFINITIONS AND GENERA...
# 2   TITLE I SUBJECT MATTER, DEFINITIONS AND GENERA...
# 3   TITLE I SUBJECT MATTER, DEFINITIONS AND GENERA...
# 4   TITLE I SUBJECT MATTER, DEFINITIONS AND GENERA...
# ..                                                ...
# 61  TITLE I SUBJECT MATTER, DEFINITIONS AND GENERA...
# 62  TITLE I SUBJECT MATTER, DEFINITIONS AND GENERA...
# 63  TITLE I SUBJECT MATTER, DEFINITIONS AND GENERA...
# 64  TITLE I SUBJECT MATTER, DEFINITIONS AND GENERA...
# 65  TITLE I SUBJECT MATTER, DEFINITIONS AND GENERA...
#
#                     Article  \
# 0   Article 2  Definitions
# 1   Article 2  Definitions
# 2   Article 2  Definitions
# 3   Article 2  Definitions
# 4   Article 2  Definitions
# ..                      ...
# 61  Article 2  Definitions
# 62  Article 2  Definitions
# 63  Article 2  Definitions
# 64  Article 2  Definitions
# 65  Article 2  Definitions
#
#                                 Original Article Text  \
# 0   [' ‘applicant’ means a natural person or an en...
# 1   [' ‘applicant’ means a natural person or an en...
# 2   [' ‘applicant’ means a natural person or an en...
# 3   [' ‘applicant’ means a natural person or an en...
# 4   [' ‘applicant’ means a natural person or an en...
# ..                                                ...
# 61  [' ‘applicant’ means a natural person or an en...
# 62  [' ‘applicant’ means a natural person or an en...
# 63  [' ‘applicant’ means a natural person or an en...
# 64  [' ‘applicant’ means a natural person or an en...
# 65  [' ‘applicant’ means a natural person or an en...
#
#                                   Clean Original Tail  \
# 0   a natural person or an entity with or without ...
# 1   a tender a request to participate a grant appl...
# 2   a procurement procedure a grant award procedur...
# 3   a legal act other than a recommendation or an ...
# 4   a natural person or an entity with or without ...
# ..                                                ...
# 61  the european union the european atomic energy ...
# 62  the european parliament the european council t...
# 63  an economic operator registered in a list of v...
# 64  a person working on a noncompulsory basis for ...
# 65  a contract covering either : the execution or ...
#
#                                     Tail First Tokens
# 0               a natural person or an entity with or
# 1           a tender a request to participate a grant
# 2   a procurement procedure a grant award procedure a
# 3          a legal act other than a recommendation or
# 4               a natural person or an entity with or
# ..                                                ...
# 61  the european union the european atomic energy ...
# 62  the european parliament the european council t...
# 63       an economic operator registered in a list of
# 64      a person working on a noncompulsory basis for
# 65      a contract covering either : the execution or
#
# [66 rows x 10 columns]

# %%
def convert_to_list(column):
    return column.apply(ast.literal_eval)

triplets_df_nostop['Content'] = convert_to_list(triplets_df_nostop['Content'])
triplets_df_nostop['triplets_list'] = convert_to_list(triplets_df_nostop['triplets_list'])
