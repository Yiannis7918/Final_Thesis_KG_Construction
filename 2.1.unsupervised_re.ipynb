# %% [markdown]
# ## Import final_dataframe.csv and packages
#
# THE claucy package had to be installed from https://github.com/mmxgn/spacy-clausie and is based on the paper of ClausIE

# %%
import pandas as pd
import ast
import spacy
import re
import claucy

# %%
# The previously content and cleaned content columns, contained lists, but due to csv format, they had become strings
# Thus, they are converted back to lists 

final_dataframe = pd.read_csv('final_dataframe.csv')

def convert_to_list(column):
    return column.apply(ast.literal_eval)

final_dataframe['Content'] = convert_to_list(final_dataframe['Content'])
final_dataframe['Cleaned_Content'] = convert_to_list(final_dataframe['Cleaned_Content'])

# %%
final_dataframe
# Out:
#                                                  Title  \
# 0    TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 1    TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 2    TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 3    TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 4    TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# ..                                                 ...
# 277  TITLE XVI \nINFORMATION REQUESTS AND DELEGATED...
# 278  TITLE XVI \nINFORMATION REQUESTS AND DELEGATED...
# 279  TITLE XVI \nINFORMATION REQUESTS AND DELEGATED...
# 280  TITLE XVI \nINFORMATION REQUESTS AND DELEGATED...
# 281  TITLE XVI \nINFORMATION REQUESTS AND DELEGATED...
#
#                                               Articles  \
# 0                           Article 1  Subject matter
# 1                              Article 2  Definitions
# 2    Article 3  Compliance of secondary legislation...
# 3           Article 4  Periods, dates and time limits
# 4              Article 5  Protection of personal data
# ..                                                 ...
# 277  Article 278  Amendment to Decision No 541/2014...
# 278              Article 279  Transitional provisions
# 279                               Article 280  Review
# 280                               Article 281  Repeal
# 281     Article 282  Entry into force and application
#
#                                                Content  \
# 0    [\nThis Regulation lays down the rules for the...
# 1    [ ‘applicant’ means a natural person or an ent...
# 2    [ \nProvisions concerning the implementation o...
# 3    [\nUnless otherwise provided in this Regulatio...
# 4    [\nThis Regulation is without prejudice to Reg...
# ..                                                 ...
# 277  [\nIn Article 4 of Decision No 541/2014/EU of ...
# 278  [ \nLegal commitments for grants implementing ...
# 279  [\nThis Regulation shall be reviewed whenever ...
# 280  [ \nRegulation (EU, Euratom) No 966/2012 is re...
# 281  [ \nThis Regulation shall enter into force on ...
#
#                                        Cleaned_Content
# 0    [this regulation lays down the rules for the e...
# 1    [‘applicant’ means a natural person or an enti...
# 2    [provisions concerning the implementation of t...
# 3    [unless otherwise provided in this regulation,...
# 4    [this regulation is without prejudice to regul...
# ..                                                 ...
# 277  [in article 4 of decision no 541/2014/eu of th...
# 278  [legal commitments for grants implementing the...
# 279  [this regulation shall be reviewed whenever it...
# 280  [regulation (eu, euratom) no 966/2012 is repea...
# 281  [this regulation shall enter into force on the...
#
# [282 rows x 4 columns]

# %%
final_dataframe.iloc[6,3]
# Out:
# ['for each financial year, the budget shall forecast and authorise all revenue and expenditure considered necessary for the union. it shall comprise: (a) the revenue and expenditure of the union, including administrative expenditure resulting from the implementation of the provisions of the teu relating to the common foreign and security policy (cfsp), and operational expenditure occasioned by implementation of those provisions where it is charged to the budget; (b) the revenue and expenditure of the european atomic energy community.',
#  'the budget shall contain differentiated appropriations, which consist of commitment appropriations and payment appropriations, and non-differentiated appropriations. the appropriations authorised for the financial year shall consist of: (a) appropriations provided in the budget, including by amending budgets; (b) appropriations carried over from preceding financial years; (c) appropriations made available again in accordance with article 15; (d) appropriations arising from pre-financing payments which have been repaid in accordance with point (b) of article 12(4); (e) appropriations provided following the receipt of revenue assigned during the financial year or carried over from preceding financial years.',
#  'commitment appropriations shall cover the total cost of the legal commitments entered into during the financial year, subject to article 114(2).',
#  'payment appropriations shall cover payments made to honour the legal commitments entered into in the financial year or preceding financial years.',
#  'paragraphs 2 and 3 of this article shall not prevent appropriations being committed globally or budgetary commitments being made in annual instalments as respectively provided for in point (b) of the first subparagraph of article 112(1) and in article 112(2).']

# %%
final_dataframe["Articles"].unique()
# Out:
# array(['Article 1  Subject matter ', 'Article 2  Definitions ',
#        'Article 3  Compliance of secondary legislation with this Regulation ',
#        'Article 4  Periods, dates and time limits ',
#        'Article 5  Protection of personal data ',
#        'Article 6  Respect for budgetary principles ',
#        'Article 7  Scope of the budget ',
#        'Article 8  Specific rules on the principles of unity and budgetary accuracy ',
#        'Article 9  Definition ',
#        'Article 10  Budgetary accounting for revenue and appropriations ',
#        'Article 11  Commitment of appropriations ',
#        'Article 12  Cancellation and carry-over of appropriations ',
#        'Article 13  Detailed provisions on cancellation and carry-over of appropriations ',
#        'Article 14  Decommitments ',
#        'Article 15  Making appropriations corresponding to decommitments available again ',
#        'Article 16  Rules applicable in the event of late adoption of the budget ',
#        'Article 17  Definition and scope ',
#        'Article 18  Balance from financial year ',
#        'Article 19  Use of euro ', 'Article 20  Scope ',
#        'Article 21  Assigned revenue ',
#        'Article 22  Structure to accommodate assigned revenue and provision of corresponding appropriations ',
#        'Article 23  Contributions from Member States to research programmes ',
#        'Article 24  Assigned revenue resulting from the participation of EFTA States in certain Union programmes ',
#        'Article 25  Donations ', 'Article 26  Corporate sponsorship ',
#        'Article 27  Rules on deductions and exchange rate adjustments ',
#        'Article 28  General provisions ',
#        'Article 29  Transfers by Union institutions other than the Commission ',
#        'Article 30  Transfers by the Commission ',
#        'Article 31  Transfer proposals submitted to the European Parliament and to the Council by Union institutions ',
#        'Article 32  Transfers subject to special provisions ',
#        'Article 33  Performance and principles of economy, efficiency and effectiveness ',
#        'Article 34  Evaluations ',
#        'Article 35  Compulsory financial statement ',
#        'Article 36  Internal control of budget implementation ',
#        'Article 37  Publication of accounts and budgets ',
#        'Article 38  Publication of information on recipients and other information ',
#        'Article 39  Estimates of revenue and expenditure ',
#        'Article 40  Estimated budget of the Union bodies referred to in Article 70 ',
#        'Article 41  Draft budget ',
#        'Article 42  Letter of amendment to the draft budget ',
#        'Article 43  Obligations of Member States as a result of the adoption of the budget ',
#        'Article 44  Draft amending budgets ',
#        'Article 45  Early transmission of estimates and draft budgets ',
#        'Article 46  Structure of the budget ',
#        'Article 47  Budget nomenclature ',
#        'Article 48  Negative revenue ', 'Article 49  Provisions ',
#        'Article 50  Negative reserve ',
#        'Article 51  Emergency Aid Reserve ',
#        'Article 52  Presentation of the budget ',
#        'Article 53  Rules on the establishment plans for staff ',
#        'Article 54  Compliance with the multiannual financial framework and Decision 2014/335/EU, Euratom ',
#        'Article 55  Compliance of Union acts with the budget ',
#        'Article 56  Budget implementation in accordance with the principle of sound financial management ',
#        'Article 57  Information on transfers of personal data for audit purposes ',
#        'Article 58  Basic act and exceptions ',
#        'Article 59  Budget implementation by Union institutions other than the Commission ',
#        'Article 60  Delegation of budget implementation powers ',
#        'Article 61  Conflict of interests ',
#        'Article 62  Methods of budget implementation ',
#        'Article 63  Shared management with Member States ',
#        'Article 64  Scope of competences of European offices ',
#        'Article 65  Appropriations regarding European offices ',
#        'Article 66  Non-obligatory tasks ',
#        'Article 67  Accounting records of European offices ',
#        'Article 68  Applicability to the Euratom Supply Agency ',
#        'Article 69  Executive agencies ',
#        'Article 70  Bodies set up under the TFEU and the Euratom Treaty ',
#        'Article 71  Public-private partnership bodies ',
#        'Article 72  Segregation of duties ',
#        'Article 73  Authorising officer ',
#        'Article 74  Powers and duties of the authorising officer ',
#        'Article 75  Keeping of supporting documents by authorising officers ',
#        'Article 76  Powers and duties of Heads of Union Delegations ',
#        'Article 77  Powers and duties of the accounting officer ',
#        'Article 78  Appointment and termination of duties of the accounting officer ',
#        'Article 79  Powers which may be delegated by the accounting officer ',
#        'Article 80  Accounting rules ',
#        'Article 81  Organisation of the accounts ',
#        'Article 82  Keeping the accounts ',
#        'Article 83  Content and keeping of budget accounts ',
#        'Article 84  General accounts ', 'Article 85  Bank accounts ',
#        'Article 86  Treasury management ',
#        'Article 87  The inventory of assets ',
#        'Article 88  Imprest accounts ',
#        'Article 89  Creation and administration of imprest accounts ',
#        'Article 90  Withdrawal of delegation of powers to and suspension of duties of financial actors ',
#        'Article 91  Liability of financial actors for illegal activity, fraud or corruption ',
#        'Article 92  Rules applicable to authorising officers ',
#        'Article 93  Treatment of financial irregularities on the part of a member of staff ',
#        'Article 94  Rules applicable to accounting officers ',
#        'Article 95  Rules applicable to imprest administrators ',
#        'Article 96  Own resources ',
#        'Article 97  Estimate of amounts receivable ',
#        'Article 98  Establishment of amounts receivable ',
#        'Article 99  Default interest ',
#        'Article 100  Authorisation of recovery ',
#        'Article 101  Rules on recovery ',
#        'Article 102  Recovery by offsetting ',
#        'Article 103  Recovery procedure failing voluntary payment ',
#        'Article 104  Additional time for payment ',
#        'Article 105  Limitation period ',
#        'Article 106  National treatment for entitlements of the Union ',
#        'Article 107  Fines, other penalties, sanctions and accrued interest imposed by Union institutions ',
#        'Article 108  Recovery of fines, other penalties or sanctions imposed by Union institutions ',
#        'Article 109  Compensatory interests ',
#        'Article 110  Financing decisions ',
#        'Article 111  Expenditure operations ',
#        'Article 112  Types of budgetary commitments ',
#        'Article 113  Commitments for EAGF appropriations ',
#        'Article 114  Time limits for commitments ',
#        'Article 115  Types of payments ',
#        'Article 116  Time limits for payments ',
#        'Article 117  Appointment of the internal auditor ',
#        'Article 118  Powers and duties of the internal auditor ',
#        'Article 119  Work programme of the internal auditor ',
#        'Article 120  Independence of the internal auditor ',
#        'Article 121  Liability of the internal auditor ',
#        'Article 122  Action before the Court of Justice of the European Union ',
#        'Article 123  Internal audit progress committees ',
#        'Article 124  Scope ', 'Article 125  Forms of Union contribution ',
#        'Article 126  Cross-reliance on assessments ',
#        'Article 127  Cross-reliance on audits ',
#        'Article 128  Use of already available information ',
#        'Article 129  Cooperation for protection of the financial interests of the Union ',
#        'Article 130  Financial framework partnerships ',
#        'Article 131  Suspension, termination and reduction ',
#        'Article 132  Record-keeping ',
#        'Article 133  Adversarial procedure and means of redress ',
#        'Article 134  Interest rate rebates and guarantee fee subsidies ',
#        'Article 135  Protection of the financial interests of the Union by means of detection of risks, exclusion and imposition of ',
#        'Article 136  Exclusion criteria and decisions on exclusions ',
#        'Article 137  Declaration and evidence of absence of an exclusion situation ',
#        'Article 138  Financial penalties ',
#        'Article 139  Duration of exclusion and limitation period ',
#        'Article 140  Publication of exclusion and financial penalties ',
#        'Article 141  Rejection from an award procedure ',
#        'Article 142  The early-detection and exclusion system ',
#        'Article 143  Panel ',
#        'Article 144  Functioning of the database for the early-detection and exclusion system ',
#        'Article 145  Exception applicable to the Joint Research Centre ',
#        'Article 146  Electronic management of operations ',
#        'Article 147  e-Government ',
#        'Article 148  Electronic exchange systems ',
#        'Article 149  Submission of application documents ',
#        'Article 150  Evaluation committee ',
#        'Article 151  Clarification and correction of application documents ',
#        'Article 152  Guarantees ',
#        'Article 153  Guarantee on pre-financing ',
#        'Article 154  Indirect management ',
#        'Article 155  Implementation of Union funds and budgetary guarantees ',
#        'Article 156  Indirect management with international organisations ',
#        'Article 157  Indirect management with Member State organisations ',
#        'Article 158  Indirect management with third countries ',
#        'Article 159  Blending operations ',
#        'Article 160  Principles applicable to contracts and scope ',
#        'Article 161  Annex on procurement and delegation of powers ',
#        'Article 162  Mixed contracts and common procurement vocabulary ',
#        'Article 163  Publicity measures ',
#        'Article 164  Procurement procedures ',
#        'Article 165  Interinstitutional procurement and joint procurement ',
#        'Article 166  Preparation of a procurement procedure ',
#        'Article 167  Award of contracts ',
#        'Article 168  Submission, electronic communication and evaluation ',
#        'Article 169  Contacts during the procurement procedure ',
#        'Article 170  Award decision and information to candidates or tenderers ',
#        'Article 171  Cancellation of the procurement procedure ',
#        'Article 172  Performance and modifications of the contract ',
#        'Article 173  Performance guarantees and retention money guarantees ',
#        'Article 174  The contracting authority ',
#        'Article 175  Thresholds applicable and standstill period ',
#        'Article 176  Rules on access to procurement ',
#        'Article 177  Procurement rules of the World Trade Organisation ',
#        'Article 178  External action procurement ',
#        'Article 179  Rules on access to procurement in the field of external actions ',
#        'Article 180  Scope and form of grants ',
#        'Article 181  Lump sums, unit costs and flat-rate financing ',
#        'Article 182  Single lump sums ',
#        'Article 183  Checks and controls on beneficiaries related to lump sums, unit costs and flat rates ',
#        'Article 184  Periodic assessment of lump sums, unit costs or flat-rates ',
#        'Article 185  Usual cost accounting practices of the beneficiary ',
#        'Article 186  Eligible costs ',
#        'Article 187  Affiliated entities and sole beneficiary ',
#        'Article 188  General principles applicable to grants ',
#        'Article 189  Transparency ', 'Article 190  Co-financing ',
#        'Article 191  Principle of non-cumulative award and prohibition of double funding ',
#        'Article 192  No-profit principle ',
#        'Article 193  Principle of non-retroactivity ',
#        'Article 194  Content and publication of calls for proposals ',
#        'Article 195  Exceptions to calls for proposals ',
#        'Article 196  Content of grant applications ',
#        'Article 197  Eligibility criteria ',
#        'Article 198  Selection criteria ', 'Article 199  Award criteria ',
#        'Article 200  Evaluation procedure ',
#        'Article 201  Grant agreement ',
#        'Article 202  Amount of the grant and extension of audit findings ',
#        'Article 203  Supporting documents for payment requests ',
#        'Article 204  Financial support to third parties ',
#        'Article 205  Implementation contracts ',
#        'Article 206  General rules ',
#        'Article 207  Rules of contest, award and publication ',
#        'Article 208  Scope and implementation ',
#        'Article 209  Principles and conditions applicable to financial instruments and budgetary guarantees ',
#        'Article 210  Financial liability of the Union ',
#        'Article 211  Provisioning of financial liabilities ',
#        'Article 212  Common provisioning fund ',
#        'Article 213  Effective provisioning rate ',
#        'Article 214  Annual reporting ',
#        'Article 215  Rules and implementation ',
#        'Article 216  Financial instruments directly implemented by the Commission ',
#        'Article 217  Treatment of contributions from funds implemented under shared management ',
#        'Article 218  Rules for budgetary guarantees ',
#        'Article 219  Implementation of budgetary guarantees ',
#        'Article 220  Rules and implementation ',
#        'Article 221  General provisions ', 'Article 222  Principles ',
#        'Article 223  Budgetary aspects ',
#        'Article 224  Call for contributions ',
#        'Article 225  Award procedure ',
#        'Article 226  Form of contributions ', 'Article 227  Guarantees ',
#        'Article 228  Use of contributions ',
#        'Article 229  Report on the use of the contributions ',
#        'Article 230  Amount of the contribution ',
#        'Article 231  Control and penalties ',
#        'Article 232  Record keeping ',
#        'Article 233  Selection of external audit bodies or experts ',
#        'Article 234  Union trust funds for external actions ',
#        'Article 235  Implementation of Union trust funds for external actions ',
#        'Article 236  Use of budget support ',
#        'Article 237  Remunerated external experts ',
#        'Article 238  Non-remunerated experts ',
#        'Article 239  Membership fees and other payments of subscriptions ',
#        'Article 240  Expenditure on the members and staff of Union institutions ',
#        'Article 241  Structure of the accounts ',
#        'Article 242  Supporting documents ',
#        'Article 243  Financial statements ',
#        'Article 244  Budget implementation reports ',
#        'Article 245  Provisional accounts ',
#        'Article 246  Approval of the final consolidated accounts ',
#        'Article 247  Integrated financial and accountability reporting ',
#        'Article 248  Monthly reporting on budget implementation ',
#        'Article 249  Annual report on budgetary and financial management ',
#        'Article 250  Annual report on financial instruments, budgetary guarantees and financial assistance ',
#        'Article 251  Status report on accounting issues ',
#        'Article 252  Reporting on Union trust funds for external actions ',
#        'Article 253  Publication of information on recipients ',
#        'Article 254  External audit by the Court of Auditors ',
#        'Article 255  Rules and procedure on the audit ',
#        'Article 256  Checks on securities and cash ',
#        'Article 257  Court of Auditors’ right of access ',
#        'Article 258  Annual report of the Court of Auditors ',
#        'Article 259  Special reports of the Court of Auditors ',
#        'Article 260  Timetable of the discharge procedure ',
#        'Article 261  The discharge procedure ',
#        'Article 262  Follow-up measures ',
#        'Article 263  Specific provisions regarding the EEAS ',
#        'Article 264  General provisions ',
#        'Article 265  Payments made in advance ',
#        'Article 266  Specific provisions regarding building projects ',
#        'Article 267  Early information procedure and prior approval procedure ',
#        'Article 268  Information requests by the European Parliament and by the Council ',
#        'Article 269  Exercise of the delegation ',
#        'Article 270  Amendments to Regulation (EU) No 1296/2013 ',
#        'Article 271  Amendments to Regulation (EU) No 1301/2013 ',
#        'Article 272  Amendments to Regulation (EU) No 1303/2013 ',
#        'Article 273  Amendments to Regulation (EU) No 1304/2013 ',
#        'Article 274  Amendments to Regulation (EU) No 1309/2013 ',
#        'Article 275  Amendments to Regulation (EU) No 1316/2013 ',
#        'Article 276  Amendments to Regulation (EU) No 223/2014 ',
#        'Article 277  Amendments to Regulation (EU) No 283/2014 ',
#        'Article 278  Amendment to Decision No 541/2014/EU ',
#        'Article 279  Transitional provisions ', 'Article 280  Review ',
#        'Article 281  Repeal ',
#        'Article 282  Entry into force and application '], dtype=object)

# %%
final_dataframe[final_dataframe["Articles"]=="Article 100  Authorisation of recovery "].iloc[0,3]
# Out:
# ['the authorising officer responsible shall, by issuing a recovery order, instruct the accounting officer to recover an amount receivable which that authorising officer responsible has established (‘the authorisation of recovery’).',
#  'a union institution may formally establish an amount as being receivable from persons other than member states by means of a decision which shall be enforceable within the meaning of article 299 tfeu. if the efficient and timely protection of the financial interests of the union so requires, other union institutions may, in exceptional circumstances, request the commission to adopt such an enforceable decision for their benefit with respect to claims arising in relation to staff or in relation to members or former members of a union institution, provided that those institutions have agreed with the commission on the practical modalities for the application of this article. such exceptional circumstances shall be deemed to exist when there is no prospect of recovery of the debt by the union institution concerned by means of a voluntary payment or by means of offsetting as provided for in article 101(1) and the conditions for waiving the recovery under article 101(2) and (3) are not met. in all cases, the enforceable decision shall specify that the amounts claimed shall be entered in the section of the budget relating to the union institution concerned, which shall act as authorising officer. the revenue shall be entered as general revenue except if it constitutes assigned revenue as provided for in article 21(3). the requesting union institution shall inform the commission of any event likely to alter the recovery and shall intervene in support of the commission in the event of an appeal against the enforceable decision. s e c t i o n 5 r e c o v e r y']

# %%
final_dataframe.shape
# Out:
# (282, 4)

# %%
final_dataframe
# Out:
#                                                  Title  \
# 0    TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 1    TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 2    TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 3    TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 4    TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# ..                                                 ...
# 277  TITLE XVI \nINFORMATION REQUESTS AND DELEGATED...
# 278  TITLE XVI \nINFORMATION REQUESTS AND DELEGATED...
# 279  TITLE XVI \nINFORMATION REQUESTS AND DELEGATED...
# 280  TITLE XVI \nINFORMATION REQUESTS AND DELEGATED...
# 281  TITLE XVI \nINFORMATION REQUESTS AND DELEGATED...
#
#                                               Articles  \
# 0                           Article 1  Subject matter
# 1                              Article 2  Definitions
# 2    Article 3  Compliance of secondary legislation...
# 3           Article 4  Periods, dates and time limits
# 4              Article 5  Protection of personal data
# ..                                                 ...
# 277  Article 278  Amendment to Decision No 541/2014...
# 278              Article 279  Transitional provisions
# 279                               Article 280  Review
# 280                               Article 281  Repeal
# 281     Article 282  Entry into force and application
#
#                                                Content  \
# 0    [\nThis Regulation lays down the rules for the...
# 1    [ ‘applicant’ means a natural person or an ent...
# 2    [ \nProvisions concerning the implementation o...
# 3    [\nUnless otherwise provided in this Regulatio...
# 4    [\nThis Regulation is without prejudice to Reg...
# ..                                                 ...
# 277  [\nIn Article 4 of Decision No 541/2014/EU of ...
# 278  [ \nLegal commitments for grants implementing ...
# 279  [\nThis Regulation shall be reviewed whenever ...
# 280  [ \nRegulation (EU, Euratom) No 966/2012 is re...
# 281  [ \nThis Regulation shall enter into force on ...
#
#                                        Cleaned_Content
# 0    [this regulation lays down the rules for the e...
# 1    [‘applicant’ means a natural person or an enti...
# 2    [provisions concerning the implementation of t...
# 3    [unless otherwise provided in this regulation,...
# 4    [this regulation is without prejudice to regul...
# ..                                                 ...
# 277  [in article 4 of decision no 541/2014/eu of th...
# 278  [legal commitments for grants implementing the...
# 279  [this regulation shall be reviewed whenever it...
# 280  [regulation (eu, euratom) no 966/2012 is repea...
# 281  [this regulation shall enter into force on the...
#
# [282 rows x 4 columns]

# %%
dataframe_I = final_dataframe[final_dataframe["Title"]=='TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENERAL PRINCIPLES ']
dataframe_I.shape
# Out:
# (5, 4)

# %%
dataframe_I
# Out:
#                                                Title  \
# 0  TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 1  TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 2  TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 3  TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 4  TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
#
#                                             Articles  \
# 0                         Article 1  Subject matter
# 1                            Article 2  Definitions
# 2  Article 3  Compliance of secondary legislation...
# 3         Article 4  Periods, dates and time limits
# 4            Article 5  Protection of personal data
#
#                                              Content  \
# 0  [\nThis Regulation lays down the rules for the...
# 1  [ ‘applicant’ means a natural person or an ent...
# 2  [ \nProvisions concerning the implementation o...
# 3  [\nUnless otherwise provided in this Regulatio...
# 4  [\nThis Regulation is without prejudice to Reg...
#
#                                      Cleaned_Content
# 0  [this regulation lays down the rules for the e...
# 1  [‘applicant’ means a natural person or an enti...
# 2  [provisions concerning the implementation of t...
# 3  [unless otherwise provided in this regulation,...
# 4  [this regulation is without prejudice to regul...

# %% [markdown]
# ## Expand the Dataframe: Row for each paragraph of an article

# %%
# Each text paragraph for each article gets its own row 
# Expand the dataframe by creating a row for each element of each cleaned content list 

dataframe_I = dataframe_I.explode('Cleaned_Content')
dataframe_I
# Out:
#                                                 Title  \
# 0   TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 1   TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 1   TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 1   TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 1   TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# ..                                                ...
# 1   TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 2   TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 2   TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 3   TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 4   TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
#
#                                              Articles  \
# 0                          Article 1  Subject matter
# 1                             Article 2  Definitions
# 1                             Article 2  Definitions
# 1                             Article 2  Definitions
# 1                             Article 2  Definitions
# ..                                                ...
# 1                             Article 2  Definitions
# 2   Article 3  Compliance of secondary legislation...
# 2   Article 3  Compliance of secondary legislation...
# 3          Article 4  Periods, dates and time limits
# 4             Article 5  Protection of personal data
#
#                                               Content  \
# 0   [\nThis Regulation lays down the rules for the...
# 1   [ ‘applicant’ means a natural person or an ent...
# 1   [ ‘applicant’ means a natural person or an ent...
# 1   [ ‘applicant’ means a natural person or an ent...
# 1   [ ‘applicant’ means a natural person or an ent...
# ..                                                ...
# 1   [ ‘applicant’ means a natural person or an ent...
# 2   [ \nProvisions concerning the implementation o...
# 2   [ \nProvisions concerning the implementation o...
# 3   [\nUnless otherwise provided in this Regulatio...
# 4   [\nThis Regulation is without prejudice to Reg...
#
#                                       Cleaned_Content
# 0   this regulation lays down the rules for the es...
# 1   ‘applicant’ means a natural person or an entit...
# 1   ‘application document’ means a tender, a reque...
# 1   ‘award procedure’ means a procurement procedur...
# 1   ‘basic act’ means a legal act, other than a re...
# ..                                                ...
# 1   ‘works contract’ means a contract covering eit...
# 2   provisions concerning the implementation of th...
# 2   without prejudice to paragraph 1, any proposal...
# 3   unless otherwise provided in this regulation, ...
# 4   this regulation is without prejudice to regula...
#
# [76 rows x 4 columns]

# %%
dataframe_I.iloc[4,3]
# Out:
# '‘basic act’ means a legal act, other than a recommendation or an opinion, which provides a legal basis for an action and for the implementation of the corresponding expenditure entered in the budget or of the budgetary guarantee or financial assistance backed by the budget, and which may take any of the following forms: (a) in implementation of the treaty on the functioning of the european union (tfeu) and the treaty establishing the european atomic energy community (the euratom treaty), the form of a regulation, a directive or a decision within the meaning of article 288 tfeu; or (b) in implementation of title v of the treaty on european union (teu), one of the forms specified in articles 28(1) and 31(2), article 33, and articles 42(4) and 43(2) teu;'

# %%
dataframe_I["Articles"].unique()
# Out:
# array(['Article 1  Subject matter ', 'Article 2  Definitions ',
#        'Article 3  Compliance of secondary legislation with this Regulation ',
#        'Article 4  Periods, dates and time limits ',
#        'Article 5  Protection of personal data '], dtype=object)

# %%
dataframe_I[dataframe_I['Articles']=="Article 2  Definitions "]["Cleaned_Content"].iloc[9,]
# Out:
# '‘building contract’ means a contract covering the purchase, exchange, long lease, usufruct, leasing, rental or hire purchase, with or without option to buy, of land, buildings or other immovable property. it covers both existing buildings and buildings before completion provided that the candidate has obtained a valid building permit for it. it does not cover buildings designed in accordance with the specifications of the contracting authority that are covered by works contracts;'

# %% [markdown]
# ## Text Preprocessing for each paragraph of each article (cleaned content)
#
# -Remove instances of (a),(b),(c) Example:  ....(a) in implementation of the treaty on the functioning of the european union...(b)....(c)
#
# -Remove punctuation except from dots as they are used for further segmentation
#
# -Segment the content on the dot --> Create a row for each sentence or small text chunk, and store in new column, named cleaned_content_new

# %%
dataframe_I
# Out:
#                                                 Title  \
# 0   TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 1   TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 1   TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 1   TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 1   TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# ..                                                ...
# 1   TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 2   TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 2   TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 3   TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 4   TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
#
#                                              Articles  \
# 0                          Article 1  Subject matter
# 1                             Article 2  Definitions
# 1                             Article 2  Definitions
# 1                             Article 2  Definitions
# 1                             Article 2  Definitions
# ..                                                ...
# 1                             Article 2  Definitions
# 2   Article 3  Compliance of secondary legislation...
# 2   Article 3  Compliance of secondary legislation...
# 3          Article 4  Periods, dates and time limits
# 4             Article 5  Protection of personal data
#
#                                               Content  \
# 0   [\nThis Regulation lays down the rules for the...
# 1   [ ‘applicant’ means a natural person or an ent...
# 1   [ ‘applicant’ means a natural person or an ent...
# 1   [ ‘applicant’ means a natural person or an ent...
# 1   [ ‘applicant’ means a natural person or an ent...
# ..                                                ...
# 1   [ ‘applicant’ means a natural person or an ent...
# 2   [ \nProvisions concerning the implementation o...
# 2   [ \nProvisions concerning the implementation o...
# 3   [\nUnless otherwise provided in this Regulatio...
# 4   [\nThis Regulation is without prejudice to Reg...
#
#                                       Cleaned_Content
# 0   this regulation lays down the rules for the es...
# 1   ‘applicant’ means a natural person or an entit...
# 1   ‘application document’ means a tender, a reque...
# 1   ‘award procedure’ means a procurement procedur...
# 1   ‘basic act’ means a legal act, other than a re...
# ..                                                ...
# 1   ‘works contract’ means a contract covering eit...
# 2   provisions concerning the implementation of th...
# 2   without prejudice to paragraph 1, any proposal...
# 3   unless otherwise provided in this regulation, ...
# 4   this regulation is without prejudice to regula...
#
# [76 rows x 4 columns]

# %%
# Example text before removal 

repr(dataframe_I.iloc[4,3])
# Out:
# "'‘basic act’ means a legal act, other than a recommendation or an opinion, which provides a legal basis for an action and for the implementation of the corresponding expenditure entered in the budget or of the budgetary guarantee or financial assistance backed by the budget, and which may take any of the following forms: (a) in implementation of the treaty on the functioning of the european union (tfeu) and the treaty establishing the european atomic energy community (the euratom treaty), the form of a regulation, a directive or a decision within the meaning of article 288 tfeu; or (b) in implementation of title v of the treaty on european union (teu), one of the forms specified in articles 28(1) and 31(2), article 33, and articles 42(4) and 43(2) teu;'"

# %%
# remove instances of (a),(b) etc using general expression
pattern_a = r'\s\([a-z]\)'

example_text = dataframe_I.iloc[4,3]

example_text = re.sub(pattern_a, '', example_text)

# %%
# Example text after removal 

example_text
# Out:
# '‘basic act’ means a legal act, other than a recommendation or an opinion, which provides a legal basis for an action and for the implementation of the corresponding expenditure entered in the budget or of the budgetary guarantee or financial assistance backed by the budget, and which may take any of the following forms: in implementation of the treaty on the functioning of the european union (tfeu) and the treaty establishing the european atomic energy community (the euratom treaty), the form of a regulation, a directive or a decision within the meaning of article 288 tfeu; or in implementation of title v of the treaty on european union (teu), one of the forms specified in articles 28(1) and 31(2), article 33, and articles 42(4) and 43(2) teu;'

# %%
# Remove punctuation function BUT without removing dots (.) for possible future segmentation 

def remove_punct(text):
    pattern_a = r'\s\([a-z]\)'
    text = re.sub(pattern_a, '', text)
    cleaned = ""
    punctuation = '!@#$%^&*_-+={}[];"\'|<>,?/~`’‘'
    for i in text:
        if i not in punctuation:
            cleaned = cleaned + i 
    return cleaned.strip()

# %%
dataframe_I
# Out:
#                                                 Title  \
# 0   TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 1   TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 1   TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 1   TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 1   TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# ..                                                ...
# 1   TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 2   TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 2   TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 3   TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 4   TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
#
#                                              Articles  \
# 0                          Article 1  Subject matter
# 1                             Article 2  Definitions
# 1                             Article 2  Definitions
# 1                             Article 2  Definitions
# 1                             Article 2  Definitions
# ..                                                ...
# 1                             Article 2  Definitions
# 2   Article 3  Compliance of secondary legislation...
# 2   Article 3  Compliance of secondary legislation...
# 3          Article 4  Periods, dates and time limits
# 4             Article 5  Protection of personal data
#
#                                               Content  \
# 0   [\nThis Regulation lays down the rules for the...
# 1   [ ‘applicant’ means a natural person or an ent...
# 1   [ ‘applicant’ means a natural person or an ent...
# 1   [ ‘applicant’ means a natural person or an ent...
# 1   [ ‘applicant’ means a natural person or an ent...
# ..                                                ...
# 1   [ ‘applicant’ means a natural person or an ent...
# 2   [ \nProvisions concerning the implementation o...
# 2   [ \nProvisions concerning the implementation o...
# 3   [\nUnless otherwise provided in this Regulatio...
# 4   [\nThis Regulation is without prejudice to Reg...
#
#                                       Cleaned_Content
# 0   this regulation lays down the rules for the es...
# 1   ‘applicant’ means a natural person or an entit...
# 1   ‘application document’ means a tender, a reque...
# 1   ‘award procedure’ means a procurement procedur...
# 1   ‘basic act’ means a legal act, other than a re...
# ..                                                ...
# 1   ‘works contract’ means a contract covering eit...
# 2   provisions concerning the implementation of th...
# 2   without prejudice to paragraph 1, any proposal...
# 3   unless otherwise provided in this regulation, ...
# 4   this regulation is without prejudice to regula...
#
# [76 rows x 4 columns]

# %%
dataframe_I[dataframe_I["Articles"]=="Article 4  Periods, dates and time limits "].iloc[0,3]
# Out:
# 'unless otherwise provided in this regulation, council regulation (eec, euratom) no 1182/71 ( 1 ) shall apply to the deadlines set out in this regulation. l 193/30    1).'

# %%
# Remove punctuation (not .) from cleaned content column 

dataframe_I['Cleaned_Content'] = dataframe_I['Cleaned_Content'].apply(remove_punct)

# %%
dataframe_I.iloc[14,3].split(".")
# Out:
# ['concession contract means a contract for pecuniary interest concluded in writing between one or more economic operators and one or more contracting authorities within the meaning of articles 174 and 178 in order to entrust the execution of works or the provision and management of services to an economic operator (the concession) and where: the remuneration consists either solely in the right to exploit the works or services or in that right together with payment the award of the concession contract involves the transfer to the concessionaire of an operating risk in exploiting those works or services encompassing demand risk or supply risk or both',
#  ' the concessionaire shall be deemed to assume an operating risk where under normal operating conditions there is no guarantee of recouping the investments made or the costs incurred in operating the works or the services concerned']

# %%
dataframe_I.iloc[4,3]
# Out:
# 'basic act means a legal act other than a recommendation or an opinion which provides a legal basis for an action and for the implementation of the corresponding expenditure entered in the budget or of the budgetary guarantee or financial assistance backed by the budget and which may take any of the following forms: in implementation of the treaty on the functioning of the european union (tfeu) and the treaty establishing the european atomic energy community (the euratom treaty) the form of a regulation a directive or a decision within the meaning of article 288 tfeu or in implementation of title v of the treaty on european union (teu) one of the forms specified in articles 28(1) and 31(2) article 33 and articles 42(4) and 43(2) teu'

# %%
# Create new column of sentences or small text chunks 

dataframe_I['Cleaned_Content_new'] = dataframe_I['Cleaned_Content'].apply(lambda x: x.split('.'))

# %%
dataframe_I
# Out:
#                                                 Title  \
# 0   TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 1   TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 1   TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 1   TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 1   TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# ..                                                ...
# 1   TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 2   TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 2   TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 3   TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 4   TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
#
#                                              Articles  \
# 0                          Article 1  Subject matter
# 1                             Article 2  Definitions
# 1                             Article 2  Definitions
# 1                             Article 2  Definitions
# 1                             Article 2  Definitions
# ..                                                ...
# 1                             Article 2  Definitions
# 2   Article 3  Compliance of secondary legislation...
# 2   Article 3  Compliance of secondary legislation...
# 3          Article 4  Periods, dates and time limits
# 4             Article 5  Protection of personal data
#
#                                               Content  \
# 0   [\nThis Regulation lays down the rules for the...
# 1   [ ‘applicant’ means a natural person or an ent...
# 1   [ ‘applicant’ means a natural person or an ent...
# 1   [ ‘applicant’ means a natural person or an ent...
# 1   [ ‘applicant’ means a natural person or an ent...
# ..                                                ...
# 1   [ ‘applicant’ means a natural person or an ent...
# 2   [ \nProvisions concerning the implementation o...
# 2   [ \nProvisions concerning the implementation o...
# 3   [\nUnless otherwise provided in this Regulatio...
# 4   [\nThis Regulation is without prejudice to Reg...
#
#                                       Cleaned_Content  \
# 0   this regulation lays down the rules for the es...
# 1   applicant means a natural person or an entity ...
# 1   application document means a tender a request ...
# 1   award procedure means a procurement procedure ...
# 1   basic act means a legal act other than a recom...
# ..                                                ...
# 1   works contract means a contract covering eithe...
# 2   provisions concerning the implementation of th...
# 2   without prejudice to paragraph 1 any proposal ...
# 3   unless otherwise provided in this regulation c...
# 4   this regulation is without prejudice to regula...
#
#                                   Cleaned_Content_new
# 0   [this regulation lays down the rules for the e...
# 1   [applicant means a natural person or an entity...
# 1   [application document means a tender a request...
# 1   [award procedure means a procurement procedure...
# 1   [basic act means a legal act other than a reco...
# ..                                                ...
# 1   [works contract means a contract covering eith...
# 2   [provisions concerning the implementation of t...
# 2   [without prejudice to paragraph 1 any proposal...
# 3   [unless otherwise provided in this regulation ...
# 4   [this regulation is without prejudice to regul...
#
# [76 rows x 5 columns]

# %%
# Example of empty elements problem 

dataframe_I.iloc[0,4]
# Out:
# ['this regulation lays down the rules for the establishment and the implementation of the general budget of the european union and of the european atomic energy community (the budget) and the presentation and auditing of their accounts',
#  '']

# %%
# Function to only keep text elements that are NOT empty or are NOT single characters or single numbers 

def keep_text_elements(text_list):
    cleaned_text_list = []
    if isinstance(text_list,list):
        for element in text_list:
            if len(re.findall(r'[a-zA-Z]', element)) > 1:
                cleaned_text_list.append(element)
    return cleaned_text_list

# %%
keep_text_elements(dataframe_I.iloc[0,4])
# Out:
# ['this regulation lays down the rules for the establishment and the implementation of the general budget of the european union and of the european atomic energy community (the budget) and the presentation and auditing of their accounts']

# %%
# Apply the function to cleaned content new 

dataframe_I['Cleaned_Content_new'] = dataframe_I['Cleaned_Content_new'].apply(keep_text_elements)

# %%
dataframe_I
# Out:
#                                                 Title  \
# 0   TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 1   TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 1   TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 1   TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 1   TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# ..                                                ...
# 1   TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 2   TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 2   TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 3   TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 4   TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
#
#                                              Articles  \
# 0                          Article 1  Subject matter
# 1                             Article 2  Definitions
# 1                             Article 2  Definitions
# 1                             Article 2  Definitions
# 1                             Article 2  Definitions
# ..                                                ...
# 1                             Article 2  Definitions
# 2   Article 3  Compliance of secondary legislation...
# 2   Article 3  Compliance of secondary legislation...
# 3          Article 4  Periods, dates and time limits
# 4             Article 5  Protection of personal data
#
#                                               Content  \
# 0   [\nThis Regulation lays down the rules for the...
# 1   [ ‘applicant’ means a natural person or an ent...
# 1   [ ‘applicant’ means a natural person or an ent...
# 1   [ ‘applicant’ means a natural person or an ent...
# 1   [ ‘applicant’ means a natural person or an ent...
# ..                                                ...
# 1   [ ‘applicant’ means a natural person or an ent...
# 2   [ \nProvisions concerning the implementation o...
# 2   [ \nProvisions concerning the implementation o...
# 3   [\nUnless otherwise provided in this Regulatio...
# 4   [\nThis Regulation is without prejudice to Reg...
#
#                                       Cleaned_Content  \
# 0   this regulation lays down the rules for the es...
# 1   applicant means a natural person or an entity ...
# 1   application document means a tender a request ...
# 1   award procedure means a procurement procedure ...
# 1   basic act means a legal act other than a recom...
# ..                                                ...
# 1   works contract means a contract covering eithe...
# 2   provisions concerning the implementation of th...
# 2   without prejudice to paragraph 1 any proposal ...
# 3   unless otherwise provided in this regulation c...
# 4   this regulation is without prejudice to regula...
#
#                                   Cleaned_Content_new
# 0   [this regulation lays down the rules for the e...
# 1   [applicant means a natural person or an entity...
# 1   [application document means a tender a request...
# 1   [award procedure means a procurement procedure...
# 1   [basic act means a legal act other than a reco...
# ..                                                ...
# 1   [works contract means a contract covering eith...
# 2   [provisions concerning the implementation of t...
# 2   [without prejudice to paragraph 1 any proposal...
# 3   [unless otherwise provided in this regulation ...
# 4   [this regulation is without prejudice to regul...
#
# [76 rows x 5 columns]

# %%
# Row for each sentence or small text chunk in the list of the cleaned (punctuation, noise, lowercase) text

dataframe_I = dataframe_I.explode('Cleaned_Content_new')
dataframe_I
# Out:
#                                                 Title  \
# 0   TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 1   TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 1   TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 1   TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 1   TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# ..                                                ...
# 1   TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 2   TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 2   TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 3   TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 4   TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
#
#                                              Articles  \
# 0                          Article 1  Subject matter
# 1                             Article 2  Definitions
# 1                             Article 2  Definitions
# 1                             Article 2  Definitions
# 1                             Article 2  Definitions
# ..                                                ...
# 1                             Article 2  Definitions
# 2   Article 3  Compliance of secondary legislation...
# 2   Article 3  Compliance of secondary legislation...
# 3          Article 4  Periods, dates and time limits
# 4             Article 5  Protection of personal data
#
#                                               Content  \
# 0   [\nThis Regulation lays down the rules for the...
# 1   [ ‘applicant’ means a natural person or an ent...
# 1   [ ‘applicant’ means a natural person or an ent...
# 1   [ ‘applicant’ means a natural person or an ent...
# 1   [ ‘applicant’ means a natural person or an ent...
# ..                                                ...
# 1   [ ‘applicant’ means a natural person or an ent...
# 2   [ \nProvisions concerning the implementation o...
# 2   [ \nProvisions concerning the implementation o...
# 3   [\nUnless otherwise provided in this Regulatio...
# 4   [\nThis Regulation is without prejudice to Reg...
#
#                                       Cleaned_Content  \
# 0   this regulation lays down the rules for the es...
# 1   applicant means a natural person or an entity ...
# 1   application document means a tender a request ...
# 1   award procedure means a procurement procedure ...
# 1   basic act means a legal act other than a recom...
# ..                                                ...
# 1   works contract means a contract covering eithe...
# 2   provisions concerning the implementation of th...
# 2   without prejudice to paragraph 1 any proposal ...
# 3   unless otherwise provided in this regulation c...
# 4   this regulation is without prejudice to regula...
#
#                                   Cleaned_Content_new
# 0   this regulation lays down the rules for the es...
# 1   applicant means a natural person or an entity ...
# 1   application document means a tender a request ...
# 1   award procedure means a procurement procedure ...
# 1   basic act means a legal act other than a recom...
# ..                                                ...
# 1   works contract means a contract covering eithe...
# 2   provisions concerning the implementation of th...
# 2   without prejudice to paragraph 1 any proposal ...
# 3   unless otherwise provided in this regulation c...
# 4   this regulation is without prejudice to regula...
#
# [82 rows x 5 columns]

# %%
dataframe_I[dataframe_I["Articles"]=='Article 3  Compliance of secondary legislation with this Regulation '].iloc[0,3]
# Out:
# 'provisions concerning the implementation of the revenue and expenditure of the budget and contained in a basic act shall comply with the budgetary principles set out in title ii.'

# %% [markdown]
# ## Obtain triplets of Subject-Verb-Object
#
# - Apply a Rule Based Method (ClausIE), specifically the algorithm mentioned in the relevant paper
#
# Experiment on a subset

# %%
import claucy

nlp = spacy.load("en_core_web_sm")
claucy.add_to_pipe(nlp)

doc = nlp('basic act means a legal act, other than a recommendation or an opinion, which provides a legal basis for an action and for the implementation of the corresponding expenditure entered in the budget or of the budgetary guarantee or financial assistance backed by the budget, and which may take any of the following forms')

propositions = doc._.clauses
propositions

# triplet = [str(propositions.subject),str(propositions.verb),str(propositions.direct_object) +  " " + str(propositions.complement) + str(propositions.adverbials[0])]
# print(triplet)
# Out:
# [<SVO, basic act, means, None, a legal act, other than a recommendation or an opinion, which provides a legal basis for an action and for the implementation of the corresponding expenditure entered in the budget or of the budgetary guarantee or financial assistance backed by the budget,, None, []>,
#  <SVO, which, provides, None, a legal basis for an action and for the implementation of the corresponding expenditure entered in the budget or of the budgetary guarantee or financial assistance backed by the budget, None, []>,
#  <SVO, which, may take, None, any of the following forms, None, []>]

# %%
def triplet(propos):
    triplet = []
    tail = ''
    if propos.subject != None:
        triplet.append(str(propos.subject))
    if propos.verb != None:
        triplet.append(str(propos.verb))
    if propos.direct_object != None:
        tail = tail + str(propos.direct_object)
    if propos.complement != None:
        tail = tail + " " + str(propos.complement)
    if len(propos.adverbials) != 0:
        adverbial = ""
        for i in propos.adverbials:
            adverbial = adverbial + " " + str(i)
        adverbial = adverbial.strip()
        tail = tail + " " + adverbial.strip()
    triplet.append(tail)
    
    return triplet


def all_triplets(propositions_list):
    triplet_list = []
    for proposition in propositions_list:
        if len(triplet(proposition))==3:
            triplet_list.append(triplet(proposition))
    return triplet_list       


def obtain_proposition_list(complex_sentence):
    import claucy

    nlp = spacy.load("en_core_web_sm")
    claucy.add_to_pipe(nlp)

    doc = nlp(complex_sentence)

    propositions = doc._.clauses

    return all_triplets(propositions)

# %%
dataframe_I['triplets_list'] = dataframe_I['Cleaned_Content_new'].apply(obtain_proposition_list)

# %%
dataframe_I
# Out:
#                                                 Title  \
# 0   TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 1   TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 1   TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 1   TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 1   TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# ..                                                ...
# 1   TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 2   TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 2   TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 3   TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 4   TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
#
#                                              Articles  \
# 0                          Article 1  Subject matter
# 1                             Article 2  Definitions
# 1                             Article 2  Definitions
# 1                             Article 2  Definitions
# 1                             Article 2  Definitions
# ..                                                ...
# 1                             Article 2  Definitions
# 2   Article 3  Compliance of secondary legislation...
# 2   Article 3  Compliance of secondary legislation...
# 3          Article 4  Periods, dates and time limits
# 4             Article 5  Protection of personal data
#
#                                               Content  \
# 0   [\nThis Regulation lays down the rules for the...
# 1   [ ‘applicant’ means a natural person or an ent...
# 1   [ ‘applicant’ means a natural person or an ent...
# 1   [ ‘applicant’ means a natural person or an ent...
# 1   [ ‘applicant’ means a natural person or an ent...
# ..                                                ...
# 1   [ ‘applicant’ means a natural person or an ent...
# 2   [ \nProvisions concerning the implementation o...
# 2   [ \nProvisions concerning the implementation o...
# 3   [\nUnless otherwise provided in this Regulatio...
# 4   [\nThis Regulation is without prejudice to Reg...
#
#                                       Cleaned_Content  \
# 0   this regulation lays down the rules for the es...
# 1   applicant means a natural person or an entity ...
# 1   application document means a tender a request ...
# 1   award procedure means a procurement procedure ...
# 1   basic act means a legal act other than a recom...
# ..                                                ...
# 1   works contract means a contract covering eithe...
# 2   provisions concerning the implementation of th...
# 2   without prejudice to paragraph 1 any proposal ...
# 3   unless otherwise provided in this regulation c...
# 4   this regulation is without prejudice to regula...
#
#                                   Cleaned_Content_new  \
# 0   this regulation lays down the rules for the es...
# 1   applicant means a natural person or an entity ...
# 1   application document means a tender a request ...
# 1   award procedure means a procurement procedure ...
# 1   basic act means a legal act other than a recom...
# ..                                                ...
# 1   works contract means a contract covering eithe...
# 2   provisions concerning the implementation of th...
# 2   without prejudice to paragraph 1 any proposal ...
# 3   unless otherwise provided in this regulation c...
# 4   this regulation is without prejudice to regula...
#
#                                         triplets_list
# 0   [[this regulation, lays, the rules for the est...
# 1   [[applicant, means, a natural person or an ent...
# 1           [[application document, means, a tender]]
# 1   [[award procedure, means, a procurement proced...
# 1   [[basic act, means, a legal act other than a r...
# ..                                                ...
# 1   [[works contract, means, a contract covering e...
# 2   [[provisions concerning the implementation of ...
# 2                                                  []
# 3                                                  []
# 4   [[this regulation, is,  without prejudice to r...
#
# [82 rows x 6 columns]

# %%
dataframe_I['empty_list'] = dataframe_I['triplets_list'].apply(lambda x: len(x)==0)
dataframe_I['empty_list'].sum()
# Out:
# np.int64(2)

# %%
dataframe_I['empty_list'].sum()
# Out:
# np.int64(2)

# %%
dataframe_I = dataframe_I[dataframe_I['empty_list']==False]

# %%
dataframe_I.iloc[0,5]
# Out:
# [['this regulation', 'lays', 'the rules for the establishment']]

# %%
dataframe_I['many_triplets'] = dataframe_I['triplets_list'].apply(lambda x: len(x)>1)
dataframe_I['many_triplets'].sum()
# Out:
# C:\Users\Student\AppData\Local\Temp\ipykernel_2932\4009133928.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe_I['many_triplets'] = dataframe_I['triplets_list'].apply(lambda x: len(x)>1)
# np.int64(40)

# %%
dataframe_I['many_triplets'].sum()
# Out:
# np.int64(40)

# %%
dataframe_I
# Out:
#                                                 Title  \
# 0   TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 1   TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 1   TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 1   TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 1   TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# ..                                                ...
# 1   TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 1   TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 1   TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 2   TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 4   TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
#
#                                              Articles  \
# 0                          Article 1  Subject matter
# 1                             Article 2  Definitions
# 1                             Article 2  Definitions
# 1                             Article 2  Definitions
# 1                             Article 2  Definitions
# ..                                                ...
# 1                             Article 2  Definitions
# 1                             Article 2  Definitions
# 1                             Article 2  Definitions
# 2   Article 3  Compliance of secondary legislation...
# 4             Article 5  Protection of personal data
#
#                                               Content  \
# 0   [\nThis Regulation lays down the rules for the...
# 1   [ ‘applicant’ means a natural person or an ent...
# 1   [ ‘applicant’ means a natural person or an ent...
# 1   [ ‘applicant’ means a natural person or an ent...
# 1   [ ‘applicant’ means a natural person or an ent...
# ..                                                ...
# 1   [ ‘applicant’ means a natural person or an ent...
# 1   [ ‘applicant’ means a natural person or an ent...
# 1   [ ‘applicant’ means a natural person or an ent...
# 2   [ \nProvisions concerning the implementation o...
# 4   [\nThis Regulation is without prejudice to Reg...
#
#                                       Cleaned_Content  \
# 0   this regulation lays down the rules for the es...
# 1   applicant means a natural person or an entity ...
# 1   application document means a tender a request ...
# 1   award procedure means a procurement procedure ...
# 1   basic act means a legal act other than a recom...
# ..                                                ...
# 1   volunteer means a person working on a noncompu...
# 1   work means the outcome of building or civil en...
# 1   works contract means a contract covering eithe...
# 2   provisions concerning the implementation of th...
# 4   this regulation is without prejudice to regula...
#
#                                   Cleaned_Content_new  \
# 0   this regulation lays down the rules for the es...
# 1   applicant means a natural person or an entity ...
# 1   application document means a tender a request ...
# 1   award procedure means a procurement procedure ...
# 1   basic act means a legal act other than a recom...
# ..                                                ...
# 1   volunteer means a person working on a noncompu...
# 1   work means the outcome of building or civil en...
# 1   works contract means a contract covering eithe...
# 2   provisions concerning the implementation of th...
# 4   this regulation is without prejudice to regula...
#
#                                         triplets_list  empty_list  \
# 0   [[this regulation, lays, the rules for the est...       False
# 1   [[applicant, means, a natural person or an ent...       False
# 1           [[application document, means, a tender]]       False
# 1   [[award procedure, means, a procurement proced...       False
# 1   [[basic act, means, a legal act other than a r...       False
# ..                                                ...         ...
# 1   [[volunteer, means, a person working on a nonc...       False
# 1   [[work, means, the outcome of building or civi...       False
# 1   [[works contract, means, a contract covering e...       False
# 2   [[provisions concerning the implementation of ...       False
# 4   [[this regulation, is,  without prejudice to r...       False
#
#     many_triplets
# 0           False
# 1            True
# 1           False
# 1           False
# 1            True
# ..            ...
# 1           False
# 1            True
# 1           False
# 2           False
# 4           False
#
# [80 rows x 8 columns]

# %%
final_dataframe["Title"].unique()
# Out:
# array(['TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENERAL PRINCIPLES ',
#        'TITLE II \nBUDGET AND BUDGETARY PRINCIPLES ',
#        'TITLE III \nESTABLISHMENT AND STRUCTURE OF THE BUDGET ',
#        'TITLE IV \nBUDGET IMPLEMENTATION ', 'TITLE V \nCOMMON RULES ',
#        'TITLE VI \nINDIRECT MANAGEMENT ',
#        'TITLE VII \nPROCUREMENT AND CONCESSIONS ', 'TITLE VIII \nGRANTS ',
#        'TITLE IX \nPRIZES ',
#        'TITLE X \nFINANCIAL INSTRUMENTS, BUDGETARY GUARANTEES AND FINANCIAL ASSISTANCE ',
#        'TITLE XI \nCONTRIBUTIONS TO EUROPEAN POLITICAL PARTIES ',
#        'TITLE XII \nOTHER BUDGET IMPLEMENTATION INSTRUMENTS ',
#        'TITLE XIII \nANNUAL ACCOUNTS AND OTHER FINANCIAL REPORTING ',
#        'TITLE XIV \nEXTERNAL AUDIT AND DISCHARGE ',
#        'TITLE XV \nADMINISTRATIVE APPROPRIATIONS ',
#        'TITLE XVI \nINFORMATION REQUESTS AND DELEGATED ACTS '],
#       dtype=object)

# %%
dataframe_II = final_dataframe[final_dataframe["Title"]=='TITLE II \nBUDGET AND BUDGETARY PRINCIPLES ']

# %%
dataframe_II
# Out:
#                                           Title  \
# 5   TITLE II \nBUDGET AND BUDGETARY PRINCIPLES
# 6   TITLE II \nBUDGET AND BUDGETARY PRINCIPLES
# 7   TITLE II \nBUDGET AND BUDGETARY PRINCIPLES
# 8   TITLE II \nBUDGET AND BUDGETARY PRINCIPLES
# 9   TITLE II \nBUDGET AND BUDGETARY PRINCIPLES
# 10  TITLE II \nBUDGET AND BUDGETARY PRINCIPLES
# 11  TITLE II \nBUDGET AND BUDGETARY PRINCIPLES
# 12  TITLE II \nBUDGET AND BUDGETARY PRINCIPLES
# 13  TITLE II \nBUDGET AND BUDGETARY PRINCIPLES
# 14  TITLE II \nBUDGET AND BUDGETARY PRINCIPLES
# 15  TITLE II \nBUDGET AND BUDGETARY PRINCIPLES
# 16  TITLE II \nBUDGET AND BUDGETARY PRINCIPLES
# 17  TITLE II \nBUDGET AND BUDGETARY PRINCIPLES
# 18  TITLE II \nBUDGET AND BUDGETARY PRINCIPLES
# 19  TITLE II \nBUDGET AND BUDGETARY PRINCIPLES
# 20  TITLE II \nBUDGET AND BUDGETARY PRINCIPLES
# 21  TITLE II \nBUDGET AND BUDGETARY PRINCIPLES
# 22  TITLE II \nBUDGET AND BUDGETARY PRINCIPLES
# 23  TITLE II \nBUDGET AND BUDGETARY PRINCIPLES
# 24  TITLE II \nBUDGET AND BUDGETARY PRINCIPLES
# 25  TITLE II \nBUDGET AND BUDGETARY PRINCIPLES
# 26  TITLE II \nBUDGET AND BUDGETARY PRINCIPLES
# 27  TITLE II \nBUDGET AND BUDGETARY PRINCIPLES
# 28  TITLE II \nBUDGET AND BUDGETARY PRINCIPLES
# 29  TITLE II \nBUDGET AND BUDGETARY PRINCIPLES
# 30  TITLE II \nBUDGET AND BUDGETARY PRINCIPLES
# 31  TITLE II \nBUDGET AND BUDGETARY PRINCIPLES
# 32  TITLE II \nBUDGET AND BUDGETARY PRINCIPLES
# 33  TITLE II \nBUDGET AND BUDGETARY PRINCIPLES
# 34  TITLE II \nBUDGET AND BUDGETARY PRINCIPLES
# 35  TITLE II \nBUDGET AND BUDGETARY PRINCIPLES
# 36  TITLE II \nBUDGET AND BUDGETARY PRINCIPLES
# 37  TITLE II \nBUDGET AND BUDGETARY PRINCIPLES
#
#                                              Articles  \
# 5        Article 6  Respect for budgetary principles
# 6                     Article 7  Scope of the budget
# 7   Article 8  Specific rules on the principles of...
# 8                              Article 9  Definition
# 9   Article 10  Budgetary accounting for revenue a...
# 10          Article 11  Commitment of appropriations
# 11  Article 12  Cancellation and carry-over of app...
# 12  Article 13  Detailed provisions on cancellatio...
# 13                         Article 14  Decommitments
# 14  Article 15  Making appropriations correspondin...
# 15  Article 16  Rules applicable in the event of l...
# 16                  Article 17  Definition and scope
# 17           Article 18  Balance from financial year
# 18                           Article 19  Use of euro
# 19                                 Article 20  Scope
# 20                      Article 21  Assigned revenue
# 21  Article 22  Structure to accommodate assigned ...
# 22  Article 23  Contributions from Member States t...
# 23  Article 24  Assigned revenue resulting from th...
# 24                             Article 25  Donations
# 25                 Article 26  Corporate sponsorship
# 26  Article 27  Rules on deductions and exchange r...
# 27                    Article 28  General provisions
# 28  Article 29  Transfers by Union institutions ot...
# 29           Article 30  Transfers by the Commission
# 30  Article 31  Transfer proposals submitted to th...
# 31  Article 32  Transfers subject to special provi...
# 32  Article 33  Performance and principles of econ...
# 33                           Article 34  Evaluations
# 34        Article 35  Compulsory financial statement
# 35  Article 36  Internal control of budget impleme...
# 36   Article 37  Publication of accounts and budgets
# 37  Article 38  Publication of information on reci...
#
#                                               Content  \
# 5   [\nThe budget shall be established and impleme...
# 6   [ \nFor each financial year, the budget shall ...
# 7   [ \nAll revenue and expenditure shall be booke...
# 8   [\nThe appropriations entered in the budget sh...
# 9   [ \nThe revenue of a financial year shall be e...
# 10  [ \nThe appropriations entered in the budget m...
# 11  [ \nAppropriations which have not been used by...
# 12  [ \nThe commitment appropriations and the non-...
# 13  [ \nWhere budgetary commitments are decommitte...
# 14  [ \nThe appropriations corresponding to decomm...
# 15  [ \nIf the budget has not been definitively ad...
# 16  [ \nRevenue and payment appropriations shall b...
# 17  [ \nThe balance from each financial year shall...
# 18  [ \nThe multiannual financial framework and th...
# 19  [\nWithout prejudice to Article 21, total reve...
# 20  [ \nExternal assigned revenue and internal ass...
# 21  [ \nWithout prejudice to point (c) of the firs...
# 22  [ \nThe contributions from Member States to th...
# 23  [ \nThe budget structure to accommodate the re...
# 24  [ \nUnion institutions may accept any donation...
# 25  [ \n‘Corporate sponsorship’ means an agreement...
# 26  [ \nThe following deductions may be made from ...
# 27  [ \nAppropriations shall be earmarked for spec...
# 28  [ \nAny Union institution other than the Commi...
# 29  [ \nThe Commission may, within its own section...
# 30  [ \nEach Union institution shall submit its tr...
# 31  [ \nAppropriations corresponding to assigned r...
# 32  [ \nAppropriations shall be used in accordance...
# 33  [ \nProgrammes and activities which entail sig...
# 34  [ \nAny proposal or initiative submitted to th...
# 35  [ \nPursuant to the principle of sound financi...
# 36  [ \nThe budget shall be established and implem...
# 37  [ \nThe Commission shall make available, in an...
#
#                                       Cleaned_Content
# 5   [the budget shall be established and implement...
# 6   [for each financial year, the budget shall for...
# 7   [all revenue and expenditure shall be booked t...
# 8   [the appropriations entered in the budget shal...
# 9   [the revenue of a financial year shall be ente...
# 10  [the appropriations entered in the budget may ...
# 11  [appropriations which have not been used by th...
# 12  [the commitment appropriations and the non-dif...
# 13  [where budgetary commitments are decommitted i...
# 14  [the appropriations corresponding to decommitm...
# 15  [if the budget has not been definitively adopt...
# 16  [revenue and payment appropriations shall be i...
# 17  [the balance from each financial year shall be...
# 18  [the multiannual financial framework and the b...
# 19  [without prejudice to article 21, total revenu...
# 20  [external assigned revenue and internal assign...
# 21  [without prejudice to point (c) of the first s...
# 22  [the contributions from member states to the f...
# 23  [the budget structure to accommodate the reven...
# 24  [union institutions may accept any donation ma...
# 25  [‘corporate sponsorship’ means an agreement by...
# 26  [the following deductions may be made from pay...
# 27  [appropriations shall be earmarked for specifi...
# 28  [any union institution other than the commissi...
# 29  [the commission may, within its own section of...
# 30  [each union institution shall submit its trans...
# 31  [appropriations corresponding to assigned reve...
# 32  [appropriations shall be used in accordance wi...
# 33  [programmes and activities which entail signif...
# 34  [any proposal or initiative submitted to the l...
# 35  [pursuant to the principle of sound financial ...
# 36  [the budget shall be established and implement...
# 37  [the commission shall make available, in an ap...

# %%
dataframe_II = dataframe_II.explode("Cleaned_Content")

# %%
dataframe_II = dataframe_II.reset_index(drop=True)

# %% [markdown]
# # Utilize Coreference Resolution Dataframe "coreferenced_final_dataframe.csv"
#
# -Pipeline for Triplet Extraction from all Titles using rule-based clausIE method using the whole dataframe

# %%
final_dataframe
# Out:
#                                                  Title  \
# 0    TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 1    TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 2    TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 3    TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 4    TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# ..                                                 ...
# 277  TITLE XVI \nINFORMATION REQUESTS AND DELEGATED...
# 278  TITLE XVI \nINFORMATION REQUESTS AND DELEGATED...
# 279  TITLE XVI \nINFORMATION REQUESTS AND DELEGATED...
# 280  TITLE XVI \nINFORMATION REQUESTS AND DELEGATED...
# 281  TITLE XVI \nINFORMATION REQUESTS AND DELEGATED...
#
#                                               Articles  \
# 0                           Article 1  Subject matter
# 1                              Article 2  Definitions
# 2    Article 3  Compliance of secondary legislation...
# 3           Article 4  Periods, dates and time limits
# 4              Article 5  Protection of personal data
# ..                                                 ...
# 277  Article 278  Amendment to Decision No 541/2014...
# 278              Article 279  Transitional provisions
# 279                               Article 280  Review
# 280                               Article 281  Repeal
# 281     Article 282  Entry into force and application
#
#                                                Content  \
# 0    [\nThis Regulation lays down the rules for the...
# 1    [ ‘applicant’ means a natural person or an ent...
# 2    [ \nProvisions concerning the implementation o...
# 3    [\nUnless otherwise provided in this Regulatio...
# 4    [\nThis Regulation is without prejudice to Reg...
# ..                                                 ...
# 277  [\nIn Article 4 of Decision No 541/2014/EU of ...
# 278  [ \nLegal commitments for grants implementing ...
# 279  [\nThis Regulation shall be reviewed whenever ...
# 280  [ \nRegulation (EU, Euratom) No 966/2012 is re...
# 281  [ \nThis Regulation shall enter into force on ...
#
#                                        Cleaned_Content
# 0    [this regulation lays down the rules for the e...
# 1    [‘applicant’ means a natural person or an enti...
# 2    [provisions concerning the implementation of t...
# 3    [unless otherwise provided in this regulation,...
# 4    [this regulation is without prejudice to regul...
# ..                                                 ...
# 277  [in article 4 of decision no 541/2014/eu of th...
# 278  [legal commitments for grants implementing the...
# 279  [this regulation shall be reviewed whenever it...
# 280  [regulation (eu, euratom) no 966/2012 is repea...
# 281  [this regulation shall enter into force on the...
#
# [282 rows x 4 columns]

# %%
final_dataframe = pd.read_csv(r'C:\Users\Student\Desktop\Thesis-Coding\coreferenced_final_dataframe.csv')

# %%
final_dataframe = final_dataframe[["Title","Articles","Content","coreference_list_ready"]]
final_dataframe
# Out:
#                                                  Title  \
# 0    TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 1    TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 2    TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 3    TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 4    TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# ..                                                 ...
# 277  TITLE XVI \nINFORMATION REQUESTS AND DELEGATED...
# 278  TITLE XVI \nINFORMATION REQUESTS AND DELEGATED...
# 279  TITLE XVI \nINFORMATION REQUESTS AND DELEGATED...
# 280  TITLE XVI \nINFORMATION REQUESTS AND DELEGATED...
# 281  TITLE XVI \nINFORMATION REQUESTS AND DELEGATED...
#
#                                               Articles  \
# 0                           Article 1  Subject matter
# 1                              Article 2  Definitions
# 2    Article 3  Compliance of secondary legislation...
# 3           Article 4  Periods, dates and time limits
# 4              Article 5  Protection of personal data
# ..                                                 ...
# 277  Article 278  Amendment to Decision No 541/2014...
# 278              Article 279  Transitional provisions
# 279                               Article 280  Review
# 280                               Article 281  Repeal
# 281     Article 282  Entry into force and application
#
#                                                Content  \
# 0    ['\nThis Regulation lays down the rules for th...
# 1    [' ‘applicant’ means a natural person or an en...
# 2    [' \nProvisions concerning the implementation ...
# 3    ['\nUnless otherwise provided in this Regulati...
# 4    ['\nThis Regulation is without prejudice to Re...
# ..                                                 ...
# 277  ['\nIn Article 4 of Decision No 541/2014/EU of...
# 278  [' \nLegal commitments for grants implementing...
# 279  ['\nThis Regulation shall be reviewed whenever...
# 280  [' \nRegulation (EU, Euratom) No 966/2012 is r...
# 281  [' \nThis Regulation shall enter into force on...
#
#                                 coreference_list_ready
# 0    ['this regulation lays down the rules for the ...
# 1    ['‘applicant’ means a natural person or an ent...
# 2    ['provisions concerning the implementation of ...
# 3    ['unless otherwise provided in this regulation...
# 4    ['this regulation is without prejudice to regu...
# ..                                                 ...
# 277  ['in article 4 of decision no 541/2014/eu of t...
# 278  ['legal commitments for grants implementing th...
# 279  ['this regulation shall be reviewed whenever t...
# 280  ['regulation (eu, euratom) no 966/2012 is repe...
# 281  ['this regulation shall enter into force on th...
#
# [282 rows x 4 columns]

# %%
def convert_to_list(column):
    return column.apply(ast.literal_eval)

final_dataframe['Content'] = convert_to_list(final_dataframe['Content'])
final_dataframe['coreference_list_ready'] = convert_to_list(final_dataframe['coreference_list_ready'])

# %%
def remove_punct(text):
    pattern_a = r'\s\([a-z]\)'
    text = re.sub(pattern_a, '', text)
    cleaned = ""
    punctuation = '!@#$%^&*_-+={}[];"\'|<>,?/~`’‘'
    for i in text:
        if i not in punctuation:
            cleaned = cleaned + i 
    return cleaned.strip()

def keep_text_elements(text_list):
    cleaned_text_list = []
    if isinstance(text_list,list):
        for element in text_list:
            if len(re.findall(r'[a-zA-Z]', element)) > 1:
                cleaned_text_list.append(element)
    return cleaned_text_list

def triplet(propos):
    triplet = []
    tail = ''
    if propos.subject != None:
        triplet.append(str(propos.subject))
    if propos.verb != None:
        triplet.append(str(propos.verb))
    if propos.direct_object != None:
        tail = tail + str(propos.direct_object)
    if propos.complement != None:
        tail = tail + " " + str(propos.complement)
    if len(propos.adverbials) != 0:
        adverbial = ""
        for i in propos.adverbials:
            adverbial = adverbial + " " + str(i)
        adverbial = adverbial.strip()
        tail = tail + " " + adverbial.strip()
    triplet.append(tail)
    
    return triplet


def all_triplets(propositions_list):
    triplet_list = []
    for proposition in propositions_list:
        triplet_instance = triplet(proposition)
        k = False
        for i in triplet_instance:
            if len(i)==1:
                k = True
        if len(triplet_instance)==3 and not k and '' not in triplet_instance:
            triplet_list.append(triplet(proposition))
    if len(triplet_list) != 0:
       return triplet_list       


def obtain_proposition_list(complex_sentence):
    import claucy

    nlp = spacy.load("en_core_web_sm")
    claucy.add_to_pipe(nlp)

    doc = nlp(complex_sentence)

    propositions = doc._.clauses

    return all_triplets(propositions)

# %%
import time


titles_list = []
for title in final_dataframe["Title"].unique():
    start_time = time.time()
    dataframe_title = final_dataframe[final_dataframe["Title"]==title].explode('coreference_list_ready')
    dataframe_title['coreference_list_ready'] = dataframe_title['coreference_list_ready'].apply(remove_punct)
    dataframe_title['Cleaned_Content_new'] = dataframe_title['coreference_list_ready'].apply(lambda x: x.split('.'))
    dataframe_title['Cleaned_Content_new'] = dataframe_title['Cleaned_Content_new'].apply(keep_text_elements)
    dataframe_title = dataframe_title.explode('Cleaned_Content_new')
    dataframe_title['triplets_list'] = dataframe_title['Cleaned_Content_new'].apply(obtain_proposition_list)
    titles_list.append(dataframe_title)
    elapsed_time = time.time() - start_time
    print(f"Processed title '{title}' in {elapsed_time:.2f} seconds.")

triplets_dataframe = pd.concat(titles_list, ignore_index=True, axis=0)
triplets_dataframe
# Out:
# Processed title 'TITLE I
# SUBJECT MATTER, DEFINITIONS AND GENERAL PRINCIPLES ' in 95.10 seconds.
# Processed title 'TITLE II
# BUDGET AND BUDGETARY PRINCIPLES ' in 260.79 seconds.
# Processed title 'TITLE III
# ESTABLISHMENT AND STRUCTURE OF THE BUDGET ' in 113.33 seconds.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[60], line 12
#      10 dataframe_title['Cleaned_Content_new'] = dataframe_title['Cleaned_Content_new'].apply(keep_text_elements)
#      11 dataframe_title = dataframe_title.explode('Cleaned_Content_new')
# ---> 12 dataframe_title['triplets_list'] = dataframe_title['Cleaned_Content_new'].apply(obtain_proposition_list)
#      13 titles_list.append(dataframe_title)
#      14 elapsed_time = time.time() - start_time
#
# File c:\Users\Student\Desktop\Thesis-Coding\.venv\Lib\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# File c:\Users\Student\Desktop\Thesis-Coding\.venv\Lib\site-packages\pandas\core\apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File c:\Users\Student\Desktop\Thesis-Coding\.venv\Lib\site-packages\pandas\core\apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File c:\Users\Student\Desktop\Thesis-Coding\.venv\Lib\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File c:\Users\Student\Desktop\Thesis-Coding\.venv\Lib\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[58], line 58, in obtain_proposition_list(complex_sentence)
#      55 def obtain_proposition_list(complex_sentence):
#      56     import claucy
# ---> 58     nlp = spacy.load("en_core_web_sm")
#      59     claucy.add_to_pipe(nlp)
#      61     doc = nlp(complex_sentence)
#
# File c:\Users\Student\Desktop\Thesis-Coding\.venv\Lib\site-packages\spacy\__init__.py:51, in load(name, vocab, disable, enable, exclude, config)
#      27 def load(
#      28     name: Union[str, Path],
#      29     *,
#    (...)
#      34     config: Union[Dict[str, Any], Config] = util.SimpleFrozenDict(),
#      35 ) -> Language:
#      36     """Load a spaCy model from an installed package or a local path.
#      37
#      38     name (str): Package name or model path.
#    (...)
#      49     RETURNS (Language): The loaded nlp object.
#      50     """
# ---> 51     return util.load_model(
#      52         name,
#      53         vocab=vocab,
#      54         disable=disable,
#      55         enable=enable,
#      56         exclude=exclude,
#      57         config=config,
#      58     )
#
# File c:\Users\Student\Desktop\Thesis-Coding\.venv\Lib\site-packages\spacy\util.py:465, in load_model(name, vocab, disable, enable, exclude, config)
#     463     return get_lang_class(name.replace("blank:", ""))()
#     464 if is_package(name):  # installed as package
# --> 465     return load_model_from_package(name, **kwargs)  # type: ignore[arg-type]
#     466 if Path(name).exists():  # path to model data directory
#     467     return load_model_from_path(Path(name), **kwargs)  # type: ignore[arg-type]
#
# File c:\Users\Student\Desktop\Thesis-Coding\.venv\Lib\site-packages\spacy\util.py:501, in load_model_from_package(name, vocab, disable, enable, exclude, config)
#     484 """Load a model from an installed package.
#     485
#     486 name (str): The package name.
#    (...)
#     498 RETURNS (Language): The loaded nlp object.
#     499 """
#     500 cls = importlib.import_module(name)
# --> 501 return cls.load(vocab=vocab, disable=disable, enable=enable, exclude=exclude, config=config)
#
# File c:\Users\Student\Desktop\Thesis-Coding\.venv\Lib\site-packages\en_core_web_sm\__init__.py:10, in load(**overrides)
#       9 def load(**overrides):
# ---> 10     return load_model_from_init_py(__file__, **overrides)
#
# File c:\Users\Student\Desktop\Thesis-Coding\.venv\Lib\site-packages\spacy\util.py:682, in load_model_from_init_py(init_file, vocab, disable, enable, exclude, config)
#     680 if not model_path.exists():
#     681     raise IOError(Errors.E052.format(path=data_path))
# --> 682 return load_model_from_path(
#     683     data_path,
#     684     vocab=vocab,
#     685     meta=meta,
#     686     disable=disable,
#     687     enable=enable,
#     688     exclude=exclude,
#     689     config=config,
#     690 )
#
# File c:\Users\Student\Desktop\Thesis-Coding\.venv\Lib\site-packages\spacy\util.py:547, in load_model_from_path(model_path, meta, vocab, disable, enable, exclude, config)
#     538 config = load_config(config_path, overrides=overrides)
#     539 nlp = load_model_from_config(
#     540     config,
#     541     vocab=vocab,
#    (...)
#     545     meta=meta,
#     546 )
# --> 547 return nlp.from_disk(model_path, exclude=exclude, overrides=overrides)
#
# File c:\Users\Student\Desktop\Thesis-Coding\.venv\Lib\site-packages\spacy\language.py:2246, in Language.from_disk(self, path, exclude, overrides)
#    2243 if not (path / "vocab").exists() and "vocab" not in exclude:  # type: ignore[operator]
#    2244     # Convert to list here in case exclude is (default) tuple
#    2245     exclude = list(exclude) + ["vocab"]
# -> 2246 util.from_disk(path, deserializers, exclude)  # type: ignore[arg-type]
#    2247 self._path = path  # type: ignore[assignment]
#    2248 self._link_components()
#
# File c:\Users\Student\Desktop\Thesis-Coding\.venv\Lib\site-packages\spacy\util.py:1390, in from_disk(path, readers, exclude)
#    1387 for key, reader in readers.items():
#    1388     # Split to support file names like meta.json
#    1389     if key.split(".")[0] not in exclude:
# -> 1390         reader(path / key)
#    1391 return path
#
# File c:\Users\Student\Desktop\Thesis-Coding\.venv\Lib\site-packages\spacy\language.py:2222, in Language.from_disk.<locals>.deserialize_vocab(path)
#    2220 def deserialize_vocab(path: Path) -> None:
#    2221     if path.exists():
# -> 2222         self.vocab.from_disk(path, exclude=exclude)
#
# File c:\Users\Student\Desktop\Thesis-Coding\.venv\Lib\site-packages\spacy\vocab.pyx:553, in spacy.vocab.Vocab.from_disk()
#
# File c:\Users\Student\Desktop\Thesis-Coding\.venv\Lib\site-packages\spacy\vectors.pyx:718, in spacy.vectors.Vectors.from_disk()
#
# File c:\Users\Student\Desktop\Thesis-Coding\.venv\Lib\site-packages\spacy\util.py:1386, in from_disk(path, readers, exclude)
#    1381 def from_disk(
#    1382     path: Union[str, Path],
#    1383     readers: Dict[str, Callable[[Path], None]],
#    1384     exclude: Iterable[str],
#    1385 ) -> Path:
# -> 1386     path = ensure_path(path)
#    1387     for key, reader in readers.items():
#    1388         # Split to support file names like meta.json
#    1389         if key.split(".")[0] not in exclude:
#
# File c:\Users\Student\Desktop\Thesis-Coding\.venv\Lib\site-packages\spacy\util.py:389, in ensure_path(path)
#     381     """Set a custom Language class name that can be loaded via get_lang_class.
#     382
#     383     name (str): Name of Language class.
#     384     cls (Language): Language class.
#     385     """
#     386     registry.languages.register(name, func=cls)
# --> 389 def ensure_path(path: Any) -> Any:
#     390     """Ensure string is converted to a Path.
#     391
#     392     path (Any): Anything. If string, it's converted to Path.
#     393     RETURNS: Path or original argument.
#     394     """
#     395     if isinstance(path, str):
#
# KeyboardInterrupt:

# %%
# Load triplets dataframe 
triplets_dataframe= pd.read_csv(r'C:\Users\Student\Desktop\Thesis-Coding\triplets_dataframe.csv')

# %%
triplets_dataframe
# Out:
#                                                   Title  \
# 0     TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 1     TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 2     TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 3     TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 4     TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# ...                                                 ...
# 2391  TITLE XVI \nINFORMATION REQUESTS AND DELEGATED...
# 2392  TITLE XVI \nINFORMATION REQUESTS AND DELEGATED...
# 2393  TITLE XVI \nINFORMATION REQUESTS AND DELEGATED...
# 2394  TITLE XVI \nINFORMATION REQUESTS AND DELEGATED...
# 2395  TITLE XVI \nINFORMATION REQUESTS AND DELEGATED...
#
#                                             Articles  \
# 0                         Article 1  Subject matter
# 1                            Article 2  Definitions
# 2                            Article 2  Definitions
# 3                            Article 2  Definitions
# 4                            Article 2  Definitions
# ...                                              ...
# 2391  Article 282  Entry into force and application
# 2392  Article 282  Entry into force and application
# 2393  Article 282  Entry into force and application
# 2394  Article 282  Entry into force and application
# 2395  Article 282  Entry into force and application
#
#                                                 Content  \
# 0     ['\nThis Regulation lays down the rules for th...
# 1     [' ‘applicant’ means a natural person or an en...
# 2     [' ‘applicant’ means a natural person or an en...
# 3     [' ‘applicant’ means a natural person or an en...
# 4     [' ‘applicant’ means a natural person or an en...
# ...                                                 ...
# 2391  [' \nThis Regulation shall enter into force on...
# 2392  [' \nThis Regulation shall enter into force on...
# 2393  [' \nThis Regulation shall enter into force on...
# 2394  [' \nThis Regulation shall enter into force on...
# 2395  [' \nThis Regulation shall enter into force on...
#
#                                  coreference_list_ready  \
# 0     this regulation lays down the rules for the es...
# 1     applicant means a natural person or an entity ...
# 2     application document means a tender a request ...
# 3     award procedure means a procurement procedure ...
# 4     basic act means a legal act other than a recom...
# ...                                                 ...
# 2391  by way of derogation from paragraph 2 of this ...
# 2392  by way of derogation from paragraph 2 of this ...
# 2393  by way of derogation from paragraph 2 of this ...
# 2394  by way of derogation from paragraph 2 of this ...
# 2395  by way of derogation from paragraph 2 of this ...
#
#                                     Cleaned_Content_new  \
# 0     this regulation lays down the rules for the es...
# 1     applicant means a natural person or an entity ...
# 2     application document means a tender a request ...
# 3     award procedure means a procurement procedure ...
# 4     basic act means a legal act other than a recom...
# ...                                                 ...
# 2391   this regulation shall be binding in this regu...
# 2392                      done at brussels 18 july 2018
# 2393        for the european parliament the president a
# 2394             tajani for the council the president j
# 2395                             bognerstrauss l 193186
#
#                                           triplets_list
# 0     [['this regulation', 'lays', 'the rules for th...
# 1     [['applicant', 'means', 'a natural person or a...
# 2     [['application document', 'means', 'a tender a...
# 3     [['award procedure', 'means', 'a procurement p...
# 4     [['basic act', 'means', 'a legal act other tha...
# ...                                                 ...
# 2391  [['this regulation', 'be', ' binding in this r...
# 2392                                                NaN
# 2393                                                NaN
# 2394                                                NaN
# 2395                                                NaN
#
# [2396 rows x 6 columns]

# %%
triplets_dataframe.iloc[0,2]
# Out:
# "['\\nThis Regulation lays down the rules for the establishment and the implementation of the general budget of the European \\nUnion and of the European Atomic Energy Community (‘the budget’) and the presentation and auditing of their accounts. ']"

# %%
triplets_dataframe.isna().sum()
# Out:
# Title                       0
# Articles                    0
# Content                     0
# coreference_list_ready      0
# Cleaned_Content_new         0
# triplets_list             173
# dtype: int64

# %%
triplets_dataframe_cleaned = triplets_dataframe.dropna()

# %%
def convert_to_list(column):
    return column.apply(ast.literal_eval)

triplets_dataframe_cleaned['Content'] = convert_to_list(triplets_dataframe_cleaned['Content'])
triplets_dataframe_cleaned['triplets_list'] = convert_to_list(triplets_dataframe_cleaned['triplets_list'])
# Out:
# C:\Users\Student\AppData\Local\Temp\ipykernel_2932\950390277.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   triplets_dataframe_cleaned['Content'] = convert_to_list(triplets_dataframe_cleaned['Content'])
# C:\Users\Student\AppData\Local\Temp\ipykernel_2932\950390277.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   triplets_dataframe_cleaned['triplets_list'] = convert_to_list(triplets_dataframe_cleaned['triplets_list'])

# %%
triplets_dataframe_cleaned['Title'].unique()
# Out:
# array(['TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENERAL PRINCIPLES ',
#        'TITLE II \nBUDGET AND BUDGETARY PRINCIPLES ',
#        'TITLE III \nESTABLISHMENT AND STRUCTURE OF THE BUDGET ',
#        'TITLE IV \nBUDGET IMPLEMENTATION ', 'TITLE V \nCOMMON RULES ',
#        'TITLE VI \nINDIRECT MANAGEMENT ',
#        'TITLE VII \nPROCUREMENT AND CONCESSIONS ', 'TITLE VIII \nGRANTS ',
#        'TITLE IX \nPRIZES ',
#        'TITLE X \nFINANCIAL INSTRUMENTS, BUDGETARY GUARANTEES AND FINANCIAL ASSISTANCE ',
#        'TITLE XI \nCONTRIBUTIONS TO EUROPEAN POLITICAL PARTIES ',
#        'TITLE XII \nOTHER BUDGET IMPLEMENTATION INSTRUMENTS ',
#        'TITLE XIII \nANNUAL ACCOUNTS AND OTHER FINANCIAL REPORTING ',
#        'TITLE XIV \nEXTERNAL AUDIT AND DISCHARGE ',
#        'TITLE XV \nADMINISTRATIVE APPROPRIATIONS ',
#        'TITLE XVI \nINFORMATION REQUESTS AND DELEGATED ACTS '],
#       dtype=object)

# %%
triplets_dataframe_cleaned['empty_list'] = triplets_dataframe_cleaned['triplets_list'].apply(lambda x: len(x)==0)
triplets_dataframe_cleaned['empty_list'].sum()
# Out:
# C:\Users\Student\AppData\Local\Temp\ipykernel_2932\2587516709.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   triplets_dataframe_cleaned['empty_list'] = triplets_dataframe_cleaned['triplets_list'].apply(lambda x: len(x)==0)
# np.int64(0)

# %%
triplets_dataframe_cleaned
# Out:
#                                                   Title  \
# 0     TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 1     TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 2     TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 3     TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 4     TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# ...                                                 ...
# 2387  TITLE XVI \nINFORMATION REQUESTS AND DELEGATED...
# 2388  TITLE XVI \nINFORMATION REQUESTS AND DELEGATED...
# 2389  TITLE XVI \nINFORMATION REQUESTS AND DELEGATED...
# 2390  TITLE XVI \nINFORMATION REQUESTS AND DELEGATED...
# 2391  TITLE XVI \nINFORMATION REQUESTS AND DELEGATED...
#
#                                             Articles  \
# 0                         Article 1  Subject matter
# 1                            Article 2  Definitions
# 2                            Article 2  Definitions
# 3                            Article 2  Definitions
# 4                            Article 2  Definitions
# ...                                              ...
# 2387                            Article 281  Repeal
# 2388  Article 282  Entry into force and application
# 2389  Article 282  Entry into force and application
# 2390  Article 282  Entry into force and application
# 2391  Article 282  Entry into force and application
#
#                                                 Content  \
# 0     [\nThis Regulation lays down the rules for the...
# 1     [ ‘applicant’ means a natural person or an ent...
# 2     [ ‘applicant’ means a natural person or an ent...
# 3     [ ‘applicant’ means a natural person or an ent...
# 4     [ ‘applicant’ means a natural person or an ent...
# ...                                                 ...
# 2387  [ \nRegulation (EU, Euratom) No 966/2012 is re...
# 2388  [ \nThis Regulation shall enter into force on ...
# 2389  [ \nThis Regulation shall enter into force on ...
# 2390  [ \nThis Regulation shall enter into force on ...
# 2391  [ \nThis Regulation shall enter into force on ...
#
#                                  coreference_list_ready  \
# 0     this regulation lays down the rules for the es...
# 1     applicant means a natural person or an entity ...
# 2     application document means a tender a request ...
# 3     award procedure means a procurement procedure ...
# 4     basic act means a legal act other than a recom...
# ...                                                 ...
# 2387  references to the repealed regulation shall be...
# 2388  this regulation shall enter into force on the ...
# 2389    this regulation shall apply from 2 august 2018.
# 2390  by way of derogation from paragraph 2 of this ...
# 2391  by way of derogation from paragraph 2 of this ...
#
#                                     Cleaned_Content_new  \
# 0     this regulation lays down the rules for the es...
# 1     applicant means a natural person or an entity ...
# 2     application document means a tender a request ...
# 3     award procedure means a procurement procedure ...
# 4     basic act means a legal act other than a recom...
# ...                                                 ...
# 2387  references to the repealed regulation shall be...
# 2388  this regulation shall enter into force on the ...
# 2389     this regulation shall apply from 2 august 2018
# 2390  by way of derogation from paragraph 2 of this ...
# 2391   this regulation shall be binding in this regu...
#
#                                           triplets_list  empty_list
# 0     [[this regulation, lays, the rules for the est...       False
# 1     [[applicant, means, a natural person or an ent...       False
# 2     [[application document, means, a tender a requ...       False
# 3     [[award procedure, means, a procurement proced...       False
# 4     [[basic act, means, a legal act other than a r...       False
# ...                                                 ...         ...
# 2387  [[references to the repealed regulation, be co...       False
# 2388  [[this regulation, shall enter,  into force on...       False
# 2389  [[this regulation, shall apply,  from 2 august...       False
# 2390  [[(17) (18) (22) and (23) article 272(26)(d) a...       False
# 2391  [[this regulation, be,  binding in this regula...       False
#
# [2223 rows x 7 columns]

# %%
triplets_dataframe_cleaned.iloc[0,5]
# Out:
# [['this regulation',
#   'lays',
#   'the rules for the establishment and the implementation of the general budget of the european union and of the european atomic energy community (the budget) and the presentation and auditing of the european union and of the european atomic energy community accounts']]

# %%
triplets_dataframe_cleaned['many_triplets'] = triplets_dataframe_cleaned['triplets_list'].apply(lambda x: len(x)>1)
triplets_dataframe_cleaned['many_triplets'].sum()
# Out:
# C:\Users\Student\AppData\Local\Temp\ipykernel_2932\1455361532.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   triplets_dataframe_cleaned['many_triplets'] = triplets_dataframe_cleaned['triplets_list'].apply(lambda x: len(x)>1)
# np.int64(1203)

# %%
# coreference resolution required ? 

triplets_dataframe_cleaned.iloc[509,5]
# Out:
# [['who', 'carry', 'the verification'],
#  [' the staff who carry out the verification',
#   'be',
#   ' subordinate to the members of staff who initiated a given operation'],
#  ['who', 'initiated', 'a given operation']]

# %%
triplets_dataframe_cleaned
# Out:
#                                                   Title  \
# 0     TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 1     TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 2     TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 3     TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 4     TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# ...                                                 ...
# 2387  TITLE XVI \nINFORMATION REQUESTS AND DELEGATED...
# 2388  TITLE XVI \nINFORMATION REQUESTS AND DELEGATED...
# 2389  TITLE XVI \nINFORMATION REQUESTS AND DELEGATED...
# 2390  TITLE XVI \nINFORMATION REQUESTS AND DELEGATED...
# 2391  TITLE XVI \nINFORMATION REQUESTS AND DELEGATED...
#
#                                             Articles  \
# 0                         Article 1  Subject matter
# 1                            Article 2  Definitions
# 2                            Article 2  Definitions
# 3                            Article 2  Definitions
# 4                            Article 2  Definitions
# ...                                              ...
# 2387                            Article 281  Repeal
# 2388  Article 282  Entry into force and application
# 2389  Article 282  Entry into force and application
# 2390  Article 282  Entry into force and application
# 2391  Article 282  Entry into force and application
#
#                                                 Content  \
# 0     [\nThis Regulation lays down the rules for the...
# 1     [ ‘applicant’ means a natural person or an ent...
# 2     [ ‘applicant’ means a natural person or an ent...
# 3     [ ‘applicant’ means a natural person or an ent...
# 4     [ ‘applicant’ means a natural person or an ent...
# ...                                                 ...
# 2387  [ \nRegulation (EU, Euratom) No 966/2012 is re...
# 2388  [ \nThis Regulation shall enter into force on ...
# 2389  [ \nThis Regulation shall enter into force on ...
# 2390  [ \nThis Regulation shall enter into force on ...
# 2391  [ \nThis Regulation shall enter into force on ...
#
#                                  coreference_list_ready  \
# 0     this regulation lays down the rules for the es...
# 1     applicant means a natural person or an entity ...
# 2     application document means a tender a request ...
# 3     award procedure means a procurement procedure ...
# 4     basic act means a legal act other than a recom...
# ...                                                 ...
# 2387  references to the repealed regulation shall be...
# 2388  this regulation shall enter into force on the ...
# 2389    this regulation shall apply from 2 august 2018.
# 2390  by way of derogation from paragraph 2 of this ...
# 2391  by way of derogation from paragraph 2 of this ...
#
#                                     Cleaned_Content_new  \
# 0     this regulation lays down the rules for the es...
# 1     applicant means a natural person or an entity ...
# 2     application document means a tender a request ...
# 3     award procedure means a procurement procedure ...
# 4     basic act means a legal act other than a recom...
# ...                                                 ...
# 2387  references to the repealed regulation shall be...
# 2388  this regulation shall enter into force on the ...
# 2389     this regulation shall apply from 2 august 2018
# 2390  by way of derogation from paragraph 2 of this ...
# 2391   this regulation shall be binding in this regu...
#
#                                           triplets_list  empty_list  \
# 0     [[this regulation, lays, the rules for the est...       False
# 1     [[applicant, means, a natural person or an ent...       False
# 2     [[application document, means, a tender a requ...       False
# 3     [[award procedure, means, a procurement proced...       False
# 4     [[basic act, means, a legal act other than a r...       False
# ...                                                 ...         ...
# 2387  [[references to the repealed regulation, be co...       False
# 2388  [[this regulation, shall enter,  into force on...       False
# 2389  [[this regulation, shall apply,  from 2 august...       False
# 2390  [[(17) (18) (22) and (23) article 272(26)(d) a...       False
# 2391  [[this regulation, be,  binding in this regula...       False
#
#       many_triplets
# 0             False
# 1              True
# 2             False
# 3             False
# 4              True
# ...             ...
# 2387           True
# 2388          False
# 2389          False
# 2390           True
# 2391          False
#
# [2223 rows x 8 columns]

# %%
triplets_df_all = triplets_dataframe_cleaned.explode("triplets_list")

# %%
triplets_df_all
# Out:
#                                                   Title  \
# 0     TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 1     TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 1     TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 2     TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 3     TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# ...                                                 ...
# 2390  TITLE XVI \nINFORMATION REQUESTS AND DELEGATED...
# 2390  TITLE XVI \nINFORMATION REQUESTS AND DELEGATED...
# 2390  TITLE XVI \nINFORMATION REQUESTS AND DELEGATED...
# 2390  TITLE XVI \nINFORMATION REQUESTS AND DELEGATED...
# 2391  TITLE XVI \nINFORMATION REQUESTS AND DELEGATED...
#
#                                             Articles  \
# 0                         Article 1  Subject matter
# 1                            Article 2  Definitions
# 1                            Article 2  Definitions
# 2                            Article 2  Definitions
# 3                            Article 2  Definitions
# ...                                              ...
# 2390  Article 282  Entry into force and application
# 2390  Article 282  Entry into force and application
# 2390  Article 282  Entry into force and application
# 2390  Article 282  Entry into force and application
# 2391  Article 282  Entry into force and application
#
#                                                 Content  \
# 0     [\nThis Regulation lays down the rules for the...
# 1     [ ‘applicant’ means a natural person or an ent...
# 1     [ ‘applicant’ means a natural person or an ent...
# 2     [ ‘applicant’ means a natural person or an ent...
# 3     [ ‘applicant’ means a natural person or an ent...
# ...                                                 ...
# 2390  [ \nThis Regulation shall enter into force on ...
# 2390  [ \nThis Regulation shall enter into force on ...
# 2390  [ \nThis Regulation shall enter into force on ...
# 2390  [ \nThis Regulation shall enter into force on ...
# 2391  [ \nThis Regulation shall enter into force on ...
#
#                                  coreference_list_ready  \
# 0     this regulation lays down the rules for the es...
# 1     applicant means a natural person or an entity ...
# 1     applicant means a natural person or an entity ...
# 2     application document means a tender a request ...
# 3     award procedure means a procurement procedure ...
# ...                                                 ...
# 2390  by way of derogation from paragraph 2 of this ...
# 2390  by way of derogation from paragraph 2 of this ...
# 2390  by way of derogation from paragraph 2 of this ...
# 2390  by way of derogation from paragraph 2 of this ...
# 2391  by way of derogation from paragraph 2 of this ...
#
#                                     Cleaned_Content_new  \
# 0     this regulation lays down the rules for the es...
# 1     applicant means a natural person or an entity ...
# 1     applicant means a natural person or an entity ...
# 2     application document means a tender a request ...
# 3     award procedure means a procurement procedure ...
# ...                                                 ...
# 2390  by way of derogation from paragraph 2 of this ...
# 2390  by way of derogation from paragraph 2 of this ...
# 2390  by way of derogation from paragraph 2 of this ...
# 2390  by way of derogation from paragraph 2 of this ...
# 2391   this regulation shall be binding in this regu...
#
#                                           triplets_list  empty_list  \
# 0     [this regulation, lays, the rules for the esta...       False
# 1     [applicant, means, a natural person or an enti...       False
# 1     [who, has submitted, an application in a grant...       False
# 2     [application document, means, a tender a reque...       False
# 3     [award procedure, means, a procurement procedu...       False
# ...                                                 ...         ...
# 2390  [(17) (18) (22) and (23) article 272(26)(d) ar...       False
# 2390  [(17) (18) (22) and (23) article 272(26)(d) ar...       False
# 2390  [(17) (18) (22) and (23) article 272(26)(d) ar...       False
# 2390  [the information on the estimated amount of as...       False
# 2391  [this regulation, be,  binding in this regulat...       False
#
#       many_triplets
# 0             False
# 1              True
# 1              True
# 2             False
# 3             False
# ...             ...
# 2390           True
# 2390           True
# 2390           True
# 2390           True
# 2391          False
#
# [4630 rows x 8 columns]

# %%
example_list = triplets_df_all.iloc[850,5]

# %%
# English pipelines include a rule-based lemmatizer
nlp = spacy.load("en_core_web_sm")
lemmatizer = nlp.get_pipe("lemmatizer")
# print(lemmatizer.mode)  # 'rule'

# doc = nlp("respecting")
# print(" ".join([token.lemma_ for token in doc]))
# ['I', 'be', 'read', 'the', 'paper', '.']

def lemmatize(text):
    doc = nlp(text)
    return " ".join([token.lemma_ for token in doc])

def lemmatize_sec_element(triplet):
    triplet[1] = lemmatize(triplet[1])
    return triplet

# %%
lemmatize("respecting")
# Out:
# 'respect'

# %%
triplets_df_all['triplets_list'] = triplets_df_all['triplets_list'].apply(lemmatize_sec_element)

# %% [markdown]
# # Remove heads that are stopwords

# %%
triplets_df_all.iloc[1555,5]
# Out:
# ['this', 'be consider', ' as an interruption of the limitation period']

# %%
triplets_df_all.iloc[1831,5]
# Out:
# ['the internal auditor',
#  'shall enjoy',
#  'complete independence in the conduct of the audits']

# %%
triplets_df_all["head"] = triplets_df_all["triplets_list"].apply(lambda x: x[0].strip())
triplets_df_all["relation"] = triplets_df_all["triplets_list"].apply(lambda x: x[1].strip())
triplets_df_all["tail"] = triplets_df_all["triplets_list"].apply(lambda x: x[2].strip())

# %%
triplets_df_all
# Out:
#                                                   Title  \
# 0     TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 1     TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 1     TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 2     TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 3     TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# ...                                                 ...
# 2390  TITLE XVI \nINFORMATION REQUESTS AND DELEGATED...
# 2390  TITLE XVI \nINFORMATION REQUESTS AND DELEGATED...
# 2390  TITLE XVI \nINFORMATION REQUESTS AND DELEGATED...
# 2390  TITLE XVI \nINFORMATION REQUESTS AND DELEGATED...
# 2391  TITLE XVI \nINFORMATION REQUESTS AND DELEGATED...
#
#                                             Articles  \
# 0                         Article 1  Subject matter
# 1                            Article 2  Definitions
# 1                            Article 2  Definitions
# 2                            Article 2  Definitions
# 3                            Article 2  Definitions
# ...                                              ...
# 2390  Article 282  Entry into force and application
# 2390  Article 282  Entry into force and application
# 2390  Article 282  Entry into force and application
# 2390  Article 282  Entry into force and application
# 2391  Article 282  Entry into force and application
#
#                                                 Content  \
# 0     [\nThis Regulation lays down the rules for the...
# 1     [ ‘applicant’ means a natural person or an ent...
# 1     [ ‘applicant’ means a natural person or an ent...
# 2     [ ‘applicant’ means a natural person or an ent...
# 3     [ ‘applicant’ means a natural person or an ent...
# ...                                                 ...
# 2390  [ \nThis Regulation shall enter into force on ...
# 2390  [ \nThis Regulation shall enter into force on ...
# 2390  [ \nThis Regulation shall enter into force on ...
# 2390  [ \nThis Regulation shall enter into force on ...
# 2391  [ \nThis Regulation shall enter into force on ...
#
#                                  coreference_list_ready  \
# 0     this regulation lays down the rules for the es...
# 1     applicant means a natural person or an entity ...
# 1     applicant means a natural person or an entity ...
# 2     application document means a tender a request ...
# 3     award procedure means a procurement procedure ...
# ...                                                 ...
# 2390  by way of derogation from paragraph 2 of this ...
# 2390  by way of derogation from paragraph 2 of this ...
# 2390  by way of derogation from paragraph 2 of this ...
# 2390  by way of derogation from paragraph 2 of this ...
# 2391  by way of derogation from paragraph 2 of this ...
#
#                                     Cleaned_Content_new  \
# 0     this regulation lays down the rules for the es...
# 1     applicant means a natural person or an entity ...
# 1     applicant means a natural person or an entity ...
# 2     application document means a tender a request ...
# 3     award procedure means a procurement procedure ...
# ...                                                 ...
# 2390  by way of derogation from paragraph 2 of this ...
# 2390  by way of derogation from paragraph 2 of this ...
# 2390  by way of derogation from paragraph 2 of this ...
# 2390  by way of derogation from paragraph 2 of this ...
# 2391   this regulation shall be binding in this regu...
#
#                                           triplets_list  empty_list  \
# 0     [this regulation, lay, the rules for the estab...       False
# 1     [applicant, mean, a natural person or an entit...       False
# 1     [who, have submit, an application in a grant a...       False
# 2     [application document, mean, a tender a reques...       False
# 3     [award procedure, mean, a procurement procedur...       False
# ...                                                 ...         ...
# 2390  [(17) (18) (22) and (23) article 272(26)(d) ar...       False
# 2390  [(17) (18) (22) and (23) article 272(26)(d) ar...       False
# 2390  [(17) (18) (22) and (23) article 272(26)(d) ar...       False
# 2390  [the information on the estimated amount of as...       False
# 2391  [this regulation, be,  binding in this regulat...       False
#
#       many_triplets                                               head  \
# 0             False                                    this regulation
# 1              True                                          applicant
# 1              True                                                who
# 2             False                               application document
# 3             False                                    award procedure
# ...             ...                                                ...
# 2390           True  (17) (18) (22) and (23) article 272(26)(d) art...
# 2390           True  (17) (18) (22) and (23) article 272(26)(d) art...
# 2390           True  (17) (18) (22) and (23) article 272(26)(d) art...
# 2390           True  the information on the estimated amount of ass...
# 2391          False                                    this regulation
#
#          relation                                               tail
# 0             lay  the rules for the establishment and the implem...
# 1            mean  a natural person or an entity with or without ...
# 1     have submit  an application in a grant award procedure or i...
# 2            mean  a tender a request to participate a grant appl...
# 3            mean  a procurement procedure a grant award procedur...
# ...           ...                                                ...
# 2390      article                         212 and 213 article 214(2)
# 2390      article                                    218 219 and 220
# 2390  shall apply  the information on the annual average of fullt...
# 2390   be provide  for the first time together with the draft bud...
# 2391           be  binding in this regulation entirety and direct...
#
# [4630 rows x 11 columns]

# %%
triplets_df_all.iloc[0,8]
# Out:
# 'this regulation'

# %%
stop_words = spacy.lang.en.stop_words.STOP_WORDS

# %%
stop_words
# Out:
# {"'d",
#  "'ll",
#  "'m",
#  "'re",
#  "'s",
#  "'ve",
#  'a',
#  'about',
#  'above',
#  'across',
#  'after',
#  'afterwards',
#  'again',
#  'against',
#  'all',
#  'almost',
#  'alone',
#  'along',
#  'already',
#  'also',
#  'although',
#  'always',
#  'am',
#  'among',
#  'amongst',
#  'amount',
#  'an',
#  'and',
#  'another',
#  'any',
#  'anyhow',
#  'anyone',
#  'anything',
#  'anyway',
#  'anywhere',
#  'are',
#  'around',
#  'as',
#  'at',
#  'back',
#  'be',
#  'became',
#  'because',
#  'become',
#  'becomes',
#  'becoming',
#  'been',
#  'before',
#  'beforehand',
#  'behind',
#  'being',
#  'below',
#  'beside',
#  'besides',
#  'between',
#  'beyond',
#  'both',
#  'bottom',
#  'but',
#  'by',
#  'ca',
#  'call',
#  'can',
#  'cannot',
#  'could',
#  'did',
#  'do',
#  'does',
#  'doing',
#  'done',
#  'down',
#  'due',
#  'during',
#  'each',
#  'eight',
#  'either',
#  'eleven',
#  'else',
#  'elsewhere',
#  'empty',
#  'enough',
#  'even',
#  'ever',
#  'every',
#  'everyone',
#  'everything',
#  'everywhere',
#  'except',
#  'few',
#  'fifteen',
#  'fifty',
#  'first',
#  'five',
#  'for',
#  'former',
#  'formerly',
#  'forty',
#  'four',
#  'from',
#  'front',
#  'full',
#  'further',
#  'get',
#  'give',
#  'go',
#  'had',
#  'has',
#  'have',
#  'he',
#  'hence',
#  'her',
#  'here',
#  'hereafter',
#  'hereby',
#  'herein',
#  'hereupon',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'however',
#  'hundred',
#  'i',
#  'if',
#  'in',
#  'indeed',
#  'into',
#  'is',
#  'it',
#  'its',
#  'itself',
#  'just',
#  'keep',
#  'last',
#  'latter',
#  'latterly',
#  'least',
#  'less',
#  'made',
#  'make',
#  'many',
#  'may',
#  'me',
#  'meanwhile',
#  'might',
#  'mine',
#  'more',
#  'moreover',
#  'most',
#  'mostly',
#  'move',
#  'much',
#  'must',
#  'my',
#  'myself',
#  "n't",
#  'name',
#  'namely',
#  'neither',
#  'never',
#  'nevertheless',
#  'next',
#  'nine',
#  'no',
#  'nobody',
#  'none',
#  'noone',
#  'nor',
#  'not',
#  'nothing',
#  'now',
#  'nowhere',
#  'n‘t',
#  'n’t',
#  'of',
#  'off',
#  'often',
#  'on',
#  'once',
#  'one',
#  'only',
#  'onto',
#  'or',
#  'other',
#  'others',
#  'otherwise',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  'part',
#  'per',
#  'perhaps',
#  'please',
#  'put',
#  'quite',
#  'rather',
#  're',
#  'really',
#  'regarding',
#  'same',
#  'say',
#  'see',
#  'seem',
#  'seemed',
#  'seeming',
#  'seems',
#  'serious',
#  'several',
#  'she',
#  'should',
#  'show',
#  'side',
#  'since',
#  'six',
#  'sixty',
#  'so',
#  'some',
#  'somehow',
#  'someone',
#  'something',
#  'sometime',
#  'sometimes',
#  'somewhere',
#  'still',
#  'such',
#  'take',
#  'ten',
#  'than',
#  'that',
#  'the',
#  'their',
#  'them',
#  'themselves',
#  'then',
#  'thence',
#  'there',
#  'thereafter',
#  'thereby',
#  'therefore',
#  'therein',
#  'thereupon',
#  'these',
#  'they',
#  'third',
#  'this',
#  'those',
#  'though',
#  'three',
#  'through',
#  'throughout',
#  'thru',
#  'thus',
#  'to',
#  'together',
#  'too',
#  'top',
#  'toward',
#  'towards',
#  'twelve',
#  'twenty',
#  'two',
#  'under',
#  'unless',
#  'until',
#  'up',
#  'upon',
#  'us',
#  'used',
#  'using',
#  'various',
#  'very',
#  'via',
#  'was',
#  'we',
#  'well',
#  'were',
#  'what',
#  'whatever',
#  'when',
#  'whence',
#  'whenever',
#  'where',
#  'whereafter',
#  'whereas',
#  'whereby',
#  'wherein',
#  'whereupon',
#  'wherever',
#  'whether',
#  'which',
#  'while',
#  'whither',
#  'who',
#  'whoever',
#  'whole',
#  'whom',
#  'whose',
#  'why',
#  'will',
#  'with',
#  'within',
#  'without',
#  'would',
#  'yet',
#  'you',
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  '‘d',
#  '‘ll',
#  '‘m',
#  '‘re',
#  '‘s',
#  '‘ve',
#  '’d',
#  '’ll',
#  '’m',
#  '’re',
#  '’s',
#  '’ve'}

# %%
def detect_stopwords(head_text):
    k = False
    for stopword in stop_words:
        if stopword == head_text:
            k = True
    return k

# %%
triplets_df_all["is_stopword"] = triplets_df_all["head"].apply(detect_stopwords)

# %%
triplets_df_all["is_stopword"].sum()
# Out:
# np.int64(541)

# %%
triplets_df_all[triplets_df_all["is_stopword"]==True]
# Out:
#                                                   Title  \
# 1     TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 4     TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 4     TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 9     TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 9     TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# ...                                                 ...
# 2327  TITLE XVI \nINFORMATION REQUESTS AND DELEGATED...
# 2338  TITLE XVI \nINFORMATION REQUESTS AND DELEGATED...
# 2349  TITLE XVI \nINFORMATION REQUESTS AND DELEGATED...
# 2380  TITLE XVI \nINFORMATION REQUESTS AND DELEGATED...
# 2390  TITLE XVI \nINFORMATION REQUESTS AND DELEGATED...
#
#                                                Articles  \
# 1                               Article 2  Definitions
# 4                               Article 2  Definitions
# 4                               Article 2  Definitions
# 9                               Article 2  Definitions
# 9                               Article 2  Definitions
# ...                                                 ...
# 2327  Article 275  Amendments to Regulation (EU) No ...
# 2338  Article 276  Amendments to Regulation (EU) No ...
# 2349  Article 276  Amendments to Regulation (EU) No ...
# 2380              Article 279  Transitional provisions
# 2390     Article 282  Entry into force and application
#
#                                                 Content  \
# 1     [ ‘applicant’ means a natural person or an ent...
# 4     [ ‘applicant’ means a natural person or an ent...
# 4     [ ‘applicant’ means a natural person or an ent...
# 9     [ ‘applicant’ means a natural person or an ent...
# 9     [ ‘applicant’ means a natural person or an ent...
# ...                                                 ...
# 2327  [ the following chapter is inserted: \n‘CHAPTE...
# 2338  [ in Article 9, the following paragraph is add...
# 2349  [ in Article 9, the following paragraph is add...
# 2380  [ \nLegal commitments for grants implementing ...
# 2390  [ \nThis Regulation shall enter into force on ...
#
#                                  coreference_list_ready  \
# 1     applicant means a natural person or an entity ...
# 4     basic act means a legal act other than a recom...
# 4     basic act means a legal act other than a recom...
# 9     budgetary guarantee means a legal commitment o...
# 9     budgetary guarantee means a legal commitment o...
# ...                                                 ...
# 2327  the following chapter is inserted: chapter va ...
# 2338  in article 9 the following paragraph is added:...
# 2349  in article 30(2) the fourth subparagraph is re...
# 2380  for financial contributions from the egf inclu...
# 2390  by way of derogation from paragraph 2 of this ...
#
#                                     Cleaned_Content_new  \
# 1     applicant means a natural person or an entity ...
# 4     basic act means a legal act other than a recom...
# 4     basic act means a legal act other than a recom...
# 9     budgetary guarantee means a legal commitment o...
# 9     budgetary guarantee means a legal commitment o...
# ...                                                 ...
# 2327   they shall: represent european added value re...
# 2338   that decision shall specify the date of that ...
# 2349  in article 30(2) the fourth subparagraph is re...
# 2380   where the provisions of title viii applicable...
# 2390  by way of derogation from paragraph 2 of this ...
#
#                                           triplets_list  empty_list  \
# 1     [who, have submit, an application in a grant a...       False
# 4     [which, provide, a legal basis for an action a...       False
# 4         [which, may take, any of the following forms]       False
# 9                                [that, be call,  upon]       False
# 9     [that, remain,  valid for the duration of the ...       False
# ...                                                 ...         ...
# 2327  [they, climate, change mitigation and adaptati...       False
# 2338  [which, be,  earlier than the date of that dec...       False
# 2349  [this, be,  as a result of fault or negligence...       False
# 2380  [this, be,  the case the provisions of title v...       False
# 2390  [this, be,  without prejudice to point of this...       False
#
#       many_triplets   head     relation  \
# 1              True    who  have submit
# 4              True  which      provide
# 4              True  which     may take
# 9              True   that      be call
# 9              True   that       remain
# ...             ...    ...          ...
# 2327           True   they      climate
# 2338           True  which           be
# 2349           True   this           be
# 2380           True   this           be
# 2390           True   this           be
#
#                                                    tail  is_stopword
# 1     an application in a grant award procedure or i...         True
# 4     a legal basis for an action and for the implem...         True
# 4                            any of the following forms         True
# 9                                                  upon         True
# 9     valid for the duration of the maturity of the ...         True
# ...                                                 ...          ...
# 2327    change mitigation and adaptation where possible         True
# 2338    earlier than the date of that decision adoption         True
# 2349  as a result of fault or negligence on the part...         True
# 2380  the case the provisions of title viii applicab...         True
# 2390  without prejudice to point of this paragraph p...         True
#
# [541 rows x 12 columns]

# %%
triplets_df_nostop =  triplets_df_all[triplets_df_all["is_stopword"]==False]
triplets_df_nostop
# Out:
#                                                   Title  \
# 0     TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 1     TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 2     TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 3     TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 4     TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# ...                                                 ...
# 2390  TITLE XVI \nINFORMATION REQUESTS AND DELEGATED...
# 2390  TITLE XVI \nINFORMATION REQUESTS AND DELEGATED...
# 2390  TITLE XVI \nINFORMATION REQUESTS AND DELEGATED...
# 2390  TITLE XVI \nINFORMATION REQUESTS AND DELEGATED...
# 2391  TITLE XVI \nINFORMATION REQUESTS AND DELEGATED...
#
#                                             Articles  \
# 0                         Article 1  Subject matter
# 1                            Article 2  Definitions
# 2                            Article 2  Definitions
# 3                            Article 2  Definitions
# 4                            Article 2  Definitions
# ...                                              ...
# 2390  Article 282  Entry into force and application
# 2390  Article 282  Entry into force and application
# 2390  Article 282  Entry into force and application
# 2390  Article 282  Entry into force and application
# 2391  Article 282  Entry into force and application
#
#                                                 Content  \
# 0     [\nThis Regulation lays down the rules for the...
# 1     [ ‘applicant’ means a natural person or an ent...
# 2     [ ‘applicant’ means a natural person or an ent...
# 3     [ ‘applicant’ means a natural person or an ent...
# 4     [ ‘applicant’ means a natural person or an ent...
# ...                                                 ...
# 2390  [ \nThis Regulation shall enter into force on ...
# 2390  [ \nThis Regulation shall enter into force on ...
# 2390  [ \nThis Regulation shall enter into force on ...
# 2390  [ \nThis Regulation shall enter into force on ...
# 2391  [ \nThis Regulation shall enter into force on ...
#
#                                  coreference_list_ready  \
# 0     this regulation lays down the rules for the es...
# 1     applicant means a natural person or an entity ...
# 2     application document means a tender a request ...
# 3     award procedure means a procurement procedure ...
# 4     basic act means a legal act other than a recom...
# ...                                                 ...
# 2390  by way of derogation from paragraph 2 of this ...
# 2390  by way of derogation from paragraph 2 of this ...
# 2390  by way of derogation from paragraph 2 of this ...
# 2390  by way of derogation from paragraph 2 of this ...
# 2391  by way of derogation from paragraph 2 of this ...
#
#                                     Cleaned_Content_new  \
# 0     this regulation lays down the rules for the es...
# 1     applicant means a natural person or an entity ...
# 2     application document means a tender a request ...
# 3     award procedure means a procurement procedure ...
# 4     basic act means a legal act other than a recom...
# ...                                                 ...
# 2390  by way of derogation from paragraph 2 of this ...
# 2390  by way of derogation from paragraph 2 of this ...
# 2390  by way of derogation from paragraph 2 of this ...
# 2390  by way of derogation from paragraph 2 of this ...
# 2391   this regulation shall be binding in this regu...
#
#                                           triplets_list  empty_list  \
# 0     [this regulation, lay, the rules for the estab...       False
# 1     [applicant, mean, a natural person or an entit...       False
# 2     [application document, mean, a tender a reques...       False
# 3     [award procedure, mean, a procurement procedur...       False
# 4     [basic act, mean, a legal act other than a rec...       False
# ...                                                 ...         ...
# 2390  [(17) (18) (22) and (23) article 272(26)(d) ar...       False
# 2390  [(17) (18) (22) and (23) article 272(26)(d) ar...       False
# 2390  [(17) (18) (22) and (23) article 272(26)(d) ar...       False
# 2390  [the information on the estimated amount of as...       False
# 2391  [this regulation, be,  binding in this regulat...       False
#
#       many_triplets                                               head  \
# 0             False                                    this regulation
# 1              True                                          applicant
# 2             False                               application document
# 3             False                                    award procedure
# 4              True                                          basic act
# ...             ...                                                ...
# 2390           True  (17) (18) (22) and (23) article 272(26)(d) art...
# 2390           True  (17) (18) (22) and (23) article 272(26)(d) art...
# 2390           True  (17) (18) (22) and (23) article 272(26)(d) art...
# 2390           True  the information on the estimated amount of ass...
# 2391          False                                    this regulation
#
#          relation                                               tail  \
# 0             lay  the rules for the establishment and the implem...
# 1            mean  a natural person or an entity with or without ...
# 2            mean  a tender a request to participate a grant appl...
# 3            mean  a procurement procedure a grant award procedur...
# 4            mean  a legal act other than a recommendation or an ...
# ...           ...                                                ...
# 2390      article                         212 and 213 article 214(2)
# 2390      article                                    218 219 and 220
# 2390  shall apply  the information on the annual average of fullt...
# 2390   be provide  for the first time together with the draft bud...
# 2391           be  binding in this regulation entirety and direct...
#
#       is_stopword
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
# ...           ...
# 2390        False
# 2390        False
# 2390        False
# 2390        False
# 2391        False
#
# [4089 rows x 12 columns]

# %%
triplets_df_nostop.groupby("Title")[["relation"]].count()
# Out:
#                                                     relation
# Title
# TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENER...       118
# TITLE II \nBUDGET AND BUDGETARY PRINCIPLES               370
# TITLE III \nESTABLISHMENT AND STRUCTURE OF THE ...       161
# TITLE IV \nBUDGET IMPLEMENTATION                        1009
# TITLE IX \nPRIZES                                         30
# TITLE V \nCOMMON RULES                                   428
# TITLE VI \nINDIRECT MANAGEMENT                           116
# TITLE VII \nPROCUREMENT AND CONCESSIONS                  182
# TITLE VIII \nGRANTS                                      321
# TITLE X \nFINANCIAL INSTRUMENTS, BUDGETARY GUAR...       193
# TITLE XI \nCONTRIBUTIONS TO EUROPEAN POLITICAL ...        96
# TITLE XII \nOTHER BUDGET IMPLEMENTATION INSTRUM...        96
# TITLE XIII \nANNUAL ACCOUNTS AND OTHER FINANCIA...        75
# TITLE XIV \nEXTERNAL AUDIT AND DISCHARGE                  93
# TITLE XV \nADMINISTRATIVE APPROPRIATIONS                  56
# TITLE XVI \nINFORMATION REQUESTS AND DELEGATED ...       745

# %%
triplets_df_nostop.groupby("Title")[["relation"]].nunique()
# Out:
#                                                     relation
# Title
# TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENER...        34
# TITLE II \nBUDGET AND BUDGETARY PRINCIPLES               149
# TITLE III \nESTABLISHMENT AND STRUCTURE OF THE ...       108
# TITLE IV \nBUDGET IMPLEMENTATION                         374
# TITLE IX \nPRIZES                                         20
# TITLE V \nCOMMON RULES                                   200
# TITLE VI \nINDIRECT MANAGEMENT                            77
# TITLE VII \nPROCUREMENT AND CONCESSIONS                  107
# TITLE VIII \nGRANTS                                      165
# TITLE X \nFINANCIAL INSTRUMENTS, BUDGETARY GUAR...       117
# TITLE XI \nCONTRIBUTIONS TO EUROPEAN POLITICAL ...        57
# TITLE XII \nOTHER BUDGET IMPLEMENTATION INSTRUM...        72
# TITLE XIII \nANNUAL ACCOUNTS AND OTHER FINANCIA...        42
# TITLE XIV \nEXTERNAL AUDIT AND DISCHARGE                  59
# TITLE XV \nADMINISTRATIVE APPROPRIATIONS                  37
# TITLE XVI \nINFORMATION REQUESTS AND DELEGATED ...       258

# %%
triplets_df_nostop.groupby("Title")[["head"]].nunique()
# Out:
#                                                     head
# Title
# TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENER...   103
# TITLE II \nBUDGET AND BUDGETARY PRINCIPLES           218
# TITLE III \nESTABLISHMENT AND STRUCTURE OF THE ...    84
# TITLE IV \nBUDGET IMPLEMENTATION                     520
# TITLE IX \nPRIZES                                     20
# TITLE V \nCOMMON RULES                               235
# TITLE VI \nINDIRECT MANAGEMENT                        65
# TITLE VII \nPROCUREMENT AND CONCESSIONS              102
# TITLE VIII \nGRANTS                                  194
# TITLE X \nFINANCIAL INSTRUMENTS, BUDGETARY GUAR...   108
# TITLE XI \nCONTRIBUTIONS TO EUROPEAN POLITICAL ...    46
# TITLE XII \nOTHER BUDGET IMPLEMENTATION INSTRUM...    57
# TITLE XIII \nANNUAL ACCOUNTS AND OTHER FINANCIA...    36
# TITLE XIV \nEXTERNAL AUDIT AND DISCHARGE              57
# TITLE XV \nADMINISTRATIVE APPROPRIATIONS              32
# TITLE XVI \nINFORMATION REQUESTS AND DELEGATED ...   432

# %%
triplets_df_nostop[triplets_df_nostop["Title"]=='TITLE II \nBUDGET AND BUDGETARY PRINCIPLES ']["relation"].unique()
# Out:
# array(['implement', 'set', 'authorise', 'be charge', 'shall contain',
#        'shall consist', 'shall cover', 'prevent', 'be commit', 'be make',
#        'provide', 'be book', 'be enter', 'be', 'be authorise',
#        'be adjust', 'refer', 'have reach', 'adopt', 'be approve',
#        'be lay', 'be carry', 'be complete', 'have adopt', 'use', 'exceed',
#        'be return', 'shall take', 'shall inform', 'state', 'be apply',
#        'carry', 'commit', 'annex', 'be pay', 'cancel', 'be decommitte',
#        'correspond', 'apply', 'shall examine', 'shall decide', 'belong',
#        'require', 'may authorise', 'shall', 'shall enter', 'take',
#        'shall submit', 'inform', 'wish', 'be give', 'shall act',
#        'be exceed', 'raise', 'be draw', 'be present', 'account',
#        'be establish', 'avoid', 'be calculate', 'be use',
#        'shall constitute', 'participate', 'receive', 'transfer',
#        'may assign', 'specify', 'shall include', 'indicate',
#        'shall comprise', 'may receive', 'be show', 'be receive', 'save',
#        'be express', 'be estimate', 'shall give', 'be implement',
#        'be send', 'be base', 'accommodate', 'shall set', 'be monitor',
#        'may accept', 'concern', 'explain', 'mean', 'support', 'accept',
#        'finance', 'be limited', 'be list', 'pay', 'shall apply',
#        'be treat', 'be include', 'be earmark', 'subdivide',
#        'may transfer', 'be transfer', 'have authorise', 'be take',
#        'be accompany', 'be raise', 'may propose', 'make', 'may',
#        'may submit', 'approve', 'shall deliberate', 'intend', 'consider',
#        'refrain', 'be reduce', 'represent', 'have amend', 'have approve',
#        'amend', 'agree', 'reach', 'employ', 'be achieve', 'shall focus',
#        'progress', 'be report', 'expect', 'may take', 'shall assess',
#        'be undertake', 'shall provide', 'regard', 'present',
#        'shall estimate', 'be design', 'include', 'be perform',
#        'shall identify', 'shall have', 'publish', 'be publish',
#        'be declare', 'shall make', 'grant', 'be provide', 'shall publish',
#        'be deem', 'designate', 'be remove', 'identifie'], dtype=object)

# %%
triplets_df_nostop[triplets_df_nostop["Title"]=='TITLE II \nBUDGET AND BUDGETARY PRINCIPLES ']["head"].unique()
# Out:
# array(['the budget', 'the common foreign and security policy (cfsp)',
#        'the appropriations authorised for the financial year',
#        'commitment appropriations', 'payment appropriations',
#        'paragraphs 2 and 3 of this article', 'appropriations',
#        'budgetary commitments', 'all revenue and expenditure',
#        'no expenditure', 'an appropriation',
#        'interest generated by prefinancing payments made from the budget',
#        'the appropriations entered in the budget',
#        'the revenue of a financial year',
#        'the own resources for the month of january of the following financial year may be made available in advance pursuant to regulation (eu euratom) no 6092014',
#        'the entries in respect of the value added tax (vat) and',
#        'commitments', 'the global budgetary commitments', 'payments',
#        'the expenditure of the european agricultural guarantee fund (eagf)',
#        'the payment order', 'the following expenditure',
#        'routine administrative expenditure', 'such expenditure',
#        'the basis for such expenditure',
#        'appropriations which have not been used by the end of the financial year for which they were entered may be carried over by a decision taken pursuant to paragraph 3 but only to the following financial year: commitment appropriations and nondifferentiated appropriations for which most of the preparatory stages of the commitment procedure have been completed by 31 december of the financial year',
#        'most of the preparatory stages of the commitment procedure',
#        'such appropriations', 'the legislative authority',
#        'the commission',
#        'the payment appropriations provided for in the relevant budget lines for the following financial year',
#        'the union institution concerned',
#        'carryovers of noncommitted appropriations',
#        'appropriations which are carried over',
#        'the criteria in points and of the first subparagraph of paragraph 2',
#        'commitment appropriations as referred to in regulation (eu) no 13032013 and in regulation (eu)',
#        'other commitment appropriations',
#        'the treatment of external assigned revenue as referred to in point of paragraph 4 of this article resulting from the participation of european free trade association (efta) states in certain union programmes in accordance with point of article 21(2)',
#        'no 32', 'the appropriations', 'nondifferentiated appropriations',
#        '4 appropriations placed in reserve and appropriations for staff expenditure',
#        'the commitment appropriations and the nondifferentiated appropriations',
#        'the commitments', 'the preparatory stages', 'the commitment',
#        'a carryover to the following financial year',
#        'appropriations carried over in accordance with point of the first subparagraph of article 12(2) which have not been committed by 31 march of the following financial year or by 31 december of the following financial year for amounts relating to building projects',
#        'the year in which they were made as a result of the total or partial nonimplementation of the actions for which they were earmarked the appropriations corresponding to such decommitments',
#        'no 5142014', 'this article',
#        'the appropriations corresponding to decommitments referred to in regulations (eu) no 13032013 (eu) no 2232014 and (eu)',
#        'the appropriations corresponding to decom\xadmitments',
#        'commitment appropriations corresponding to the amount of decommitments made as a result of total or partial nonimplementation of corresponding research projects',
#        'the projects', 'commitments and payments', 'that sum',
#        'the appropriations authorised in the relevant chapter of the budget for the preceding financial year',
#        'if the continuity of union action and management needs',
#        'the council',
#        'its decision on authorisation to the european parliament',
#        'the european parliament',
#        'the expiry of the 30 days in which case the commission shall submit a new proposal',
#        'the decision', 'the additional twelfths',
#        'the authorisation of four provisional twelfths granted in accordance with paragraph 4',
#        'the european parliament and the council',
#        'the overall total of the appropriations',
#        'revenue and payment appropriations',
#        'the union and the union bodies', '71',
#        'the balance from each financial year',
#        'the estimates of the revenue or payment appropriations',
#        'any discrepancy between those accounts and the estimates of the revenue or payment appropriations',
#        'the multiannual financial framework and the budget',
#        'the accounts', 'the cashflow purposes',
#        'the authorising officer responsible',
#        'the payment order or recovery order',
#        '82 83 and 84 conversion between euro and another currency',
#        'accounting exchange rate', 'the rate',
#        'currency conversion operations',
#        'the rate of conversion between the euro and other currencies',
#        'prejudice to article 21 total revenue',
#        'external assigned revenue and internal assigned revenue',
#        'the following', 'the jrc',
#        'revenue from third parties in respect of goods services or work supplied at services or work request revenue arising from the repayment in accordance with article 101 of amounts wrongly paid proceeds from the supply of goods services and works to other departments within an union institution or to other union institutions or bodies including refunds by other union institutions or bodies of mission allowances paid on their behalf insurance payments',
#        'assigned revenue', 'a basic act', 'such revenue',
#        'the structure to accommodate assigned revenue in the budget',
#        'which budget lines', 'the estimated revenue',
#        'the appropriations corresponding to assigned revenue',
#        'the revenue', 'the contribution agreement',
#        'euro commitment appropriations', 'the amount receivable',
#        'the entry of the amounts in the statement of revenue',
#        'appropriations referred to in point of the first subparagraph of this paragraph',
#        'the estimates of amounts receivable',
#        'seven twelfths of the sum entered in the budget',
#        'the remaining five twelfths',
#        'the contributions provided for in paragraph 1',
#        'any contribution or additional payment owed by member states to the budget',
#        'payments made shall be entered in the account provided for in regulation (eu euratom) no 6092014 and',
#        'in the statement of revenue a budget line with a token entry',
#        'an annex forming an integral part of the budget', 'efta states',
#        'the use of the revenue arising from the financial contribution of efta states',
#        'union institutions', 'no objection',
#        'the union institutions concerned', 'corporate sponsorship',
#        'a legal person',
#        'respective websites union institutions and bodies',
#        'the event or activity',
#        'exclusively social events the event or activity is not exclusively financed through corporate sponsorship the service in return for corporate sponsorship',
#        'the sponsor', 'the value of corporate sponsorship',
#        'the following deductions',
#        'penalties imposed on parties to contracts or beneficiaries discounts refunds and rebates on individual invoices and cost statements interest generated by prefinancing payments adjustments for amounts',
#        'the adjustments', 'the excess payment', 'union accounting rules',
#        'the cost of products or services provided to the union incorporating',
#        'the cost of products or services provided to the union incorporating taxes refunded by third countries on the basis of relevant agreements may be charged to the budget for the extax amount for any of the following amounts: the extax amount the taxinclusive amount',
#        'the first subparagraph subsequently reimbursed taxes',
#        'adjustments', 'the final gain or loss', 'the chapters',
#        'the commission and the other union institutions',
#        'the limits referred to in articles 29 30 and',
#        'the amount to be taken into consideration for the purposes of calculating the limits referred to in articles 29 30 and',
#        'transfers',
#        'the amount corresponding to the transfers which are carried out autonomously by the commission or by any other union institution concerned without a decision of the european parliament and of the council',
#        'proposals for transfers and all information for the european parliament and for the council concerning transfers made under articles 29 30 and 31',
#        'the transfer', 'the union institution',
#        'that duly justified objections',
#        'any union institution other than the commission',
#        'any union institution other than the commission may within any union institution',
#        'the appropriations concerned',
#        'the provisioned resources in the common provisioning fund of the latter',
#        'the expenditure', 'the items', 'those transfers',
#        'the commission may within the commission own section of the budget decide on the following transfers of appropriations from one title to another provided the commission',
#        'each union institution', 'the transfer of payment appropriations',
#        'the sixweek period', 'the transfer of the payment appropriations',
#        'the corresponding part of the expenditure',
#        'the european parliament and to the council',
#        'the european parliament and the council the latter acting by qualified majority',
#        'a transfer proposal shall be approved or considered to be approved if within the sixweek period any of the following occurs: the european parliament',
#        'either the european parliament or the council',
#        'the other institution',
#        'either the european parliament or the council requests',
#        'the use of the emergency aid reserve',
#        'the european parliament and by the council',
#        'proposals for transfers from the emergency aid reserve shall be accompanied by appropriate and detailed supporting documents demonstrating: the most recent information available for the implementation of appropriations and the estimate of requirements up to the end of the financial year for the budget line to which the transfer is to be made an analysis of the possibilities of reallocating appropriations',
#        'the resources used by the union institution concerned in the pursuit of its activities',
#        'the principle of economy which requires that the resources used by the union institution concerned in the pursuit of its activities shall be made available in due time in appropriate quantity and quality and at the best price',
#        'the objectives pursued', 'the use of appropriations',
#        'objectives for programmes and activities',
#        'performance indicators',
#        'problems with the achievement of objectives',
#        'specific measurable attainable relevant and timebound objectives',
#        'programmes and activities which entail significant spending',
#        'ex ante evaluations supporting the preparation of programmes and activities shall be based on evidence on the performance of related programmes or activities and shall identify and analyse the issues to be addressed the added value of union involvement objectives expected effects of different options and monitoring and evaluation arrangements',
#        'the added value of union involvement objectives',
#        'the ex ante evaluation', 'retrospective evaluations',
#        'the monitoring arrangements and indicators established for the action concerned',
#        'the findings',
#        'any proposal or initiative submitted to the legislative authority by the commission',
#        'any amendment to a proposal or initiative submitted to the legislative authority which may have an appreciable impact on the budget including changes in the number of posts',
#        'a financial statement prepared by the union institution proposing the amendment',
#        'such assessment',
#        'the purposes of budget implementation internal control',
#        'effective internal control', 'efficient internal control',
#        'the implementation of an appropriate risk management and control strategy coordinated among appropriate actors involved in the control chain the accessibility for all appropriate actors in the control chain of the results of controls',
#        'the quality of the underlying work', 'the underlying work',
#        'the level of error', 'the president of the european parliament',
#        'the budgets', 'the european union',
#        'pending official publication in the official journal of the european unionthe european union',
#        'the consolidated annual accounts',
#        'the first subparagraph of this paragraph',
#        'other union institutions', 'save in the cases',
#        'the following information', 'the recipient', 'the amount',
#        'the information referred to in the first subparagraph of this paragraph',
#        'contests', 'the information',
#        'education supports paid to natural persons and other direct support paid to natural persons most in need as referred to in point of article 191(4)',
#        'such support', 'natural persons',
#        'the disclosure of the information referred to in the first subparagraph of paragraph 2',
#        'persons or entities implementing union funds pursuant to point of the first subparagraph of article 62(1)',
#        'those rules', 'any publication of personal data', 'bodies',
#        'the funds', 'the websites of union institutions',
#        'the information as provided by the persons entities or bodies',
#        'personal data', 'the information referred', 'whose official name'],
#       dtype=object)

# %%
nlp = spacy.load("en_core_web_sm")
doc = nlp("the commission and the other union institutions")
for token in doc:
    print(token.text,'|', token.dep_, '|', token.head.text,'|', token.head.pos_,
            [child for child in token.children])
# Out:
# the | det | commission | NOUN []
# commission | ROOT | commission | NOUN [the, and, institutions]
# and | cc | commission | NOUN []
# the | det | institutions | NOUN []
# other | amod | institutions | NOUN []
# union | compound | institutions | NOUN []
# institutions | conj | commission | NOUN [the, other, union]

# %%
import spacy
# from spacy.symbols import NOUN, det, compound

nlp = spacy.load("en_core_web_sm")
doc = nlp("the commission and the other union institutions")

tokens = []
for token in doc:
    tokens.append(token)

print(tokens)
# Finding a verb with a subject from below — good
# verbs = set()
for possible_subject in doc:
    if possible_subject.dep == det and possible_subject.head.pos == NOUN:
        if possible_subject.dep == 
        print(possible_subject, possible_subject.head)
# print(verbs)
# Out:
# [the, commission, and, the, other, union, institutions]

# %%
import spacy
from spacy.symbols import NOUN, det, compound

nlp = spacy.load("en_core_web_sm")
doc = nlp("the payment appropriations provided for in the relevant budget lines for the following financial year")

for possible_subject in doc:
    if possible_subject.dep == det and possible_subject.head.pos == NOUN:
        if possible_subject.dep == 
        print(possible_subject, possible_subject.head)
# Out:
#   Cell In[42], line 9
#     if possible_subject.dep ==
#                                ^
# SyntaxError: invalid syntax

# %%
nlp = spacy.load("en_core_web_sm")
doc = nlp("carryovers of noncommitted appropriations")
for chunk in doc.noun_chunks:
    print(chunk)
# Out:
# carryovers
# noncommitted appropriations

# %%
relations_freq = triplets_df_nostop[triplets_df_nostop["Title"]=='TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENERAL PRINCIPLES '].groupby(["relation"])["relation"].count().reset_index(name='count').sort_values(by=('count'), ascending=False)

# %%
relations_freq
# Out:
#           relation  count
# 26            mean     71
# 11        conclude      4
# 28           refer      3
# 1               be      3
# 27         provide      2
# 4        be govern      2
# 13           cover      2
# 21             lay      2
# 9          be sign      2
# 7       be provide      2
# 33            work      2
# 0            andor      1
# 10  capacitybuilde      1
# 6          be pool      1
# 8          be sell      1
# 3          be deem      1
# 5        be oblige      1
# 2      be consider      1
# 17      establishe      1
# 16           enter      1
# 15       directive      1
# 14            deem      1
# 12         consist      1
# 18         execute      1
# 19     have obtain      1
# 20         involve      1
# 25       may share      1
# 24     may involve      1
# 23      may assume      1
# 22            make      1
# 29     shall apply      1
# 30    shall comply      1
# 31          supply      1
# 32            take      1

# %%
relations_freq['count'].sum()
# Out:
# np.int64(370)

# %%
triplets_df_nostop[triplets_df_nostop["Title"]=='TITLE II \nBUDGET AND BUDGETARY PRINCIPLES '][triplets_df_nostop["relation"] =='support']
# Out:
# C:\Users\Student\AppData\Local\Temp\ipykernel_4744\270250028.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   triplets_df_nostop[triplets_df_nostop["Title"]=='TITLE II \nBUDGET AND BUDGETARY PRINCIPLES '][triplets_df_nostop["relation"] =='support']
#                                            Title  \
# 306  TITLE II \nBUDGET AND BUDGETARY PRINCIPLES
#
#                                Articles  \
# 306  Article 26  Corporate sponsorship
#
#                                                Content  \
# 306  [ \n‘Corporate sponsorship’ means an agreement...
#
#                                 coreference_list_ready  \
# 306  corporate sponsorship means an agreement by wh...
#
#                                    Cleaned_Content_new  \
# 306  corporate sponsorship means an agreement by wh...
#
#                                   triplets_list  empty_list  many_triplets  \
# 306  [a legal person, support, inkind by which]       False           True
#
#                head relation             tail  is_stopword
# 306  a legal person  support  inkind by which        False

# %%
triplets_df_nostop[triplets_df_nostop["Title"]=='TITLE IV \nBUDGET IMPLEMENTATION ']["head"].unique()[0]
# Out:
# 'the commission'

# %%
nlp = spacy.load("en_core_web_sm")
doc = nlp("the commission and other union institutions")
for token in doc: 
    print(token, " | ", 
          spacy.explain(token.pos_))
# Out:
# the  |  determiner
# commission  |  noun
# and  |  coordinating conjunction
# other  |  adjective
# union  |  noun
# institutions  |  noun

# %%
import spacy
from spacy.symbols import NOUN

nlp = spacy.load("en_core_web_sm")
doc = nlp("the commission and other union institutions")

# Finding a verb with a subject from below — good
verbs = set()
for possible_subject in doc:
    if possible_subject.pos == NOUN and possible_subject.head.pos == NOUN:
        verbs.add(possible_subject.head)
print(verbs)
# Out:
# {institutions, commission}

# %%
triplets_df_nostop[triplets_df_nostop["Title"]=='TITLE IV \nBUDGET IMPLEMENTATION ']["tail"].unique()
# Out:
# array(['the revenue and expenditure of the budget in accordance with this regulation under the commission',
#        'responsibility', 'within the limits of the appropriations',
#        'with the commission',
#        'in accordance with the principle of sound financial management',
#        'that for the purposes of safeguarding the financial interests of the union their personal data may be transferred to internal audit services to the court of auditors or to the european antifraud office (olaf) and between authorising officers of the commission and the executive agencies referred to in article 69 of this regulation and the union bodies referred to in articles 70 and 71 of this regulation',
#        'for the purposes of safeguarding the financial interests of the union to internal audit services to the court of auditors or to the european antifraud office (olaf)',
#        'to in articles 70 and 71 of this regulation',
#        'in the budget for any union action', 'only',
#        'by way of derogation from paragraph 1 and subject to the conditions set out in paragraphs 3 4 and 5 without a basic act provided the actions which the following appropriations are intended to finance fall within the competences of the union',
#        'which the following appropriations are intended to finance fall within the competences of the union',
#        'appropriations for preparatory actions in the field of application of the tfeu and the euratom treaty designed to prepare proposals with a view to the adoption of future actions appropriations for preparatory measures in the field of title v of the teu appropriations for oneoff actions or for actions for an indefinite duration carried out by the commission by virtue of tasks resulting from the commission prerogatives at institutional level pursuant to the tfeu and to the euratom treaty other than the euratom treaty right of legislative initiative to submit proposals as referred to in point of this paragraph and under specific powers directly conferred on this paragraph by articles 154 156 159 and 160 tfeu articles 168(2) 171(2) and 173(2)',
#        'the second paragraph of article 175 tfeu article 181(2) tfeu article 190 tfeu and articles 210(2) and 214(6) tfeu and articles 70 and 77 to 85 of the euratom treaty    appropriations for the operation of each union institution under each union institution administrative autonomy by way of derogation from paragraph 1 and subject to the conditions set out in paragraphs 3 4 and 5 the following appropriations may be implemented without a basic act provided the actions which the following appropriations are intended to finance fall within the competences of the union',
#        'with regard to appropriations referred to in point of paragraph 2 in the budget for not more than two consecutive financial years',
#        'eur 40 000 000 in any financial year', 'a coherent approach with',
#        'various forms',
#        'in the budget for not more than three consecutive financial years',
#        'before the end of the third financial year',
#        'in the course of the procedure for the adoption of the relevant basic act to the particular features of the preparatory action with regard to the activities',
#        'the aims pursued and',
#        'as a result to the amount of those envisaged for financing the definitive action itself',
#        'to in point of paragraph 2',
#        'eur 50 000 000 in any financial year', 'eur 100 000 000',
#        'by the council on a proposal by the high representative',
#        'the european parliament and the commission in order to ensure the rapid implementation of preparatory measures as early as possible of the councils intention to launch a preparatory measure and in particular of the estimated resources required for that purpose',
#        'all the measures necessary', 'a rapid disbursement of the funds',
#        'incremental costs directly arising from a specific field deployment of a mission or team involving inter alia personnel from union institutions including highrisk insurance travel and accommodation costs and per diem payments',
#        'the requisite powers for the implementation of the sections of the budget relating to the other union institutions on the other union institutions',
#        'servicelevel agreements with each other laying down the conditions governing the provision of services supply of products execution of works or of building contracts in',
#        'the conditions governing the provision of services supply of products execution of works or of building contracts',
#        'the transfer of appropriations or the recovery of costs which result from servicelevel agreements with each other laying down the conditions governing the provision of services supply of products execution of works or of building contracts imple\xadmentation',
#        'to in paragraph 2',
#        'also upon between departments of union institutions union bodies european offices bodies or persons entrusted with implementation of specific actions in the cfsp pursuant to title v of the teu and the office of the secretarygeneral of the board of governors of the european schools',
#        'the commission and other union institutions conclude with other union institutions regularly to the european parliament and to the council on the servicelevel agreements',
#        'with other union institutions',
#        'the commission and each of the other union institutions powers of budget implementation in accordance with the conditions laid down in this regulation and the commission and each of the other union institutions internal rules and within the limits laid down in the instrument of delegation',
#        'within the limits of the powers expressly conferred upon those so empowered',
#        'the commission and each of the other union institutions powers of budget implementation in addition to paragraph 1 concerning the operational appropriations of the commission and',
#        'section of the budget to heads of union delegations',
#        'without prejudice to the responsibility of heads of union delegations for budget implementation',
#        'four weeks where', 'the commission and',
#        'the commission rules for budget implementation when',
#        'subject to the same duties obligations and accountability as any other authorising officer by subdelegation of the commission and',
#        'the delegation of powers referred to in the first subparagraph in accordance with the commission and',
#        'rules',
#        'the measures necessary to facilitate cooperation between union delegations and commission departments for the purposes of the first subparagraph',
#        'the eeas powers of budget implementation concerning the administrative appropri\xadations of the eeas exceptionally in order to ensure the continuity in the administration of such delegations in the absence of the eeas competent authorising officer from the country where the eeas competent authorising officer or the eeas competent authorising officer delegation is based',
#        'where',
#        'where as authorising officers by subdelegation of the eeas',
#        'the eeas internal rules for budget implementation in the exceptional cases where commission staff of union delegations act as authorising officers by subdelegation of the eeas',
#        'subject to the same duties obligations and accountability as any other authorising officer by subdelegation of the eeas',
#        'the delegation of powers referred to in the first subparagraph in accordance with the eeas own rules',
#        'preparatory thereto audit or control',
#        'any action which may bring financial actors within the meaning of chapter 4 of this title and other persons including national authorities at any level involved in budget implementation under direct indirect and shared management including',
#        'appropriate measures to prevent a conflict of interests from arising in the functions under those of the union responsibility and to address situations which may objectively be perceived as a conflict of interests also',
#        'a risk of a conflict of interests involving a member of staff of a national authority where',
#        'the matter to the person in question or',
#        'where for staff covered by the staff regulations',
#        'the matter to the relevant authorising officer by delegation',
#        'in writing whether a conflict of interests is found to exist',
#        'to exist',
#        'to exist the appointing authority or the relevant national authority where',
#        'all activity in the matter',
#        'that any further appropriate action is taken in accordance with the applicable law',
#        'in accordance with the applicable law',
#        'where the impartial and objective exercise of the functions of a financial actor or other person as referred to in paragraph 1 is compromised for reasons involving family emotional life political or national affinity economic interest or any other direct or indirect personal interest for the purposes of paragraph 1',
#        'where to in paragraph 1',
#        'for reasons involving family emotional life political or national affinity economic interest or any other direct or indirect personal interest',
#        'the budget in any of the following ways: directly (direct management) as set out in articles 125 to 153 by its departments including its staff in the union delegations under the authority of the union delegations respective head of delegation in accordance with article 60(2) or through executive agencies as referred to in article 69 under shared management with member states (shared management) as set out in articles 63 and 125 to 129    indirectly (indirect management) as set out in articles 125 to 149 and 154 to 159 where this is provided for in the basic act or in the cases referred to in points to of article 58(2) by entrusting budget implementation tasks to: third countries or the bodies they have designated (ii) international organisations or they agencies within the meaning of article 156 (iii) the european investment bank (the eib) or the european investment fund (the eif) or both of they acting as a group (the eib group) in any of the following ways',
#        'as a group (the eib group)',
#        'to in articles 70 and 71 public law bodies including member state organisations (vi) bodies governed by private law with a public service mission including member state organisations to the extent that member state organisations are provided with adequate financial guarantees (vii) bodies governed by the private law of a member state that are entrusted with the implementation of a public private partnership and that are provided with adequate financial guarantees (viii) bodies or persons entrusted with the implementation of specific actions in the cfsp pursuant to title v of the teu and identified in the relevant basic act',
#        'with adequate financial guarantees (vii) bodies governed by the private law of a member state that are entrusted with the implementation of a public private partnership and that are provided with adequate financial guarantees (viii) bodies or persons entrusted with the implementation of specific actions in the cfsp pursuant to title v of the teu and identified in the relevant basic act',
#        'with regard to point(vi) of the first subparagraph in the relevant basic act',
#        'to the maximum amount of the union contribution to the body concerned',
#        'in the case of multiple guarantors in the contribution agreement which may provide for the liability of each guarantor to be proportionate to the share of their respective contribution to the body',
#        'the instruments referred to in titles for the purposes of direct management',
#        'the ones provided for in sectorspecific rules for the purposes of shared management',
#        'title vi for the purposes of indirect management in the case of financial instruments and',
#        'the instruments for budget implemen\xadtation set out in the contribution agreement concerned',
#        'responsible for budget implementation in accordance with article',
#        'those tasks to third parties where such tasks involve a large measure of discretion',
#        'a large measure of discretion where',
#        'the budget where under shared management tasks relating to budget implementation',
#        'the principles of sound financial management transparency and nondiscrimination',
#        'the visibility of the union action', 'union funds when',
#        'the commission respective control to that end',
#        'the resulting responsibilities laid down in this regulation',
#        'in sectorspecific rules',
#        'correctly and effectively and in accordance with the applicable sectorspecific rules designating bodies responsible for the management and control of union funds in accordance with paragraph 3 and supervising such bodies l 19358',
#        'detecting and correcting irregularities and fraud cooperating in accordance with this regulation and sectorspecific rules with the commission',
#        'in enhanced cooperation pursuant to council regulation (eu)',
#        'the principle of propor\xadtionality',
#        'samples of transactions where',
#        'funds unduly paid and bring legal proceedings where necessary in that regard also',
#        'effective dissuasive and proportionate penalties on recipients where provided for in sector specific rules or in specific provisions in national law',
#        'the management and control systems established in member states as part of its risk assessment and in accordance with sectorspecific rules',
#        'the principle of proportionality in the commission audit work respect',
#        'the level of risk assessed in accordance with sectorspecific rules into account',
#        'tasks not related to the management of union funds also',
#        'certain of such bodies tasks to other bodies',
#        'the same as those already in place for the previous period essentially',
#        'effectively',
#        'that the designated bodies no longer comply with the criteria set out in sectorspecific rules member states',
#        'no longer with the criteria set out in sectorspecific rules member states',
#        'remedied including by ending the designation in accordance with sectorspecific rules',
#        'the role of the commission in the process set out in this paragraph',
#        'pursuant',
#        'the functioning of an effective and efficient internal control system use an accounting system that provides accurate complete and reliable information in a timely manner',
#        'an accounting system that provides accurate complete and reliable information in a timely manner',
#        'the information required under paragraphs 5 6 and 7',
#        'ex post publication in accordance with article 38(2) to (6',
#        'with regulation (eu)',
#        'pursuant to paragraph 3 by 15 february of the following financial year',
#        'the commission in the process set out in this paragraph with: bodies designated pursuant to paragraph 3 shall in the process set out in this paragraph with by 15 february of the following financial year accounts on the expenditure that was incurred during the relevant reference period as defined in sectorspecific rules in the execution of bodies designated pursuant to paragraph 3 by 15 february of the following financial year tasks',
#        'to in point of paragraph 5', 'ongoing for',
#        'by a management declaration confirming that in the opinion of those in charge of the management of the funds: the information is properly presented complete and accurate the expenditure was used for the expenditure intended purpose as defined in sectorspecific rules',
#        'in the opinion of those in charge of the management of the funds properly',
#        'for the expenditure intended purpose',
#        'the legality and regularity of the underlying transactions',
#        'by an opinion of an independent audit body drawn up in accordance with internationally accepted audit standards',
#        'whether the accounts give a true and fair view whether expenditure for which reimbursement has been requested from the commission is legal and regular and whether the control systems put in place function properly',
#        'a true and fair view whether expenditure for which reimbursement has been requested from the commission is legal and regular and whether the control systems put in place function properly',
#        'for from the commission', 'legal and regular', 'properly',
#        'whether the audit work puts in doubt also', 'doubt',
#        'to in paragraph',
#        'exceptionally by the commission to 1 march upon communication by the member state',
#        'the information referred to in paragraphs 5 and 6 and in paragraph at the appropriate level',
#        'in to the european parliament to the council and to the commission declarations signed at the appropriate level based on the information',
#        'to in paragraphs 5 and 6 and in this paragraph',
#        'in accordance with the applicable rules',
#        'complete accurate and true exclude from union financing expenditure for which disbursements have been made in breach of applicable law interrupt payment deadlines',
#        'for which in breach of applicable law', 'payments',
#        'where for in sectorspecific rules',
#        'all or part of the interruption of payment deadlines or suspension of payments as soon as the commission has taken any necessary measures',
#        'the commission observations', 'any necessary measures',
#        'to in article 74(9', 'all the obligations under paragraph 6',
#        'account of the needs of european territorial cooperation programmes as regards in particular',
#        'in paragraph 3',
#        'a register of bodies responsible for management certification and audit activities under sectorspecific rules',
#        'resources allocated to member states under shared management in combination with operations and instruments carried out under regulation (eu) 20151017 in accordance with the conditions set out in the relevant sectorspecific rules',
#        'a costbenefit study and an assessment of the associated risks inform the european parliament and the council of the results thereof and propose to enter the necessary appropriations in an annex to the section of the budget relating to the commission before setting up a new european office',
#        'the european parliament and the council of the results thereof',
#        'to enter the necessary appropriations in an annex to the section of the budget relating to the commission',
#        'to the operation of olaf with the exception of paragraph 4 of this article article 66 and article 67(1) (2) and (3',
#        'all responsibilities laid down in chapter 8 of this title',
#        'in a specific budget line within the section of the budget relating to the commission',
#        'in detail in an annex to the section of the budget relating to the commission',
#        'shall take the form of a statement of revenue and expenditure subdivided in the same way as the sections of the budget relating to the commission to in the first subparagraph',
#        'the form of a statement of revenue and expenditure subdivided in the same way as the sections of the budget relating to the commission',
#        'in an annex to that section',
#        'to implement obligatory tasks of each european office in respect of the appropriations authorised',
#        'the powers of authorising officer to the director of the european office concerned in accordance with article 73',
#        'to that of the commission',
#        'decisions on transfers within the annex referred to in paragraph',
#        'the european parliament and the council of such transfers',
#        'delegation for the nonobligatory tasks referred to in point of article 64(2) together with a delegation of the powers of the authorising officer concerning appropriations entered in the section of the budget relating to the union institution union body or other european office',
#        'adhoc servicelevel agreements with union institutions union',
#        'in accordance with the act of establishment of the european office in particular',
#        'the conditions and modalities of the delegation of powers',
#        'in the cases referred to in point of paragraph 1',
#        'the result of such accounting records to the union institutions union bodies or other european offices concerned',
#        'accounting records of each european office expenditure',
#        'the proportion of each european office services supplied to each of union institutions union bodies or other european offices',
#        'the criteria upon which the accounting records shall be based',
#        'upon which', 'to which in accordance with point of article 66(1',
#        'in which',
#        'an estimate of the costs of services supplied by the european office to each of the union institutions union bodies and other european offices concerned',
#        'to which authorising officer powers in accordance with point of article 66(1',
#        'the union institutions union bodies and other european offices concerned of the results of the accounting records provided for in paragraph 1 of this articlethis article',
#        'an integral part of the unions', 'in accordance with article 241',
#        'on a proposal from the management committee of the european office concerned',
#        'name by the commission',
#        'between the european office concerned and the commission at the end of the financial year',
#        'to the implementation of the budget for the euratom supply agency',
#        'powers to executive agencies',
#        'all or part of a union programme or project including pilot projects and preparatory actions and the implementation of administrative expenditure on the commission behalf and under the commission responsibility in accordance with council regulation (ec)',
#        'by means of a commission decision',
#        'legal personality under union law', 'an annual contribution',
#        'as authorising officers by delegation as regards the implementation of the operational appropriations relating to the union programmes which the directors of executive agencies manage in whole or in part',
#        'which in whole or in part',
#        'with the commission that the accounting officer of the commission shall also act as the accounting officer of an executive agency concerned',
#        'also as the accounting officer of an executive agency',
#        'the accounting officer of the commission also with part of the tasks of the accounting officer of the executive agency concerned taking into account costbenefit considerations',
#        'in both cases',
#        'to adopt delegated acts in accordance with article 269 of this regulation to supplement this regulation with a framework financial regulation for bodies which are set up under the tfeu and the euratom treaty and which have legal personality and receive contributions charged to the budget',
#        'on the principles and rules set out in this regulation taking into account',
#        'to in paragraph 1',
#        'from the framework financial regulation except where the bodies referred specific needs so require and subject to the commissions',
#        'specific needs so require and subject to the commissions where',
#        'so',
#        'by the european parliament on the recommendation of the council',
#        'fully with the union institutions involved in the discharge procedure and provide as appropriate any additional necessary information including through attendance at meetings of the bodies',
#        'the same powers over the bodies referred to in paragraph 1 as those exercised in respect of the commission',
#        'that the annual accounts of each of the bodies referred to in paragraph 1 of this article',
#        'to in paragraph 1 of this article',
#        'the income expenditure and financial position of the relevant body properly prior to the consolidation in the commissions final accounts',
#        'otherwise in the relevant basic act',
#        'a specific annual report on each body in line with the requirements of article 287(1)',
#        'the audit work performed by the independent external auditor and the action taken in response to the auditors findings in preparing a specific annual report on each body',
#        'findings shall remain under the full responsibility of the court of auditors to in paragraph 6 including the auditors',
#        'under the full responsibility of the court of auditors',
#        'bodies having legal personality that are set up by a basic act and entrusted with the implementation of a publicprivate partnership own financial rules',
#        'financial rules',
#        'a set of principles necessary to ensure sound financial management of union funds',
#        'to adopt delegated acts in accordance with article 269 to supplement this regulation with a model financial regulation for publicprivate partnership bodies laying down the principles necessary to ensure sound financial management of union funds',
#        'from the model financial regulation except where the financial rules of the publicprivate partnership bodies specific needs so require and subject to the commissions',
#        'specific needs where', 'partnership bodies',
#        'each financial actor with the resources required to perform each financial actor or each financial actor duties and a charter describing in detail each financial actor or each financial actor tasks rights and obligations',
#        'the duties of authorising officer',
#        'the staff to whom it delegates the duties of authorising officer to staff at an appropriate level the scope of the powers delegated and whether the persons to whom the powers delegated are delegated may subdelegate the powers',
#        'the powers', 'only to staff',
#        'within the limits set by the instrument of delegation or',
#        'by one or more members of staff entrusted under officer or officer responsibility with the carrying out of certain operations necessary for budget implementation and the production of the financial and management information',
#        'shall inform the european parliament the council the court of auditors and the accounting officer of the commission within two weeks of the appointment and the termination of the duties of authorising officers by delegation internal auditors and accounting officers and of any internal rules the commission adopts in respect of financial matters to in article 70',
#        'the council within two weeks of the appointment and the termination of the duties of authorising officers by delegation internal auditors and accounting officers and of any internal rules the commission adopts in respect of financial matters',
#        'in respect of financial matters',
#        'the court of auditors of delegation decisions of the appointment of imprest administrators under articles 79 and 88',
#        'responsible in the union institution concerned for implementing revenue and expenditure in accordance with the principle of sound financial management including through ensuring reporting on performance and for ensuring compliance with the requirements of legality and regularity and equal treatment of recipients',
#        'by a comprehensive risk analysis which takes into account account cost effectiveness and performance considerations',
#        'expenditure and authorise payments', 'recovery orders',
#        'established entitlements',
#        'subject in order to prevent errors and irregularities before the authorisation of operations and to mitigate risks of non achievement of objectives at least to an ex ante control relating to the operational and financial aspects of the operation on the basis of a multiannual control strategy which takes risk into account',
#        'by the authorising officer responsible taking into account the results of prior controls as well as',
#        'considerations on the basis of the authorising officers own risk analysis',
#        'risk analysis',
#        'in case of doubt as part of the ex ante control request complementary information or perform an onthespot control in order to obtain reasonable assurance',
#        'by staff other than those who initiated a given operation',
#        'subordinate to the members of staff who initiated a given operation',
#        'ex post controls in place', 'on a sample basis according to risk',
#        'account of the results of prior controls as well as',
#        'by staff other than those responsible for the ex ante controls',
#        'subordinate to the members of staff responsible for the ex ante controls',
#        'clear consistent and transparent', 'the grant agreement when',
#        'the following: that the authorising officers by subdelegation and subdelegation staff receive regularly updated and appropriate information and training concerning the control standards and the methods and techniques available for that purpose l 19364   that measures are taken where needed to ensure the effective and efficient functioning of the control systems in accordance with paragraph',
#        'regularly updated and appropriate information and training concerning the control standards and the methods and techniques available for that purpose',
#        'the effective and efficient functioning of the control systems in accordance with paragraph',
#        'that a decision he or she is required by he or she superior to apply or to agree to is irregular or contrary to the principle of sound financial management or the professional rules which that member of staff is required to observe he or she she shall inform he or she hierarchical superior accordingly',
#        'by he',
#        'irregular or contrary to the principle of sound financial management or the professional rules which that member of staff is required to observe he or',
#        'which that member of staff is required to observe he',
#        'so in writing', 'in writing', 'to take action',
#        'the initial decision or instruction and',
#        'that such confirmation does not constitute a reasonable response to the member of staff or her concern the member of staff shall inform the authorising officer by delegation in writing',
#        'a reasonable response to the member of staff or her concern',
#        'the authorising officer by delegation in writing',
#        'within a reasonable time given the circumstances of the case and',
#        'the relevant panel in any event within a month',
#        'to in article 143',
#        'the authorities and bodies designated in the staff regulations and in the decisions of union institutions concerning the terms and conditions for internal investigations in relation to the prevention of fraud corruption and any other illegal activity detrimental to the interests of the unionthe union in the event of any illegal activity fraud or corruption which may harm the interests of the union',
#        'for an obligation of the external auditor to inform the authorising officer by delegation of any suspected illegal activity fraud or corruption which may harm the interests of the unionthe union',
#        'to the authorising officer or her union institution on the performance of the authorising officer or her duties in the form of an annual activity report containing financial and management information including the results of controls declaring that except as otherwise specified in any reservations related to defined areas of revenue and expend\xaditure the authorising officer or her has reasonable assurance that: the information contained in the report presents a true and fair view the resources assigned to the activities described in the report have been used for the resources assigned to the activities described in the report intended purpose and',
#        'a true and fair view the resources assigned to the activities described in the report have been used for the resources assigned to the activities described in the report intended purpose and',
#        'for the resources assigned to the activities described in the report intended purpose and',
#        'the necessary guarantees concerning the legality and regularity of the underlying transactions in accordance with the principle of sound financial management and the control procedures put in place',
#        'information on the operations carried out by reference to the objectives and performance considerations set in the strategic plans the risks associated with the operations carried out the use made of the resources provided and the efficiency and effectiveness of internal control systems',
#        'the use made of the resources provided and the efficiency and effectiveness of internal control systems',
#        'an overall assessment of the costs and benefits of controls and information on the extent to which the operational expenditure authorised contributes to the achievement of strategic objectives of the union and generates eu added value',
#        'contributes to the achievement of strategic objectives of the union to which',
#        'eu added value',
#        'a summary of the annual activity reports for the preceding year',
#        'by 1 july of the following financial year on the website of the respective union institution union body european office or agency in an easily accessible way subject to duly justified confidentiality and security considerations',
#        'for each financial year record contracts concluded by negotiated procedures in accordance with points to of point 11',
#        'distinctly higher than the average recorded for the union institution',
#        'for the union institution', 'to the union institution',
#        'any measures taken to reverse that trend',
#        'a report on negotiated procedures to the european parliament and to the council',
#        'in the case of the commission to the summary of the annual activity reports referred to in paragraph 9 of this article',
#        'paperbased or electronic systems for the keeping of original supporting documents relating to budget implementation',
#        'for at least five years from the date on which the european parliament gives discharge for the financial year to which the documents relate',
#        'discharge for the financial year to which the documents relate on which',
#        'to which', 'in which definitively',
#        'where possible be deleted when personal data contained in supporting documents are not necessary for budgetary discharge control and audit purposes',
#        'necessary when for budgetary discharge control and audit purposes',
#        'to the conservation of traffic data',
#        'subject to the commission as the union institution responsible for the definition exercise monitoring and appraisal of officers duties and responsibilities as authorising officers by subdelegation',
#        'closely with the commission with regard to the proper implementation of the funds in order to ensure in particular the legality and regularity of financial transactions respect for the principle of sound financial management in the management of the funds and the effective protection of the financial interests of the union',
#        'subject to the internal rules of the commission and to the commission charter for the implementation of the financial management tasks',
#        'to the financial interests of the union',
#        'in the financial interests of the union duties by commission staff of union delegations',
#        'where to in the second subparagraph',
#        'the directorsgeneral responsible of the commission and without delay of the eeas thereof',
#        'appropriate steps to remedy the situation',
#        'heads of union delegations in a situation',
#        'to in article 74(8) heads of union delegations',
#        'to officers authorising officer by delegation so that the latter can integrate officers reports in their authorising officer or her annual activity report',
#        'officers',
#        'information on the efficiency and effectiveness of internal control systems put in place in heads of union delegations delegation as well as on the management of operations subdelegated to heads of union delegations and provide the assurance referred to in the third subparagraph of article 92(5',
#        'to the annual activity report of the authorising officer by delegation',
#        'fully with union institutions involved in the discharge procedure and provide as appropriate any necessary additional information',
#        'to any request by the authorising officer by delegation of the commission at the commissions',
#        'request',
#        'that the subdelegating of powers to heads of union delegations is not detrimental to the discharge procedure under article 319',
#        'detrimental to the discharge procedure under article 319',
#        'also to deputy heads of union delegations',
#        'when as authorising officers by subdelegation in the absence of heads of union delegations',
#        'an accounting officer who shall be responsible in each union institution for the following',
#        'payments collecting revenue and recovering amounts established as being receivable l 19366   preparing and presenting the accounts in accordance with title xiii keeping the accounts in accordance with articles 82 and 84 laying down the accounting rules procedures and the chart of accounts in accordance with articles 80 to 84 laying down and validating the accounting systems and where appropriate validating systems laid down by the authorising officer to supply or justify accounting information treasury management properly',
#        'the accounting rules procedures and the chart of accounts in accordance with articles 80 to 84 laying down and validating the accounting systems and',
#        'the accounting systems',
#        'to verify at any time compliance with the validation criteria with respect to the tasks referred to in point of the first subparagraph',
#        'concern',
#        'responsible for the entire section of the budget relating to the commission including accounting operations relating to appropriations subdelegated to heads of union delegations',
#        'also as the accounting officer of the eeas in respect of the implementation of the section of the budget relating to the eeas',
#        'an accounting officer from officials subject to the staff regulations',
#        'by each union institution on the grounds of an accounting officer or an accounting officer particular competence',
#        'by diplomas or by equivalent professional experience',
#        'an accounting officer',
#        'the necessary arrangements in order to avoid any conflict of interests in such case',
#        'without delay in the event of termination of the duties of an accounting officer',
#        'to an accounting officer by the accounting officer who is terminating an accounting officer or an accounting officer duties or if it is not possible by an official in an accounting officer or',
#        'the trial balance in acceptance within one month from the date of transmission',
#        'reservations',
#        'the result of the trial balance and any reservations made',
#        'certain tasks',
#        'by union institutions european offices and the agencies and union bodies',
#        'to in section 2 of chapter 3 of this title',
#        'on internationally accepted accounting standards for the public sector',
#        'by the accounting officer of the commission following consultation with the accounting officers of other union institutions european offices and union bodies',
#        'from the standards referred to in paragraph 1 if the accounting officer of the commission or the accounting officer of the commission considers this necessary in order to give a fair presentation of the assets and liabilities charges income and cash flow',
#        'this necessary', 'that fact and the reasons for it',
#        'the accounting principles underlying the accounts by union institutions european offices and the agencies and union bodies',
#        'the structure and content of the financial statements as well as',
#        'shall respect the budgetary principles laid down in this regulation to in article 241',
#        'the budgetary principles laid down in this regulation',
#        'to in article',
#        'shall record all revenue and expenditure operations provided for in this title and give a fair presentation thereon to in article',
#        'all revenue and expenditure operations provided for in this title',
#        'a fair presentation thereon',
#        'updated documents describing the organisation of the accounts and the accounting procedures of his or her union institution or body',
#        'in a computerised system according to the economic nature of the operation as current revenue or expenditure or as capital',
#        'responsible for laying down the harmonised charts of accounts to be applied by union institutions by european offices and by the agencies and union bodies referred to in section 2 of chapter 3 of this title',
#        'from authorising officers all the information necessary for the production of accounts which give a fair presentation of the financial situation of union institutions and of budget implementation',
#        'the reliability of that information', 'to in article 70',
#        'the adoption of the accounts by the union institution or the union body referred to in article 70 off thereby certifying that the accounting officer of the commission or she has reasonable assurance that the accounts give a fair presentation of the financial situation of the union institution or the union body the union body referred to in article 70',
#        'reasonable assurance that the accounts give a fair presentation of the financial situation of the union institution or the union body',
#        'a fair presentation of the financial situation of the union institution or the union body',
#        'that the accounts have been prepared in accordance with the accounting rules referred to in article 80 and the accounting procedures referred to in point of the first subparagraph of article 77(1) and that all revenue and expenditure is entered in the accounts for that purpose',
#        'in accordance with the accounting rules referred to in article 80',
#        'to in point of the first subparagraph of article 77(1',
#        'in the accounts', 'regularly',
#        'at least for the closure of the accounts by the accounting officer of the commission in order to allow the use of union funds to be reflected in the accounts of the union',
#        'in the accounts of the union',
#        'fully responsible for the proper use of the funds the authorising officers manage the legality and regularity of the expenditure under the authorising officers',
#        'the legality and regularity of the expenditure under the authorising officers',
#        'the accounting officer of all developments or significant modifi\xadcations of a financial management system an inventory system or a system for the valuation of assets and liabilities',
#        'data for the accounts of the union institution',
#        'to substantiate data thereof so that the accounting officer of the commission can verify compliance with the validation criteria',
#        'compliance with the validation criteria',
#        'a financial management system already validated and may request that the accounting officer of the commission establishes an action plan in order to correct in due time possible weaknesses at any time',
#        'an action plan in order to correct in due time possible weaknesses',
#        'responsible for the completeness of information sent to the accounting officer of the commission',
#        'to check the information received as well as to carry out any further checks the accounting officer of the commission or the accounting officer of the commission in order to sign off the accounts',
#        'reservations explaining exactly the nature and scope of such reservations',
#        'to organise the budgetary and financial information in such a way that figures can be entered filed and registered',
#        'that', 'budget accounts of general accounts and',
#        'in euro and on the basis of the calendar year',
#        'detailed management accounts also',
#        'until the end of the year following that in which operations are closed',
#        'in which department the documents are to be kept',
#        'to be kept in which department',
#        'for each subdivision of the budget show',
#        'the entitlements established and the amounts recovered in respect of the financial year the commitments still to be paid and the revenue still to be recovered carried forward from preceding financial years the budget accounts shall for each subdivision of the budget show: in the case of expenditure: the appropriations authorised in the budget including the appropriations entered in amending budgets the appropriations the appropriations available following collection of assigned revenue transfers of appropriations and the total appropriations available (ii) the commitment appropriations and payment appropriations in respect of the financial year in the case of revenue in the budget including the estimates entered in amending budgets assigned revenue and the total amount of estimated revenue (ii)',
#        'revenue', 'to in point of the first subparagraph', 'separately',
#        'the doubleentry method record', 'in the accounting ledgers',
#        'on supporting documents to which the entries shall refer',
#        'such as to leave a clear audit trail for all accounting entries',
#        'responsible for closing the requirements of treasury management the accounting officer also',
#        'in the name of his or her union institution open accounts with financial institutions or national central banks or request for',
#        'on internal control requirements',
#        'by at least two duly authorised members of staff or by the accounting officer',
#        'under the responsibility of the authorising officer in charge of the implementation of the programme or action in agreement with the accounting officer of the commission',
#        'under the responsibility of the accounting officer of the commission',
#        'rules for the opening management and closure of fiduciary accounts and management and',
#        'otherwise in this regulation',
#        'to manage cash and cash equivalents',
#        'responsible for only the accounting officer safekeeping',
#        'that only the accounting officer or only the accounting officer union institution has at his or her union institution disposal sufficient funds to cover the cash requirements arising from budget implementation within the applicable regulatory framework and shall set up procedures to ensure that none of the accounts opened in accordance with articles 85(1) and 89(3) is in debit',
#        'sufficient funds to cover the cash requirements arising from budget implementation within the applicable regulatory framework at his or her union institution disposal',
#        'procedures',
#        'that none of the accounts opened in accordance with articles 85(1)',
#        'in accordance with articles 85(1', 'in debit',
#        'by bank credit transfer by cheque or from imprest accounts',
#        'specifically by only the accounting officer by debit card direct debit or other means of payment in accordance with the rules laid down by only the accounting officer',
#        'the payees identity establish the legal entity and payment details of the payees and enter the legal entity and payment details of the payee in the common file by the union institution for which only the accounting officer is responsible in order to ensure transparency accountability and before entering into a commitment towards a third party',
#        'the legal entity and payment details of the payees',
# ...
#        'necessary where', 'where yet by member states', 'where in doubt',
#        'as payments within the same twomonth period',
#        'from the global provisional budgetary commitment referred to in paragraph',
#        'subject to the examination and acceptance of the accounts',
#        'without prejudice to articles 111(2) and 264(3) into by 31 december of year n year',
#        'the one in which the budgetary commitment was made',
#        'the total cost of the corresponding legal commitments entered into up to 31 december of year n1',
#        'rise to the award of a prize where', 'to in title',
#        'rise to a financing agreement concluded with a third country the financing agreement shall be concluded by 31 december of year n1 where',
#        'by 31 december of year n1',
#        'the total costs of legal commitments implementing the financing agreement entered into within a period of three years following the date of conclusion of the financing agreement in that case',
#        'the total costs of legal commitments entered into until the end of the period of implementation of the financing agreement however in the following cases',
#        'the instrument for preaccession assistance established by regulation (eu) no 2312014 of the european parliament and of the council ( 1 ) the european neighbourhood instrument established by regulation (eu) no 2322014 of the european parliament and of the council ( 2 ) to the following multiannual programmes that are implemented through split commitments:',
#        'in the cases referred to in the first subparagraph automatically by the commission in accordance with sectorspecific rules',
#        'for which within two years of the entering into the legal commitment',
#        'except where that amount relates to a case under litigation before judicial courts or arbitral bodies where the legal commitment takes the form of a financing agreement with a third country or where there are special provisions laid down in sectorspecific rules',
#        'where to a case under litigation before judicial courts or arbitral bodies where the legal commitment takes the form of a financing agreement with a third country or where there are special provisions laid down in sectorspecific rules',
#        'the form of a financing agreement with a third country where',
#        'special provisions laid down in sectorspecific rules where',
#        'by the accounting officer within the limits of the funds',
#        'on production of proof that the relevant action is in accordance with the contract the agreement or the basic act and shall cover one or more of the following operations',
#        'the agreement or the basic act in accordance with the contract',
#        'one or more of the following operations',
#        'a float which may be divided into a number of payments in accordance with the principle of sound financial management',
#        'the agreement or the basic act either on the basis of the contract',
#        'with', 'where completely',
#        'payment of a provision on the basis of supporting documents which make it possible to check that the terms of the contract or agreement in question are complied with completely into the common provisioning fund established pursuant to article 212',
#        'all preceding expenditure', 'unused amounts',
#        'in budgetary accounting between the different types of payment',
#        'to in paragraph 2 at the time', 'to in article 80',
#        'the rules for clearing the prefinancing in the accounts and for the acknowledgment of the eligibility of costs',
#        'regularly by the authorising officer responsible according to the economic nature of the project and at the latest at the end of the project',
#        'on the basis of information on costs incurred or confirmation of the conditions for payment being fulfilled in accordance with article 125 as validated by the authorising officer responsible in accordance with article 111(3',
#        'at least the information needed to calculate a reasonable estimate of the costs for grant agreements contracts or contribution agreements above eur 5 000 000 at each yearend',
#        'for clearing the prefinancing',
#        'to comply with article 82(2 by the authorising officer and the accounting officer',
#        'within',
#        'agreements involving technical services or actions which are particularly complex to evaluate',
#        'for on the approval of a report or a certificate 60 calendar days for all other contribution agreements contracts and',
#        'agreements for which payment depends on the approval of a report or a certificate 30 calendar days for all other contribution agreements contracts and grant agreements',
#        'on the approval of a report or a certificate 30 calendar days for all other contribution agreements contracts and grant agreements',
#        'to include validation authorisation and the payment of expenditure',
#        'on which',
#        'by the authorised department of the authorising officer responsible as soon as possible',
#        'to be received on the date',
#        'to be the date on which the union institutions account',
#        'the following essential elements',
#        'the amount  a payment request shall include the following essential elements',
#        'a payment request where',
#        'in writing of a rejection and the reasons for a rejection as soon as possible and in any case within 30 calendar days from the date on which a payment request was received',
#        'the time limit for payment where: the amount of a payment request is not due or',
#        'due or where',
#        'to the notice of the authorising officer responsible which puts in',
#        'to run from the date on which the requested information or revised documents are received or the necessary further verification including onthespot checks is carried out',
#        'in writing of the reasons for a suspension',
#        'except in the case of member states the eib and the eif on the expiry of the time limits laid down in paragraph 1 to interest in accordance with the following conditions',
#        'except in the case of member states the eib and the eif on the expiry of the time limits laid down in paragraph 1 the creditor shall be entitled to interest in accordance with the following conditions',
#        'payable for the period elapsing from the calendar day following expiry of the time limit for payment laid down in paragraph 1 up to the day of payment',
#        'lower than or equal to eur 200', 'to the european parliament',
#        'to the summary of the annual activity reports referred to in article 74(9',
#        'an internal audit function which shall be performed in compliance with the relevant international standards',
#        'accountable to the latter for verifying the proper operation of budget implementation systems and procedures',
#        'the authorising officer or the accounting officer',
#        'as authorising officers by subdelegation in accordance with article 60(2',
#        'to officers',
#        'the commission for the financial management shall also act as the internal auditor of the eeas in respect of the implementation of the section of the budget relating to the eeas',
#        'also as the internal auditor of the eeas in respect of the implementation of the section of the budget relating to the eeas',
#        'each union institution internal auditor in accordance with arrangements adapted to each union institution specific features and requirements',
#        'the european parliament and the council of the appointment of each union institution internal auditor',
#        'requirements the scope of the mission of each union institution internal auditor and shall lay down in detail the objectives and procedures for the exercise of the internal audit function with due respect for international internal audit standards in accordance with each union institution specific features and each union institution',
#        'the scope of the mission of each union institution internal auditor',
#        'the objectives and procedures for the exercise of the internal audit function with due respect for international internal audit standards in detail',
#        'an official or other servant covered by the staff regulations selected from nationals of member states as internal auditor by virtue of each union institution particular competence',
#        'the same internal auditor two or more union institutions shall make the necessary arrangements for the internal auditor to be declared liable for the internal auditor or the internal auditor actions as laid down in article 121',
#        'the necessary arrangements for the internal auditor to be declared liable for the internal auditor or the internal auditor actions as laid down in article 121',
#        'in article 121', 'the european parliament and council',
#        'the internal auditor or her union institution on dealing with risks by issuing independent opinions on the quality of management and control systems and by issuing recommendations for improving the conditions of implementation of operations and promoting sound financial management',
#        'responsible for: assessing the suitability and effectiveness of internal management systems and the performance of departments in implementing policies programmes and actions by reference to the risks associated with programmes and actions assessing the efficiency and effectiveness of the internal control and audit systems applicable to each budget imple\xadmentation operation in particular',
#        'the internal auditor or the internal auditor duties in relation to all the activities and departments of the union institution',
#        'full and unlimited access to all information required to perform the internal auditor or the internal auditor duties if necessary',
#        'access including in member states and in third countries also',
#        'note of the annual report of the authorising officers and any other pieces of information',
#        'to the union institution concerned on the internal auditor or the internal auditor findings and recommendations',
#        'that action is taken with regard to recommendations resulting from audits',
#        'with regard to recommendations resulting from audits',
#        'whether the recommendations made in the reports of each union institution internal auditor are suitable for an exchange of best practices with other union institutions',
#        'suitable for an exchange of best practices with other union institutions',
#        'an annual internal audit report indicating the number and type of internal audits carried out the recommendations made in the reports of its internal auditor made and the action taken with regard to the recommendations made in the reports of its internal auditor',
#        'any systemic problems detected by the panel set up pursuant to article 143 where an annual internal audit report indicating the number and type of internal audits carried out gives the opinion referred to in article 93',
#        'pursuant to article 143 where an annual internal audit report indicating the number and type of internal audits carried out gives the opinion referred to in article 93',
#        'the opinion referred to in article 93 where',
#        'particularly on the overall compliance with the principles of sound financial management and performance',
#        'that appropriate measures have been taken in order to steadily improve and enhance appropriate measures application',
#        'in order to steadily improve and enhance appropriate measures application',
#        'in the context of the discharge procedure and in accordance with article 319',
#        'available the contact details of each union institution internal auditor to any natural or legal person involved in expenditure operations for the purposes of confidentially contacting the internal auditor',
#        'a report containing a summary of the number and type of internal audits',
#        'a synthesis of the recommendations made in the reports of its internal auditor and the action taken on the recommendations made in the reports of its internal auditor and',
#        'a synthesis of the recommendations made',
#        'on those recommendations to the european parliament and to the council',
#        'for in article 247',
#        'accessible to the public only after validation by the internal auditor of the action taken for the reports and findings of the internal auditor as well as',
#        'each union institution internal auditor with the resources required for the proper performance of the internal audit function and a mission charter detailing the tasks rights and obligations of each union institution internal auditor',
#        'the work programme',
#        'the work programme to the union institution',
#        'the union institution concerned internal auditor to carry out audits not included in the work programme referred to in paragraph',
#        'internal auditor',
#        'audits not included in the work programme referred to in paragraph',
#        'complete independence in the conduct of the audits',
#        'by the union institution', 'such as',
#        'that the internal auditor is totally independent in the performance of the internal auditor or her duties and to establish the internal auditors responsibility',
#        'totally independent in the performance of the internal auditor or her duties',
#        'the internal auditors responsibility', 'any instructions',
#        'in any way',
#        'the performance of the functions which by virtue of the internal auditor or her appointment are assigned to the internal auditor or her under this regulation',
#        'to the internal auditor or her under this regulation',
#        'a member of staff or',
#        'to have this article internal auditor as a member of staff declared liable for his or her actions',
#        'a reasoned decision to open an investigation',
#        'to the interested party',
#        'one or more officials of a grade equal to or higher than that of the member of staff in charge of the investigation under each union institution direct responsi\xadbility',
#        'in the course of the investigation',
#        'to the interested party who shall then be heard by the union institution concerned on the subject of that report',
#        'either a reasoned decision terminating the proceedings or a reasoned decision in accordance with articles 22 and 86 of and annex ix to the staff regulations on the basis of the report and the hearing',
#        'for information purposes to other union institutions and the court of auditors',
#        'an action in respect of such decisions before the court of justice of the european union',
#        'for in the staff regulations',
#        'an action without prejudice to the remedies allowed by the staff regulations directly before the court of justice of the european union in respect of any act relating to the performance of his or her duties as internal auditor',
#        'such an action within three months',
#        'from the calendar day on which the act in question came to his or her knowledge such actions shall be investigated and heard in accordance with article 91(5) of the staff regulations',
#        'on which to his or her knowledge such actions shall be investigated and heard in accordance with article 91(5) of the staff regulations',
#        'in accordance with article 91(5 of the staff regulations',
#        'an internal audit progress committee tasked with ensuring the independence of the internal auditor monitoring the quality of the internal audit work and ensuring that internal and external audit recommendations are properly taken into account and followed up by each union institution services',
#        'properly into account', 'by each union institution services',
#        'by each union institution taking into account each union institution organisational autonomy and the importance of independent expert advice'],
#       dtype=object)

# %%
triplets_df_nostop.to_csv('triplets_dataframe_clean.csv', index=False)

# %% [markdown]
# ## Filter heads and relations. Count how frequency of entities and relations per title. What are the most frequent ?

# %%
import pandas as pd
import ast
import spacy
import re
import claucy

# %%
# Load triplets dataframe 
triplets_df_nostop= pd.read_csv(r'C:\Users\Student\Desktop\Thesis-Coding\triplets_dataframe_clean.csv')

# %%
def convert_to_list(column):
    return column.apply(ast.literal_eval)

triplets_df_nostop['Content'] = convert_to_list(triplets_df_nostop['Content'])
triplets_df_nostop['triplets_list'] = convert_to_list(triplets_df_nostop['triplets_list'])

# %%
triplets_df_nostop.head()
# Out:
#                                                Title  \
# 0  TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 1  TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 2  TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 3  TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 4  TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
#
#                      Articles  \
# 0  Article 1  Subject matter
# 1     Article 2  Definitions
# 2     Article 2  Definitions
# 3     Article 2  Definitions
# 4     Article 2  Definitions
#
#                                              Content  \
# 0  [\nThis Regulation lays down the rules for the...
# 1  [ ‘applicant’ means a natural person or an ent...
# 2  [ ‘applicant’ means a natural person or an ent...
# 3  [ ‘applicant’ means a natural person or an ent...
# 4  [ ‘applicant’ means a natural person or an ent...
#
#                               coreference_list_ready  \
# 0  this regulation lays down the rules for the es...
# 1  applicant means a natural person or an entity ...
# 2  application document means a tender a request ...
# 3  award procedure means a procurement procedure ...
# 4  basic act means a legal act other than a recom...
#
#                                  Cleaned_Content_new  \
# 0  this regulation lays down the rules for the es...
# 1  applicant means a natural person or an entity ...
# 2  application document means a tender a request ...
# 3  award procedure means a procurement procedure ...
# 4  basic act means a legal act other than a recom...
#
#                                        triplets_list  empty_list  \
# 0  [this regulation, lay, the rules for the estab...       False
# 1  [applicant, mean, a natural person or an entit...       False
# 2  [application document, mean, a tender a reques...       False
# 3  [award procedure, mean, a procurement procedur...       False
# 4  [basic act, mean, a legal act other than a rec...       False
#
#    many_triplets                  head relation  \
# 0          False       this regulation      lay
# 1           True             applicant     mean
# 2          False  application document     mean
# 3          False       award procedure     mean
# 4           True             basic act     mean
#
#                                                 tail  is_stopword
# 0  the rules for the establishment and the implem...        False
# 1  a natural person or an entity with or without ...        False
# 2  a tender a request to participate a grant appl...        False
# 3  a procurement procedure a grant award procedur...        False
# 4  a legal act other than a recommendation or an ...        False

# %%
triplets_df_nostop[triplets_df_nostop["Title"]=='TITLE II \nBUDGET AND BUDGETARY PRINCIPLES ']["relation"].unique()
# Out:
# array(['implement', 'set', 'authorise', 'be charge', 'shall contain',
#        'shall consist', 'shall cover', 'prevent', 'be commit', 'be make',
#        'provide', 'be book', 'be enter', 'be', 'be authorise',
#        'be adjust', 'refer', 'have reach', 'adopt', 'be approve',
#        'be lay', 'be carry', 'be complete', 'have adopt', 'use', 'exceed',
#        'be return', 'shall take', 'shall inform', 'state', 'be apply',
#        'carry', 'commit', 'annex', 'be pay', 'cancel', 'be decommitte',
#        'correspond', 'apply', 'shall examine', 'shall decide', 'belong',
#        'require', 'may authorise', 'shall', 'shall enter', 'take',
#        'shall submit', 'inform', 'wish', 'be give', 'shall act',
#        'be exceed', 'raise', 'be draw', 'be present', 'account',
#        'be establish', 'avoid', 'be calculate', 'be use',
#        'shall constitute', 'participate', 'receive', 'transfer',
#        'may assign', 'specify', 'shall include', 'indicate',
#        'shall comprise', 'may receive', 'be show', 'be receive', 'save',
#        'be express', 'be estimate', 'shall give', 'be implement',
#        'be send', 'be base', 'accommodate', 'shall set', 'be monitor',
#        'may accept', 'concern', 'explain', 'mean', 'support', 'accept',
#        'finance', 'be limited', 'be list', 'pay', 'shall apply',
#        'be treat', 'be include', 'be earmark', 'subdivide',
#        'may transfer', 'be transfer', 'have authorise', 'be take',
#        'be accompany', 'be raise', 'may propose', 'make', 'may',
#        'may submit', 'approve', 'shall deliberate', 'intend', 'consider',
#        'refrain', 'be reduce', 'represent', 'have amend', 'have approve',
#        'amend', 'agree', 'reach', 'employ', 'be achieve', 'shall focus',
#        'progress', 'be report', 'expect', 'may take', 'shall assess',
#        'be undertake', 'shall provide', 'regard', 'present',
#        'shall estimate', 'be design', 'include', 'be perform',
#        'shall identify', 'shall have', 'publish', 'be publish',
#        'be declare', 'shall make', 'grant', 'be provide', 'shall publish',
#        'be deem', 'designate', 'be remove', 'identifie'], dtype=object)

# %%
triplets_df_nostop.groupby("Title")[["head"]].nunique()
# Out:
#                                                     head
# Title
# TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENER...   103
# TITLE II \nBUDGET AND BUDGETARY PRINCIPLES           218
# TITLE III \nESTABLISHMENT AND STRUCTURE OF THE ...    84
# TITLE IV \nBUDGET IMPLEMENTATION                     520
# TITLE IX \nPRIZES                                     20
# TITLE V \nCOMMON RULES                               235
# TITLE VI \nINDIRECT MANAGEMENT                        65
# TITLE VII \nPROCUREMENT AND CONCESSIONS              102
# TITLE VIII \nGRANTS                                  194
# TITLE X \nFINANCIAL INSTRUMENTS, BUDGETARY GUAR...   108
# TITLE XI \nCONTRIBUTIONS TO EUROPEAN POLITICAL ...    46
# TITLE XII \nOTHER BUDGET IMPLEMENTATION INSTRUM...    57
# TITLE XIII \nANNUAL ACCOUNTS AND OTHER FINANCIA...    36
# TITLE XIV \nEXTERNAL AUDIT AND DISCHARGE              57
# TITLE XV \nADMINISTRATIVE APPROPRIATIONS              32
# TITLE XVI \nINFORMATION REQUESTS AND DELEGATED ...   432

# %%
triplets_df_nostop.groupby("Title")[["relation"]].nunique()
# Out:
#                                                     relation
# Title
# TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENER...        34
# TITLE II \nBUDGET AND BUDGETARY PRINCIPLES               149
# TITLE III \nESTABLISHMENT AND STRUCTURE OF THE ...       108
# TITLE IV \nBUDGET IMPLEMENTATION                         374
# TITLE IX \nPRIZES                                         20
# TITLE V \nCOMMON RULES                                   200
# TITLE VI \nINDIRECT MANAGEMENT                            77
# TITLE VII \nPROCUREMENT AND CONCESSIONS                  107
# TITLE VIII \nGRANTS                                      165
# TITLE X \nFINANCIAL INSTRUMENTS, BUDGETARY GUAR...       117
# TITLE XI \nCONTRIBUTIONS TO EUROPEAN POLITICAL ...        57
# TITLE XII \nOTHER BUDGET IMPLEMENTATION INSTRUM...        72
# TITLE XIII \nANNUAL ACCOUNTS AND OTHER FINANCIA...        42
# TITLE XIV \nEXTERNAL AUDIT AND DISCHARGE                  59
# TITLE XV \nADMINISTRATIVE APPROPRIATIONS                  37
# TITLE XVI \nINFORMATION REQUESTS AND DELEGATED ...       258

# %%
nlp = spacy.load("en_core_web_sm")

def tokens_len(text):
    doc = nlp(text)
    tokens = []
    for token in doc:
        tokens.append(token)
    return len(tokens)

def contains_nouns(text):
    doc = nlp(text)
    k = False
    tags = []
    for token in doc:
        tags.append(spacy.explain(token.pos_))
    if "noun" in tags:
            k=True
    return k

# %%
relations_freq = triplets_df_nostop[triplets_df_nostop["Title"]=='TITLE II \nBUDGET AND BUDGETARY PRINCIPLES '].groupby(["relation"])["relation"].count().reset_index(name='count').sort_values(by=('count'), ascending=False)
relations_freq
# Out:
#       relation  count
# 108      refer     31
# 42     be make     28
# 11          be     27
# 31    be enter     12
# 23   be commit      8
# ..         ...    ...
# 141    specify      1
# 144    support      1
# 143  subdivide      1
# 142      state      1
# 148       wish      1
#
# [149 rows x 2 columns]

# %%
triplets_df_nostop[triplets_df_nostop["Title"]=='TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENERAL PRINCIPLES ']
# Out:
#                                                  Title  \
# 0    TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 1    TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 2    TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 3    TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 4    TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# ..                                                 ...
# 113  TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 114  TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 115  TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 116  TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
# 117  TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENE...
#
#                                               Articles  \
# 0                           Article 1  Subject matter
# 1                              Article 2  Definitions
# 2                              Article 2  Definitions
# 3                              Article 2  Definitions
# 4                              Article 2  Definitions
# ..                                                 ...
# 113                            Article 2  Definitions
# 114  Article 3  Compliance of secondary legislation...
# 115         Article 4  Periods, dates and time limits
# 116         Article 4  Periods, dates and time limits
# 117            Article 5  Protection of personal data
#
#                                                Content  \
# 0    [\nThis Regulation lays down the rules for the...
# 1    [ ‘applicant’ means a natural person or an ent...
# 2    [ ‘applicant’ means a natural person or an ent...
# 3    [ ‘applicant’ means a natural person or an ent...
# 4    [ ‘applicant’ means a natural person or an ent...
# ..                                                 ...
# 113  [ ‘applicant’ means a natural person or an ent...
# 114  [ \nProvisions concerning the implementation o...
# 115  [\nUnless otherwise provided in this Regulatio...
# 116  [\nUnless otherwise provided in this Regulatio...
# 117  [\nThis Regulation is without prejudice to Reg...
#
#                                 coreference_list_ready  \
# 0    this regulation lays down the rules for the es...
# 1    applicant means a natural person or an entity ...
# 2    application document means a tender a request ...
# 3    award procedure means a procurement procedure ...
# 4    basic act means a legal act other than a recom...
# ..                                                 ...
# 113  works contract means a contract covering eithe...
# 114  provisions concerning the implementation of th...
# 115  unless otherwise provided in this regulation c...
# 116  unless otherwise provided in this regulation c...
# 117  this regulation is without prejudice to regula...
#
#                                    Cleaned_Content_new  \
# 0    this regulation lays down the rules for the es...
# 1    applicant means a natural person or an entity ...
# 2    application document means a tender a request ...
# 3    award procedure means a procurement procedure ...
# 4    basic act means a legal act other than a recom...
# ..                                                 ...
# 113  works contract means a contract covering eithe...
# 114  provisions concerning the implementation of th...
# 115  unless otherwise provided in this regulation c...
# 116  unless otherwise provided in this regulation c...
# 117  this regulation is without prejudice to regula...
#
#                                          triplets_list  empty_list  \
# 0    [this regulation, lay, the rules for the estab...       False
# 1    [applicant, mean, a natural person or an entit...       False
# 2    [application document, mean, a tender a reques...       False
# 3    [award procedure, mean, a procurement procedur...       False
# 4    [basic act, mean, a legal act other than a rec...       False
# ..                                                 ...         ...
# 113  [the execution or both the execution and desig...       False
# 114  [provisions concerning the implementation of t...       False
# 115  [no 118271 ( 1 ), provide,  otherwise in this ...       False
# 116  [no 118271 ( 1 ), shall apply,  to the deadlin...       False
# 117  [this regulation, be,  without prejudice to re...       False
#
#      many_triplets                                               head  \
# 0            False                                    this regulation
# 1             True                                          applicant
# 2            False                               application document
# 3            False                                    award procedure
# 4             True                                          basic act
# ..             ...                                                ...
# 113           True  the execution or both the execution and design...
# 114          False  provisions concerning the implementation of th...
# 115           True                                    no 118271 ( 1 )
# 116           True                                    no 118271 ( 1 )
# 117          False                                    this regulation
#
#          relation                                               tail  \
# 0             lay  the rules for the establishment and the implem...
# 1            mean  a natural person or an entity with or without ...
# 2            mean  a tender a request to participate a grant appl...
# 3            mean  a procurement procedure a grant award procedur...
# 4            mean  a legal act other than a recommendation or an ...
# ..            ...                                                ...
# 113     directive  201424eu or the realisation by whatever means ...
# 114  shall comply  with the budgetary principles set out in title ii
# 115       provide  otherwise in this regulation council regulatio...
# 116   shall apply        to the deadlines set out in this regulation
# 117            be  without prejudice to regulations (ec) no 45200...
#
#      is_stopword
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
# ..           ...
# 113        False
# 114        False
# 115        False
# 116        False
# 117        False
#
# [118 rows x 12 columns]

# %%
relations_freq = triplets_df_nostop.groupby(["relation"])["relation"].count().reset_index(name='count').sort_values(by=('count'), ascending=False)
relations_freq["relative_freq"] = (relations_freq["count"] / relations_freq["count"].sum()) * 100
relations_freq
# Out:
#              relation  count  relative_freq
# 36                 be    366       8.950844
# 601             refer    276       6.749817
# 240        be replace    110       2.690144
# 187           be make     75       1.834189
# 555              mean     74       1.809733
# ..                ...    ...            ...
# 815     should remain      1       0.024456
# 814     should enable      1       0.024456
# 593             reach      1       0.024456
# 812    shall withdraw      1       0.024456
# 820  stabilityoriente      1       0.024456
#
# [856 rows x 3 columns]

# %%
relations_freq.groupby("count").count()
# Out:
#        relation  relative_freq
# count
# 1           376            376
# 2           176            176
# 3            76             76
# 4            43             43
# 5            34             34
# 6            31             31
# 7            17             17
# 8            13             13
# 9            16             16
# 10            8              8
# 11            7              7
# 12            8              8
# 13            7              7
# 14            2              2
# 15            6              6
# 16            3              3
# 17            1              1
# 18            1              1
# 19            1              1
# 20            2              2
# 21            4              4
# 22            1              1
# 23            2              2
# 24            1              1
# 27            2              2
# 28            2              2
# 29            1              1
# 30            1              1
# 31            2              2
# 36            1              1
# 37            1              1
# 42            1              1
# 46            1              1
# 50            1              1
# 53            1              1
# 62            1              1
# 74            1              1
# 75            1              1
# 110           1              1
# 276           1              1
# 366           1              1

# %%
relations_freq = triplets_df_nostop[triplets_df_nostop["Title"]=='TITLE II \nBUDGET AND BUDGETARY PRINCIPLES '].groupby(["relation"])["relation"].count().reset_index(name='count').sort_values(by=('count'), ascending=False)
relations_freq["relative_freq"] = (relations_freq["count"] / relations_freq["count"].sum()) * 100
relations_freq
# Out:
#       relation  count  relative_freq
# 108      refer     31       8.378378
# 42     be make     28       7.567568
# 11          be     27       7.297297
# 31    be enter     12       3.243243
# 23   be commit      8       2.162162
# ..         ...    ...            ...
# 141    specify      1       0.270270
# 144    support      1       0.270270
# 143  subdivide      1       0.270270
# 142      state      1       0.270270
# 148       wish      1       0.270270
#
# [149 rows x 3 columns]

# %%
relations_freq.groupby("count").count()
# Out:
#        relation  relative_freq
# count
# 1            90             90
# 2            27             27
# 3            10             10
# 4             8              8
# 5             3              3
# 6             2              2
# 7             1              1
# 8             4              4
# 12            1              1
# 27            1              1
# 28            1              1
# 31            1              1

# %%
relations_freq.groupby("relative_freq")['count'].count()
# Out:
# relative_freq
# 0.270270    90
# 0.540541    27
# 0.810811    10
# 1.081081     8
# 1.351351     3
# 1.621622     2
# 1.891892     1
# 2.162162     4
# 3.243243     1
# 7.297297     1
# 7.567568     1
# 8.378378     1
# Name: count, dtype: int64

# %%
import seaborn as sns
# Out:
# WARNING:matplotlib.font_manager:Matplotlib is building the font cache; this may take a moment.
# INFO:matplotlib.font_manager:generated new fontManager

# %%
sns.barplot(relations_freq, y="relation", x="count")
# Out:
# <Axes: xlabel='count', ylabel='relation'>

# %%
sns.boxplot(data=relations_freq, y="count")
# Out:
# <Axes: ylabel='count'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Create a boxplot
plt.figure(figsize=(10, 6))
box_plot = sns.boxplot(y='count', data=relations_freq, palette="Set3")

# Calculate percentiles (25th, 50th, 75th)
percentiles = np.percentile(relations_freq['count'], [25, 50, 75])
percentile_labels = ['25th Percentile', 'Median (50th Percentile)', '75th Percentile']

# Add horizontal lines for percentiles
for p, label in zip(percentiles, percentile_labels):
    plt.axhline(y=p, color='red', linestyle='--', label=label)
    # Annotate the percentile on the right side
    plt.text(x=2.5, y=p, s=label, color='red', va='center', fontsize=10)

# Customize the plot
plt.title('Boxplot with Percentiles (No Grid)')
plt.xlabel('Categories')
plt.ylabel('Values')
plt.legend(title='Percentiles')

# Show the plot
plt.show()
# Out:
# C:\Users\Student\AppData\Local\Temp\ipykernel_4744\2053893148.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   box_plot = sns.boxplot(y='count', data=relations_freq, palette="Set3")

# %%
relations_freq["count"].quantile(0.5)
# Out:
# np.float64(2.0)

# %%
triplets_df_nostop[triplets_df_nostop["relation"] == 'should remain']
# Out:
#                                                   Title  \
# 3950  TITLE XVI \nINFORMATION REQUESTS AND DELEGATED...
#
#                                                Articles  \
# 3950  Article 274  Amendments to Regulation (EU) No ...
#
#                                                 Content  \
# 3950  [ in recital 24, the first sentence is replace...
#
#                                  coreference_list_ready  \
# 3950  in recital 24 the first sentence is replaced b...
#
#                                     Cleaned_Content_new  \
# 3950  in recital 24 the first sentence is replaced b...
#
#                                           triplets_list  empty_list  \
# 3950  [the member states, should remain,  in recital...       False
#
#       many_triplets               head       relation  \
# 3950           True  the member states  should remain
#
#                                                    tail  is_stopword
# 3950  in recital 24 the first sentence is replaced b...        False

# %%
import spacy
from spacy.symbols import NOUN, det

nlp = spacy.load("en_core_web_sm")
doc = nlp("the payment appropriations provided for in the relevant budget lines for the following financial year")

for possible_subject in doc:
    if possible_subject.dep == det and possible_subject.head.pos == NOUN:
        print(possible_subject, possible_subject.head)
# Out:
# the appropriations
# the lines
# the year

# %%
nlp = spacy.load("en_core_web_sm")
doc = nlp("the payment appropriations provided for in the relevant budget lines for the following financial year")
for token in doc:
    print(token.text, token.dep_, token.head.text, token.head.pos_,
            [child for child in token.children])
# Out:
# the det appropriations NOUN []
# payment compound appropriations NOUN []
# appropriations ROOT appropriations NOUN [the, payment, provided]
# provided acl appropriations NOUN [for, in, for]
# for prep provided VERB []
# in prep provided VERB [lines]
# the det lines NOUN []
# relevant amod lines NOUN []
# budget compound lines NOUN []
# lines pobj in ADP [the, relevant, budget]
# for prep provided VERB [year]
# the det year NOUN []
# following amod year NOUN []
# financial amod year NOUN []
# year pobj for ADP [the, following, financial]

# %%
from spacy import displacy
doc = nlp("the expenditure of the european agricultural guarantee fund (eagf)")
displacy.render(doc, options={"fine_grained": True})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="b9a38d804bad405ea19a89f54180fe0d-0" class="displacy" width="1625" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">expenditure</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">IN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">DT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">european</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">JJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">agricultural</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">JJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">guarantee</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">fund (</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">NN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">eagf)</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b9a38d804bad405ea19a89f54180fe0d-0-0" stroke-width="2px" d="M70,352.0 C70,264.5 210.0,264.5 210.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b9a38d804bad405ea19a89f54180fe0d-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,354.0 L62,342.0 78,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b9a38d804bad405ea19a89f54180fe0d-0-1" stroke-width="2px" d="M245,352.0 C245,264.5 385.0,264.5 385.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b9a38d804bad405ea19a89f54180fe0d-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M385.0,354.0 L393.0,342.0 377.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b9a38d804bad405ea19a89f54180fe0d-0-2" stroke-width="2px" d="M595,352.0 C595,89.5 1270.0,89.5 1270.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b9a38d804bad405ea19a89f54180fe0d-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M595,354.0 L587,342.0 603,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b9a38d804bad405ea19a89f54180fe0d-0-3" stroke-width="2px" d="M770,352.0 C770,177.0 1265.0,177.0 1265.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b9a38d804bad405ea19a89f54180fe0d-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770,354.0 L762,342.0 778,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b9a38d804bad405ea19a89f54180fe0d-0-4" stroke-width="2px" d="M945,352.0 C945,264.5 1085.0,264.5 1085.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b9a38d804bad405ea19a89f54180fe0d-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M945,354.0 L937,342.0 953,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b9a38d804bad405ea19a89f54180fe0d-0-5" stroke-width="2px" d="M1120,352.0 C1120,264.5 1260.0,264.5 1260.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b9a38d804bad405ea19a89f54180fe0d-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1120,354.0 L1112,342.0 1128,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b9a38d804bad405ea19a89f54180fe0d-0-6" stroke-width="2px" d="M420,352.0 C420,2.0 1275.0,2.0 1275.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b9a38d804bad405ea19a89f54180fe0d-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1275.0,354.0 L1283.0,342.0 1267.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b9a38d804bad405ea19a89f54180fe0d-0-7" stroke-width="2px" d="M1295,352.0 C1295,264.5 1435.0,264.5 1435.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b9a38d804bad405ea19a89f54180fe0d-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">appos</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1435.0,354.0 L1443.0,342.0 1427.0,342.0" fill="currentColor"/>
# </g>
# </svg></span>

# %%
nlp = spacy.load("en_core_web_sm")
doc = nlp("the expenditure of the european agricultural guarantee fund (eagf)")
for chunk in doc.noun_chunks:
    print(chunk)
# Out:
# the expenditure
# the european agricultural guarantee fund
# eagf

# %%
triplets_df_nostop[triplets_df_nostop["Title"]=='TITLE II \nBUDGET AND BUDGETARY PRINCIPLES ']["head"].unique()
# Out:
# array(['the budget', 'the common foreign and security policy (cfsp)',
#        'the appropriations authorised for the financial year',
#        'commitment appropriations', 'payment appropriations',
#        'paragraphs 2 and 3 of this article', 'appropriations',
#        'budgetary commitments', 'all revenue and expenditure',
#        'no expenditure', 'an appropriation',
#        'interest generated by prefinancing payments made from the budget',
#        'the appropriations entered in the budget',
#        'the revenue of a financial year',
#        'the own resources for the month of january of the following financial year may be made available in advance pursuant to regulation (eu euratom) no 6092014',
#        'the entries in respect of the value added tax (vat) and',
#        'commitments', 'the global budgetary commitments', 'payments',
#        'the expenditure of the european agricultural guarantee fund (eagf)',
#        'the payment order', 'the following expenditure',
#        'routine administrative expenditure', 'such expenditure',
#        'the basis for such expenditure',
#        'appropriations which have not been used by the end of the financial year for which they were entered may be carried over by a decision taken pursuant to paragraph 3 but only to the following financial year: commitment appropriations and nondifferentiated appropriations for which most of the preparatory stages of the commitment procedure have been completed by 31 december of the financial year',
#        'most of the preparatory stages of the commitment procedure',
#        'such appropriations', 'the legislative authority',
#        'the commission',
#        'the payment appropriations provided for in the relevant budget lines for the following financial year',
#        'the union institution concerned',
#        'carryovers of noncommitted appropriations',
#        'appropriations which are carried over',
#        'the criteria in points and of the first subparagraph of paragraph 2',
#        'commitment appropriations as referred to in regulation (eu) no 13032013 and in regulation (eu)',
#        'other commitment appropriations',
#        'the treatment of external assigned revenue as referred to in point of paragraph 4 of this article resulting from the participation of european free trade association (efta) states in certain union programmes in accordance with point of article 21(2)',
#        'no 32', 'the appropriations', 'nondifferentiated appropriations',
#        '4 appropriations placed in reserve and appropriations for staff expenditure',
#        'the commitment appropriations and the nondifferentiated appropriations',
#        'the commitments', 'the preparatory stages', 'the commitment',
#        'a carryover to the following financial year',
#        'appropriations carried over in accordance with point of the first subparagraph of article 12(2) which have not been committed by 31 march of the following financial year or by 31 december of the following financial year for amounts relating to building projects',
#        'the year in which they were made as a result of the total or partial nonimplementation of the actions for which they were earmarked the appropriations corresponding to such decommitments',
#        'no 5142014', 'this article',
#        'the appropriations corresponding to decommitments referred to in regulations (eu) no 13032013 (eu) no 2232014 and (eu)',
#        'the appropriations corresponding to decom\xadmitments',
#        'commitment appropriations corresponding to the amount of decommitments made as a result of total or partial nonimplementation of corresponding research projects',
#        'the projects', 'commitments and payments', 'that sum',
#        'the appropriations authorised in the relevant chapter of the budget for the preceding financial year',
#        'if the continuity of union action and management needs',
#        'the council',
#        'its decision on authorisation to the european parliament',
#        'the european parliament',
#        'the expiry of the 30 days in which case the commission shall submit a new proposal',
#        'the decision', 'the additional twelfths',
#        'the authorisation of four provisional twelfths granted in accordance with paragraph 4',
#        'the european parliament and the council',
#        'the overall total of the appropriations',
#        'revenue and payment appropriations',
#        'the union and the union bodies', '71',
#        'the balance from each financial year',
#        'the estimates of the revenue or payment appropriations',
#        'any discrepancy between those accounts and the estimates of the revenue or payment appropriations',
#        'the multiannual financial framework and the budget',
#        'the accounts', 'the cashflow purposes',
#        'the authorising officer responsible',
#        'the payment order or recovery order',
#        '82 83 and 84 conversion between euro and another currency',
#        'accounting exchange rate', 'the rate',
#        'currency conversion operations',
#        'the rate of conversion between the euro and other currencies',
#        'prejudice to article 21 total revenue',
#        'external assigned revenue and internal assigned revenue',
#        'the following', 'the jrc',
#        'revenue from third parties in respect of goods services or work supplied at services or work request revenue arising from the repayment in accordance with article 101 of amounts wrongly paid proceeds from the supply of goods services and works to other departments within an union institution or to other union institutions or bodies including refunds by other union institutions or bodies of mission allowances paid on their behalf insurance payments',
#        'assigned revenue', 'a basic act', 'such revenue',
#        'the structure to accommodate assigned revenue in the budget',
#        'which budget lines', 'the estimated revenue',
#        'the appropriations corresponding to assigned revenue',
#        'the revenue', 'the contribution agreement',
#        'euro commitment appropriations', 'the amount receivable',
#        'the entry of the amounts in the statement of revenue',
#        'appropriations referred to in point of the first subparagraph of this paragraph',
#        'the estimates of amounts receivable',
#        'seven twelfths of the sum entered in the budget',
#        'the remaining five twelfths',
#        'the contributions provided for in paragraph 1',
#        'any contribution or additional payment owed by member states to the budget',
#        'payments made shall be entered in the account provided for in regulation (eu euratom) no 6092014 and',
#        'in the statement of revenue a budget line with a token entry',
#        'an annex forming an integral part of the budget', 'efta states',
#        'the use of the revenue arising from the financial contribution of efta states',
#        'union institutions', 'no objection',
#        'the union institutions concerned', 'corporate sponsorship',
#        'a legal person',
#        'respective websites union institutions and bodies',
#        'the event or activity',
#        'exclusively social events the event or activity is not exclusively financed through corporate sponsorship the service in return for corporate sponsorship',
#        'the sponsor', 'the value of corporate sponsorship',
#        'the following deductions',
#        'penalties imposed on parties to contracts or beneficiaries discounts refunds and rebates on individual invoices and cost statements interest generated by prefinancing payments adjustments for amounts',
#        'the adjustments', 'the excess payment', 'union accounting rules',
#        'the cost of products or services provided to the union incorporating',
#        'the cost of products or services provided to the union incorporating taxes refunded by third countries on the basis of relevant agreements may be charged to the budget for the extax amount for any of the following amounts: the extax amount the taxinclusive amount',
#        'the first subparagraph subsequently reimbursed taxes',
#        'adjustments', 'the final gain or loss', 'the chapters',
#        'the commission and the other union institutions',
#        'the limits referred to in articles 29 30 and',
#        'the amount to be taken into consideration for the purposes of calculating the limits referred to in articles 29 30 and',
#        'transfers',
#        'the amount corresponding to the transfers which are carried out autonomously by the commission or by any other union institution concerned without a decision of the european parliament and of the council',
#        'proposals for transfers and all information for the european parliament and for the council concerning transfers made under articles 29 30 and 31',
#        'the transfer', 'the union institution',
#        'that duly justified objections',
#        'any union institution other than the commission',
#        'any union institution other than the commission may within any union institution',
#        'the appropriations concerned',
#        'the provisioned resources in the common provisioning fund of the latter',
#        'the expenditure', 'the items', 'those transfers',
#        'the commission may within the commission own section of the budget decide on the following transfers of appropriations from one title to another provided the commission',
#        'each union institution', 'the transfer of payment appropriations',
#        'the sixweek period', 'the transfer of the payment appropriations',
#        'the corresponding part of the expenditure',
#        'the european parliament and to the council',
#        'the european parliament and the council the latter acting by qualified majority',
#        'a transfer proposal shall be approved or considered to be approved if within the sixweek period any of the following occurs: the european parliament',
#        'either the european parliament or the council',
#        'the other institution',
#        'either the european parliament or the council requests',
#        'the use of the emergency aid reserve',
#        'the european parliament and by the council',
#        'proposals for transfers from the emergency aid reserve shall be accompanied by appropriate and detailed supporting documents demonstrating: the most recent information available for the implementation of appropriations and the estimate of requirements up to the end of the financial year for the budget line to which the transfer is to be made an analysis of the possibilities of reallocating appropriations',
#        'the resources used by the union institution concerned in the pursuit of its activities',
#        'the principle of economy which requires that the resources used by the union institution concerned in the pursuit of its activities shall be made available in due time in appropriate quantity and quality and at the best price',
#        'the objectives pursued', 'the use of appropriations',
#        'objectives for programmes and activities',
#        'performance indicators',
#        'problems with the achievement of objectives',
#        'specific measurable attainable relevant and timebound objectives',
#        'programmes and activities which entail significant spending',
#        'ex ante evaluations supporting the preparation of programmes and activities shall be based on evidence on the performance of related programmes or activities and shall identify and analyse the issues to be addressed the added value of union involvement objectives expected effects of different options and monitoring and evaluation arrangements',
#        'the added value of union involvement objectives',
#        'the ex ante evaluation', 'retrospective evaluations',
#        'the monitoring arrangements and indicators established for the action concerned',
#        'the findings',
#        'any proposal or initiative submitted to the legislative authority by the commission',
#        'any amendment to a proposal or initiative submitted to the legislative authority which may have an appreciable impact on the budget including changes in the number of posts',
#        'a financial statement prepared by the union institution proposing the amendment',
#        'such assessment',
#        'the purposes of budget implementation internal control',
#        'effective internal control', 'efficient internal control',
#        'the implementation of an appropriate risk management and control strategy coordinated among appropriate actors involved in the control chain the accessibility for all appropriate actors in the control chain of the results of controls',
#        'the quality of the underlying work', 'the underlying work',
#        'the level of error', 'the president of the european parliament',
#        'the budgets', 'the european union',
#        'pending official publication in the official journal of the european unionthe european union',
#        'the consolidated annual accounts',
#        'the first subparagraph of this paragraph',
#        'other union institutions', 'save in the cases',
#        'the following information', 'the recipient', 'the amount',
#        'the information referred to in the first subparagraph of this paragraph',
#        'contests', 'the information',
#        'education supports paid to natural persons and other direct support paid to natural persons most in need as referred to in point of article 191(4)',
#        'such support', 'natural persons',
#        'the disclosure of the information referred to in the first subparagraph of paragraph 2',
#        'persons or entities implementing union funds pursuant to point of the first subparagraph of article 62(1)',
#        'those rules', 'any publication of personal data', 'bodies',
#        'the funds', 'the websites of union institutions',
#        'the information as provided by the persons entities or bodies',
#        'personal data', 'the information referred', 'whose official name'],
#       dtype=object)

# %%
nlp = spacy.load("en_core_web_sm")
doc = nlp("all revenue and expenditure")
for chunk in doc.noun_chunks:
    print(chunk)
# Out:
# all revenue
# expenditure

# %%
triplets_df_nostop[triplets_df_nostop["Title"]=='TITLE I \nSUBJECT MATTER, DEFINITIONS AND GENERAL PRINCIPLES ']["relation"]
# Out:
# 0               lay
# 1              mean
# 2              mean
# 3              mean
# 4              mean
#            ...
# 113       directive
# 114    shall comply
# 115         provide
# 116     shall apply
# 117              be
# Name: relation, Length: 118, dtype: object
